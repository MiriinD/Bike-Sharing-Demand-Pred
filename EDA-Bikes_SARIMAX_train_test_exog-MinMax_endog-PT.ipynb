# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
# %matplotlib inline 
from clean_data_functions import * #Importing our defined functions to clean
from scipy.stats import mode
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None) 
sns.set_theme(style ="whitegrid")

# %matplotlib inline

# %%
eco_bici = pd.read_csv("DATA/year_ecobici_df.csv")

# %%
eco_bici.head(100)
# Out:
#    Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro Fecha_Retiro  \
# 0               M          24.0  2252039                   007   31/07/2023
# 1               M          33.0  8626897                   206   31/07/2023
# 2               M          34.0  4940557                   215   31/07/2023
# 3               F          30.0  2036523                   291   31/07/2023
# 4               F          23.0  8079220                   546   31/07/2023
# ..            ...           ...      ...                   ...          ...
# 95              F          29.0  5310842                   258   01/08/2023
# 96              M          16.0  7402217                   015   01/08/2023
# 97              M          46.0  5514278                   015   01/08/2023
# 98              M          21.0  2998797                   016   01/08/2023
# 99              O          31.0  8572349                   015   01/08/2023
#
#    Hora_Retiro Ciclo_EstacionArribo Fecha Arribo Hora_Arribo
# 0     23:52:38                  064   01/08/2023    00:00:03
# 1     23:48:01                  212   01/08/2023    00:00:20
# 2     23:55:50                  212   01/08/2023    00:00:30
# 3     23:32:42                  082   01/08/2023    00:01:08
# 4     23:51:09                  498   01/08/2023    00:01:21
# ..         ...                  ...          ...         ...
# 95    00:04:11                  369   01/08/2023    00:29:25
# 96    00:24:48                  006   01/08/2023    00:29:41
# 97    00:23:18                  006   01/08/2023    00:30:04
# 98    00:13:17                  181   01/08/2023    00:30:07
# 99    00:18:55                  545   01/08/2023    00:31:17
#
# [100 rows x 9 columns]

# %%
eco_bici.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13735648 entries, 0 to 13735647
# Data columns (total 9 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Genero_Usuario         object
#  1   Edad_Usuario           float64
#  2   Bici                   int64
#  3   Ciclo_Estacion_Retiro  object
#  4   Fecha_Retiro           object
#  5   Hora_Retiro            object
#  6   Ciclo_EstacionArribo   object
#  7   Fecha Arribo           object
#  8   Hora_Arribo            object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 943.2+ MB

# %%
null_check(eco_bici)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735643    0
# 13735644    0
# 13735645    0
# 13735646    0
# 13735647    0
# Length: 13735648, dtype: int64
#
# Total null values per column:
# Genero_Usuario           150
# Edad_Usuario             195
# Bici                       0
# Ciclo_Estacion_Retiro      0
# Fecha_Retiro               0
# Hora_Retiro                0
# Ciclo_EstacionArribo       0
# Fecha Arribo               0
# Hora_Arribo                0
# dtype: int64

# %%
dropna_rows_cols(eco_bici, 6, 1500)
# Out:
# Deleted 0 rows
# Deleted 0 columns
#          Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro  \
# 0                     M          24.0  2252039                   007
# 1                     M          33.0  8626897                   206
# 2                     M          34.0  4940557                   215
# 3                     F          30.0  2036523                   291
# 4                     F          23.0  8079220                   546
# ...                 ...           ...      ...                   ...
# 13735643              M          33.0  6683080                   022
# 13735644              M          28.0  2005171                   150
# 13735645              M          26.0  6842108                   545
# 13735646              M          53.0  5478714                   007
# 13735647              F          30.0  3046505                   129
#
#          Fecha_Retiro Hora_Retiro Ciclo_EstacionArribo Fecha Arribo  \
# 0          31/07/2023    23:52:38                  064   01/08/2023
# 1          31/07/2023    23:48:01                  212   01/08/2023
# 2          31/07/2023    23:55:50                  212   01/08/2023
# 3          31/07/2023    23:32:42                  082   01/08/2023
# 4          31/07/2023    23:51:09                  498   01/08/2023
# ...               ...         ...                  ...          ...
# 13735643   31/01/2024    23:47:55                  041   31/01/2024
# 13735644   31/01/2024    23:56:03                  155   31/01/2024
# 13735645   31/01/2024    23:48:34                  115   31/01/2024
# 13735646   31/01/2024    23:45:28                  151   31/01/2024
# 13735647   31/01/2024    23:48:47                  072   31/01/2024
#
#          Hora_Arribo
# 0           00:00:03
# 1           00:00:20
# 2           00:00:30
# 3           00:01:08
# 4           00:01:21
# ...              ...
# 13735643    23:59:41
# 13735644    23:59:53
# 13735645    23:59:56
# 13735646    23:59:58
# 13735647    23:59:59
#
# [13735648 rows x 9 columns]

# %%
eco_bici.columns
# Out:
# Index(['Genero_Usuario', 'Edad_Usuario', 'Bici', 'Ciclo_Estacion_Retiro',
#        'Fecha_Retiro', 'Hora_Retiro', 'Ciclo_EstacionArribo', 'Fecha Arribo',
#        'Hora_Arribo'],
#       dtype='object')

# %%
eco_bici_df= eco_bici.rename(columns={'Genero_Usuario': 'user_gender',
                                       'Edad_Usuario': 'user_age',
                                       'Bici': 'bike_id',
                                       'Ciclo_Estacion_Retiro': 'pickup_station',
                                       'Fecha_Retiro': 'pickup_date',
                                       'Hora_Retiro': 'pickup_time',
                                       'Ciclo_EstacionArribo': 'return_station',
                                       'Fecha Arribo': 'return_date',
                                       'Hora_Arribo': 'return_time'})

# %%
eco_bici_df.columns
# Out:
# Index(['user_gender', 'user_age', 'bike_id', 'pickup_station', 'pickup_date',
#        'pickup_time', 'return_station', 'return_date', 'return_time'],
#       dtype='object')

# %%
eco_bici_df["user_gender"] = eco_bici_df["user_gender"].fillna('undefined')

# %%
# #Interesting data in case we want to show the unknown cases where the bikes where not returned, time, age, or finding patterns
# ecobicis_never_returned = eco_bici_df[eco_bici_df['return_station'].isna() | eco_bici_df['return_date'].isna() | eco_bici_df['return_time'].isna()]
# ecobicis_never_returned

# %%
clean_eco_bici_df= eco_bici_df.dropna(subset=['return_station', 'return_date', 'return_time'])
clean_eco_bici_df
# Out:
#          user_gender  user_age  bike_id pickup_station pickup_date  \
# 0                  M      24.0  2252039            007  31/07/2023
# 1                  M      33.0  8626897            206  31/07/2023
# 2                  M      34.0  4940557            215  31/07/2023
# 3                  F      30.0  2036523            291  31/07/2023
# 4                  F      23.0  8079220            546  31/07/2023
# ...              ...       ...      ...            ...         ...
# 13735643           M      33.0  6683080            022  31/01/2024
# 13735644           M      28.0  2005171            150  31/01/2024
# 13735645           M      26.0  6842108            545  31/01/2024
# 13735646           M      53.0  5478714            007  31/01/2024
# 13735647           F      30.0  3046505            129  31/01/2024
#
#          pickup_time return_station return_date return_time
# 0           23:52:38            064  01/08/2023    00:00:03
# 1           23:48:01            212  01/08/2023    00:00:20
# 2           23:55:50            212  01/08/2023    00:00:30
# 3           23:32:42            082  01/08/2023    00:01:08
# 4           23:51:09            498  01/08/2023    00:01:21
# ...              ...            ...         ...         ...
# 13735643    23:47:55            041  31/01/2024    23:59:41
# 13735644    23:56:03            155  31/01/2024    23:59:53
# 13735645    23:48:34            115  31/01/2024    23:59:56
# 13735646    23:45:28            151  31/01/2024    23:59:58
# 13735647    23:48:47            072  31/01/2024    23:59:59
#
# [13735648 rows x 9 columns]

# %%
clean_eco_bici_df= eco_bici_df.dropna(subset=['return_station', 'return_date', 'return_time'])
clean_eco_bici_df['user_gender'].unique()
# Out:
# array(['M', 'F', 'O', '?', 'undefined'], dtype=object)

# %%
clean_eco_bici_df['user_gender'] = clean_eco_bici_df['user_gender'].replace(['O', '?'], 'undefined')

# %%
clean_eco_bici_df1= clean_eco_bici_df.dropna(subset=['user_age'])
null_check(clean_eco_bici_df1)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735643    0
# 13735644    0
# 13735645    0
# 13735646    0
# 13735647    0
# Length: 13735453, dtype: int64
#
# Total null values per column:
# user_gender       0
# user_age          0
# bike_id           0
# pickup_station    0
# pickup_date       0
# pickup_time       0
# return_station    0
# return_date       0
# return_time       0
# dtype: int64

# %%
clean_eco_bici_df1['pickup_time'] = clean_eco_bici_df1['pickup_time'].apply(lambda x: '{:02d}:{:02d}:00'.format(*map(int, x.replace('.', ':').split(':'))))
clean_eco_bici_df1['return_time'] = clean_eco_bici_df1['return_time'].apply(lambda x: '{:02d}:{:02d}:00'.format(*map(int, x.replace('.', ':').split(':'))))
clean_eco_bici_df1
# Out:
#          user_gender  user_age  bike_id pickup_station pickup_date  \
# 0                  M      24.0  2252039            007  31/07/2023
# 1                  M      33.0  8626897            206  31/07/2023
# 2                  M      34.0  4940557            215  31/07/2023
# 3                  F      30.0  2036523            291  31/07/2023
# 4                  F      23.0  8079220            546  31/07/2023
# ...              ...       ...      ...            ...         ...
# 13735643           M      33.0  6683080            022  31/01/2024
# 13735644           M      28.0  2005171            150  31/01/2024
# 13735645           M      26.0  6842108            545  31/01/2024
# 13735646           M      53.0  5478714            007  31/01/2024
# 13735647           F      30.0  3046505            129  31/01/2024
#
#          pickup_time return_station return_date return_time
# 0           23:52:00            064  01/08/2023    00:00:00
# 1           23:48:00            212  01/08/2023    00:00:00
# 2           23:55:00            212  01/08/2023    00:00:00
# 3           23:32:00            082  01/08/2023    00:01:00
# 4           23:51:00            498  01/08/2023    00:01:00
# ...              ...            ...         ...         ...
# 13735643    23:47:00            041  31/01/2024    23:59:00
# 13735644    23:56:00            155  31/01/2024    23:59:00
# 13735645    23:48:00            115  31/01/2024    23:59:00
# 13735646    23:45:00            151  31/01/2024    23:59:00
# 13735647    23:48:00            072  31/01/2024    23:59:00
#
# [13735453 rows x 9 columns]

# %%
clean_eco_bici_df1.isna().sum()
# Out:
# user_gender       0
# user_age          0
# bike_id           0
# pickup_station    0
# pickup_date       0
# pickup_time       0
# return_station    0
# return_date       0
# return_time       0
# dtype: int64

# %%
clean_eco_bici_df1['pickup_time'].apply(lambda x: datetime.strptime(x, "%H:%M:%S"))
clean_eco_bici_df1['pickup_time'] 
pd.to_timedelta(clean_eco_bici_df1['pickup_time'])

clean_eco_bici_df1.isna().sum()
# Out:
# 0          1900-01-01 23:52:00
# 1          1900-01-01 23:48:00
# 2          1900-01-01 23:55:00
# 3          1900-01-01 23:32:00
# 4          1900-01-01 23:51:00
#                    ...
# 13735643   1900-01-01 23:47:00
# 13735644   1900-01-01 23:56:00
# 13735645   1900-01-01 23:48:00
# 13735646   1900-01-01 23:45:00
# 13735647   1900-01-01 23:48:00
# Name: pickup_time, Length: 13735453, dtype: datetime64[ns]
# 0           23:52:00
# 1           23:48:00
# 2           23:55:00
# 3           23:32:00
# 4           23:51:00
#               ...
# 13735643    23:47:00
# 13735644    23:56:00
# 13735645    23:48:00
# 13735646    23:45:00
# 13735647    23:48:00
# Name: pickup_time, Length: 13735453, dtype: object
# 0          0 days 23:52:00
# 1          0 days 23:48:00
# 2          0 days 23:55:00
# 3          0 days 23:32:00
# 4          0 days 23:51:00
#                  ...
# 13735643   0 days 23:47:00
# 13735644   0 days 23:56:00
# 13735645   0 days 23:48:00
# 13735646   0 days 23:45:00
# 13735647   0 days 23:48:00
# Name: pickup_time, Length: 13735453, dtype: timedelta64[ns]
# user_gender       0
# user_age          0
# bike_id           0
# pickup_station    0
# pickup_date       0
# pickup_time       0
# return_station    0
# return_date       0
# return_time       0
# dtype: int64

# %%
#Convert the time column to datetime format
clean_eco_bici_df1['pickup_time']= pd.to_datetime(clean_eco_bici_df1['pickup_time'], format='%H:%M:%S', errors='coerce').dt.time
clean_eco_bici_df1['return_time']= pd.to_datetime(clean_eco_bici_df1['return_time'], format='%H:%M:%S', errors='coerce').dt.time

clean_eco_bici_df1
# Out:
#          user_gender  user_age  bike_id pickup_station pickup_date  \
# 0                  M      24.0  2252039            007  31/07/2023
# 1                  M      33.0  8626897            206  31/07/2023
# 2                  M      34.0  4940557            215  31/07/2023
# 3                  F      30.0  2036523            291  31/07/2023
# 4                  F      23.0  8079220            546  31/07/2023
# ...              ...       ...      ...            ...         ...
# 13735643           M      33.0  6683080            022  31/01/2024
# 13735644           M      28.0  2005171            150  31/01/2024
# 13735645           M      26.0  6842108            545  31/01/2024
# 13735646           M      53.0  5478714            007  31/01/2024
# 13735647           F      30.0  3046505            129  31/01/2024
#
#          pickup_time return_station return_date return_time
# 0           23:52:00            064  01/08/2023    00:00:00
# 1           23:48:00            212  01/08/2023    00:00:00
# 2           23:55:00            212  01/08/2023    00:00:00
# 3           23:32:00            082  01/08/2023    00:01:00
# 4           23:51:00            498  01/08/2023    00:01:00
# ...              ...            ...         ...         ...
# 13735643    23:47:00            041  31/01/2024    23:59:00
# 13735644    23:56:00            155  31/01/2024    23:59:00
# 13735645    23:48:00            115  31/01/2024    23:59:00
# 13735646    23:45:00            151  31/01/2024    23:59:00
# 13735647    23:48:00            072  31/01/2024    23:59:00
#
# [13735453 rows x 9 columns]

# %% [markdown]
# ### wrangling ecobici df and creating aggregated df

# %%
clean_eco_bici_df['pickup_date'] = pd.to_datetime(clean_eco_bici_df['pickup_date'], format='%d/%m/%Y', errors='coerce')
#clean_eco_bici_df['pickup_time'] = pd.to_datetime(clean_eco_bici_df['pickup_time'], format='%H:%M:%S', errors='coerce').dt.time
clean_eco_bici_df['return_date'] = pd.to_datetime(clean_eco_bici_df['return_date'], format='%d/%m/%Y', errors='coerce')
#clean_eco_bici_df['return_time'] = pd.to_datetime(clean_eco_bici_df['return_time'], format='%H:%M:%S', errors='coerce').dt.time
null_check(clean_eco_bici_df)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735643    0
# 13735644    0
# 13735645    0
# 13735646    0
# 13735647    0
# Length: 13735648, dtype: int64
#
# Total null values per column:
# user_gender         0
# user_age          195
# bike_id             0
# pickup_station      0
# pickup_date         0
# pickup_time         0
# return_station      0
# return_date         0
# return_time         0
# dtype: int64

# %%
clean_eco_bici_df= clean_eco_bici_df.dropna(subset=['pickup_date','return_date', 'user_age'])

# %%
clean_eco_bici_df['pickup_station'] = pd.to_numeric(clean_eco_bici_df['pickup_station'], errors='coerce')
clean_eco_bici_df['return_station'] = pd.to_numeric(clean_eco_bici_df['pickup_station'], errors='coerce')

# %%
# Concatenate 'pickup_date' and 'pickup_time' to create a new combined datetime column
clean_eco_bici_df['pickup_datetime'] = pd.to_datetime(clean_eco_bici_df['pickup_date'] + pd.to_timedelta(clean_eco_bici_df['pickup_time'].astype(str)))

# %%
clean_eco_bici_df['pickup_datetime'].dt.floor('H')
# Out:
# 0          2023-07-31 23:00:00
# 1          2023-07-31 23:00:00
# 2          2023-07-31 23:00:00
# 3          2023-07-31 23:00:00
# 4          2023-07-31 23:00:00
#                    ...
# 13735643   2024-01-31 23:00:00
# 13735644   2024-01-31 23:00:00
# 13735645   2024-01-31 23:00:00
# 13735646   2024-01-31 23:00:00
# 13735647   2024-01-31 23:00:00
# Name: pickup_datetime, Length: 13735453, dtype: datetime64[ns]

# %%
# Map the combined datetime to a new hourly datetime column
clean_eco_bici_df['hourly_aggregated'] = clean_eco_bici_df['pickup_datetime'].dt.floor('H')

# %%
# Calculate duration of the rental
clean_eco_bici_df['return_datetime'] = pd.to_datetime(clean_eco_bici_df['return_date'] + pd.to_timedelta(clean_eco_bici_df['return_time'].astype(str)))
clean_eco_bici_df['duration'] = clean_eco_bici_df['return_datetime'] - clean_eco_bici_df['pickup_datetime']

# %%
# identifying the individual pickup stations 
pickup_stations = clean_eco_bici_df.pickup_station.unique()
pickup_stations
# Out:
# array([7.000000e+00, 2.060000e+02, 2.150000e+02, 2.910000e+02,
#        5.460000e+02, 3.060000e+02, 6.500000e+01, 2.210000e+02,
#        3.940000e+02, 3.750000e+02, 7.400000e+01, 3.960000e+02,
#        1.360000e+02, 1.290000e+02, 2.830000e+02, 3.550000e+02,
#        1.200000e+01, 6.700000e+01, 1.870000e+02, 3.370000e+02,
#                 nan, 5.030000e+02, 2.200000e+02, 4.300000e+01,
#        7.300000e+01, 5.900000e+01, 2.260000e+02, 3.720000e+02,
#        3.400000e+02, 1.740000e+02, 1.620000e+02, 1.630000e+02,
#        4.490000e+02, 6.400000e+01, 3.000000e+01, 3.980000e+02,
#        1.480000e+02, 6.100000e+01, 1.210000e+02, 3.200000e+01,
#        2.950000e+02, 5.510000e+02, 1.890000e+02, 3.100000e+01,
#        2.500000e+01, 5.200000e+01, 9.900000e+01, 8.600000e+01,
#        4.000000e+01, 6.900000e+01, 1.550000e+02, 7.600000e+01,
#        1.230000e+02, 3.930000e+02, 5.300000e+01, 5.070000e+02,
#        4.690000e+02, 1.100000e+01, 3.000000e+02, 5.500000e+02,
#        3.200000e+02, 1.320000e+02, 2.940000e+02, 4.100000e+01,
#        4.220000e+02, 2.800000e+02, 3.150000e+02, 1.000000e+00,
#        3.780000e+02, 1.140000e+02, 2.810000e+02, 8.100000e+01,
#        1.420000e+02, 5.540000e+02, 2.900000e+02, 2.080000e+02,
#        2.580000e+02, 3.410000e+02, 1.500000e+01, 1.600000e+01,
#        4.470000e+02, 8.200000e+01, 1.030000e+02, 9.200000e+01,
#        6.000000e+01, 8.000000e+01, 1.110000e+02, 4.200000e+02,
#        2.340000e+02, 2.230000e+02, 1.800000e+01, 9.000000e+01,
#        2.400000e+01, 2.480000e+02, 1.350000e+02, 3.590000e+02,
#        2.300000e+01, 9.600000e+01, 4.620000e+02, 2.700000e+02,
#        7.000000e+01, 5.400000e+01, 1.330000e+02, 1.050000e+02,
#        4.500000e+02, 4.270000e+02, 8.700000e+01, 1.640000e+02,
#        2.600000e+02, 1.440000e+02, 1.830000e+02, 1.430000e+02,
#        4.440000e+02, 2.850000e+02, 3.250000e+02, 3.100000e+02,
#        4.120000e+02, 1.500000e+02, 1.000000e+01, 5.410000e+02,
#        3.600000e+01, 1.540000e+02, 2.630000e+02, 3.240000e+02,
#        2.780000e+02, 3.210000e+02, 8.500000e+01, 3.300000e+01,
#        3.660000e+02, 4.990000e+02, 1.600000e+02, 1.700000e+01,
#        1.710000e+02, 2.550000e+02, 1.790000e+02, 1.450000e+02,
#        4.800000e+02, 5.550000e+02, 3.290000e+02, 3.700000e+01,
#        1.470000e+02, 3.800000e+01, 1.510000e+02, 1.400000e+02,
#        7.700000e+01, 3.840000e+02, 5.040000e+02, 3.540000e+02,
#        2.000000e+00, 3.180000e+02, 3.000000e+00, 1.750000e+02,
#        4.900000e+01, 1.850000e+02, 2.440000e+02, 1.380000e+02,
#        4.010000e+02, 3.510000e+02, 1.410000e+02, 5.530000e+02,
#        5.500000e+01, 7.200000e+01, 4.530000e+02, 4.780000e+02,
#        4.090000e+02, 4.050000e+02, 3.080000e+02, 4.700000e+02,
#        1.940000e+02, 4.200000e+01, 4.640000e+02, 1.730000e+02,
#        1.370000e+02, 4.770000e+02, 8.400000e+01, 2.700000e+01,
#        1.220000e+02, 2.800000e+01, 1.560000e+02, 2.070000e+02,
#        2.760000e+02, 2.290000e+02, 4.300000e+02, 4.000000e+00,
#        1.390000e+02, 7.040000e+02, 2.980000e+02, 2.770000e+02,
#        4.390000e+02, 4.320000e+02, 3.650000e+02, 1.180000e+02,
#        6.670000e+02, 4.020000e+02, 3.520000e+02, 5.430000e+02,
#        3.740000e+02, 2.200000e+01, 2.250000e+02, 1.820000e+02,
#        1.660000e+02, 3.350000e+02, 5.490000e+02, 1.250000e+02,
#        4.650000e+02, 3.580000e+02, 4.850000e+02, 1.020000e+02,
#        1.810000e+02, 4.820000e+02, 2.000000e+02, 3.600000e+02,
#        5.360000e+02, 2.110000e+02, 3.470000e+02, 2.560000e+02,
#        4.920000e+02, 1.310000e+02, 5.100000e+01, 3.020000e+02,
#        1.120000e+02, 9.000000e+00, 1.520000e+02, 1.720000e+02,
#        1.260000e+02, 3.050000e+02, 1.610000e+02, 1.340000e+02,
#        4.600000e+01, 2.040000e+02, 3.990000e+02, 4.600000e+02,
#        1.690000e+02, 3.170000e+02, 1.160000e+02, 2.960000e+02,
#        2.460000e+02, 2.000000e+01, 2.530000e+02, 3.610000e+02,
#        4.760000e+02, 1.040000e+02, 4.950000e+02, 2.510000e+02,
#        3.230000e+02, 3.900000e+01, 4.040000e+02, 2.880000e+02,
#        7.100000e+01, 1.240000e+02, 2.860000e+02, 3.560000e+02,
#        6.690000e+02, 4.960000e+02, 5.060000e+02, 4.830000e+02,
#        3.400000e+01, 2.170000e+02, 1.400000e+01, 2.490000e+02,
#        2.930000e+02, 3.690000e+02, 1.190000e+02, 6.700000e+02,
#        3.810000e+02, 6.000000e+00, 1.950000e+02, 2.470000e+02,
#        4.660000e+02, 3.130000e+02, 4.970000e+02, 2.050000e+02,
#        1.170000e+02, 3.800000e+02, 4.190000e+02, 4.670000e+02,
#        2.970000e+02, 6.570000e+02, 2.310000e+02, 4.230000e+02,
#        2.320000e+02, 7.900000e+01, 5.000000e+00, 2.140000e+02,
#        1.700000e+02, 9.700000e+01, 2.500000e+02, 1.100000e+02,
#        3.850000e+02, 2.820000e+02, 4.800000e+01, 1.200000e+02,
#        1.880000e+02, 6.600000e+01, 2.430000e+02, 3.270000e+02,
#        4.140000e+02, 3.430000e+02, 3.280000e+02, 2.590000e+02,
#        3.670000e+02, 2.540000e+02, 2.570000e+02, 2.870000e+02,
#        1.900000e+02, 2.120000e+02, 9.800000e+01, 3.870000e+02,
#        1.650000e+02, 1.490000e+02, 2.650000e+02, 9.100000e+01,
#        3.950000e+02, 1.270000e+02, 6.800000e+01, 3.010000e+02,
#        3.480000e+02, 3.360000e+02, 2.010000e+02, 4.340000e+02,
#        3.770000e+02, 4.740000e+02, 2.100000e+02, 1.530000e+02,
#        2.990000e+02, 1.460000e+02, 1.840000e+02, 1.150000e+02,
#        4.280000e+02, 3.300000e+02, 4.520000e+02, 6.200000e+01,
#        5.450000e+02, 4.710000e+02, 4.910000e+02, 6.580000e+02,
#        4.810000e+02, 7.500000e+01, 1.860000e+02, 3.310000e+02,
#        1.800000e+02, 4.240000e+02, 4.590000e+02, 7.060000e+02,
#        8.000000e+00, 4.700000e+01, 5.600000e+01, 2.190000e+02,
#        2.030000e+02, 3.140000e+02, 4.290000e+02, 2.280000e+02,
#        3.330000e+02, 3.260000e+02, 4.480000e+02, 1.780000e+02,
#        3.120000e+02, 5.520000e+02, 2.180000e+02, 5.400000e+02,
#        4.130000e+02, 3.730000e+02, 6.300000e+01, 4.370000e+02,
#        6.680000e+02, 3.920000e+02, 4.150000e+02, 4.070000e+02,
#        2.900000e+01, 1.680000e+02, 2.330000e+02, 6.730000e+02,
#        3.380000e+02, 2.090000e+02, 8.300000e+01, 5.000000e+01,
#        4.380000e+02, 9.300000e+01, 3.320000e+02, 4.720000e+02,
#        2.420000e+02, 2.600000e+01, 4.330000e+02, 3.620000e+02,
#        2.790000e+02, 1.300000e+02, 3.890000e+02, 4.750000e+02,
#        3.340000e+02, 1.960000e+02, 4.860000e+02, 4.550000e+02,
#        1.130000e+02, 1.570000e+02, 3.220000e+02, 4.730000e+02,
#        5.700000e+01, 3.860000e+02, 7.030000e+02, 3.390000e+02,
#        7.090000e+02, 3.710000e+02, 7.800000e+01, 1.280000e+02,
#        2.270000e+02, 2.410000e+02, 3.630000e+02, 3.420000e+02,
#        4.580000e+02, 4.170000e+02, 4.500000e+01, 3.700000e+02,
#        5.800000e+01, 4.610000e+02, 3.500000e+01, 3.490000e+02,
#        5.020000e+02, 1.000000e+02, 2.840000e+02, 1.670000e+02,
#        6.590000e+02, 2.390000e+02, 4.210000e+02, 4.400000e+01,
#        2.620000e+02, 3.160000e+02, 4.790000e+02, 2.920000e+02,
#        4.570000e+02, 4.540000e+02, 3.070000e+02, 6.560000e+02,
#        3.190000e+02, 3.570000e+02, 6.600000e+02, 4.980000e+02,
#        1.990000e+02, 2.450000e+02, 3.040000e+02, 1.090000e+02,
#        1.980000e+02, 2.300000e+02, 1.770000e+02, 2.240000e+02,
#        3.450000e+02, 3.090000e+02, 1.900000e+01, 1.910000e+02,
#        2.160000e+02, 2.520000e+02, 4.510000e+02, 5.370000e+02,
#        3.530000e+02, 2.100000e+01, 6.720000e+02, 1.760000e+02,
#        3.970000e+02, 4.160000e+02, 3.460000e+02, 2.020000e+02,
#        4.360000e+02, 2.220000e+02, 2.610000e+02, 1.300000e+01,
#        2.400000e+02, 4.410000e+02, 2.130000e+02, 4.430000e+02,
#        9.400000e+01, 4.250000e+02, 4.680000e+02, 7.020000e+02,
#        8.900000e+01, 8.800000e+01, 9.500000e+01, 4.560000e+02,
#        7.080000e+02, 3.030000e+02, 4.420000e+02, 7.000000e+02,
#        1.000000e+03, 6.260000e+02, 6.960000e+02, 6.150000e+02,
#        5.970000e+02, 6.940000e+02, 6.300000e+02, 6.170000e+02,
#        6.910000e+02, 6.890000e+02, 6.920000e+02, 7.010000e+02,
#        6.180000e+02, 6.120000e+02, 6.610000e+02, 6.520000e+02,
#        6.880000e+02, 6.290000e+02, 6.510000e+02, 6.490000e+02,
#        6.020000e+02, 6.240000e+02, 6.110000e+02, 6.370000e+02,
#        6.390000e+02, 6.330000e+02, 5.920000e+02, 6.190000e+02,
#        6.230000e+02, 6.200000e+02, 5.620000e+02, 5.590000e+02,
#        6.340000e+02, 5.890000e+02, 5.600000e+02, 5.790000e+02,
#        5.680000e+02, 5.640000e+02, 5.770000e+02, 6.090000e+02,
#        5.670000e+02, 6.040000e+02, 4.940000e+02, 5.730000e+02,
#        5.010000e+02, 5.710000e+02, 5.800000e+02, 5.690000e+02,
#        6.430000e+02, 6.030000e+02, 5.780000e+02, 6.450000e+02,
#        5.630000e+02, 6.970000e+02, 5.750000e+02, 5.900000e+02,
#        5.560000e+02, 5.840000e+02, 4.630000e+02, 6.500000e+02,
#        6.790000e+02, 6.780000e+02, 6.640000e+02, 6.660000e+02,
#        6.630000e+02, 6.620000e+02, 6.860000e+02, 5.250000e+02,
#        5.270000e+02, 5.210000e+02, 5.190000e+02, 5.180000e+02,
#        5.170000e+02, 5.160000e+02, 5.310000e+02, 5.140000e+02,
#        6.550000e+02, 6.840000e+02, 6.650000e+02, 6.350000e+02,
#        6.130000e+02, 6.310000e+02, 5.940000e+02, 6.280000e+02,
#        5.570000e+02, 6.870000e+02, 5.120000e+02, 5.100000e+02,
#        5.480000e+02, 6.080000e+02, 5.390000e+02, 6.220000e+02,
#        6.420000e+02, 4.422222e+06, 5.950000e+02, 5.850000e+02,
#        5.610000e+02, 6.360000e+02, 5.960000e+02, 6.210000e+02,
#        5.980000e+02, 6.980000e+02, 6.070000e+02, 6.850000e+02,
#        6.990000e+02, 6.710000e+02, 5.420000e+02, 6.100000e+02,
#        4.930000e+02, 5.000000e+02, 5.830000e+02, 5.990000e+02,
#        6.440000e+02, 5.720000e+02, 5.910000e+02, 6.010000e+02,
#        6.950000e+02, 6.400000e+02, 4.840000e+02, 5.930000e+02,
#        4.900000e+02, 5.440000e+02, 1.060000e+02, 7.070000e+02,
#        6.930000e+02, 5.380000e+02, 4.870000e+02, 6.540000e+02,
#        6.480000e+02, 5.700000e+02, 6.740000e+02, 6.050000e+02,
#        6.530000e+02, 7.050000e+02, 6.000000e+02, 6.380000e+02,
#        5.050000e+02, 6.900000e+02, 6.270000e+02, 6.410000e+02,
#        6.460000e+02, 5.580000e+02, 5.760000e+02, 6.320000e+02,
#        1.970000e+02, 4.890000e+02, 6.140000e+02, 5.650000e+02,
#        5.660000e+02, 6.250000e+02, 5.810000e+02, 6.160000e+02,
#        5.860000e+02, 5.870000e+02, 5.740000e+02, 5.350000e+02,
#        5.820000e+02, 6.830000e+02, 4.880000e+02, 6.060000e+02,
#        5.470000e+02, 5.260000e+02, 5.230000e+02, 5.220000e+02,
#        5.280000e+02])

# %%
stations_df = pd.DataFrame(clean_eco_bici_df.pickup_station.value_counts()).reset_index()
stations_df.head(50)
# station 64, 27, 1, 43, 18 and 14 have highest pickup counts
# Out:
#     pickup_station   count
# 0             64.0  105806
# 1             27.0  104188
# 2              1.0   79356
# 3             43.0   76390
# 4             18.0   75612
# 5             14.0   73013
# 6             28.0   69840
# 7             53.0   69565
# 8            208.0   68858
# 9             72.0   65846
# 10            41.0   65605
# 11            29.0   65153
# 12           194.0   65138
# 13             7.0   64108
# 14            31.0   64083
# 15            74.0   63572
# 16            19.0   62505
# 17            38.0   62118
# 18            56.0   61897
# 19            17.0   61291
# 20           242.0   60809
# 21            10.0   60467
# 22           174.0   60378
# 23            52.0   60130
# 24            30.0   59958
# 25           134.0   59720
# 26            32.0   57886
# 27            15.0   57691
# 28           150.0   56535
# 29            70.0   56386
# 30            36.0   56266
# 31            16.0   55946
# 32           195.0   54936
# 33           555.0   54384
# 34            47.0   54296
# 35            25.0   53647
# 36           111.0   53397
# 37           139.0   52453
# 38            59.0   51564
# 39           141.0   51349
# 40            46.0   51097
# 41           182.0   49716
# 42            37.0   49151
# 43             6.0   49037
# 44           116.0   48824
# 45           136.0   47775
# 46            20.0   47594
# 47            86.0   47035
# 48            66.0   46902
# 49            45.0   46479

# %%
clean_eco_bici_df[clean_eco_bici_df['pickup_station'].isin([6])]
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 523                M      29.0  4481933             6.0  2023-08-01
# 524                F      24.0  2304590             6.0  2023-08-01
# 646                M      36.0  7402217             6.0  2023-08-01
# 1675               M      28.0  8500951             6.0  2023-08-01
# 2189               F      36.0  3836327             6.0  2023-08-01
# ...              ...       ...      ...             ...         ...
# 13734374           F      33.0  3026184             6.0  2024-01-31
# 13734654           M      32.0  4277828             6.0  2024-01-31
# 13734931           F      29.0  6510093             6.0  2024-01-31
# 13734940           M      41.0  5299292             6.0  2024-01-31
# 13735001           M      33.0  8081168             6.0  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 523         06:10:08             6.0  2023-08-01    06:16:20
# 524         06:09:50             6.0  2023-08-01    06:16:21
# 646         06:20:56             6.0  2023-08-01    06:30:00
# 1675        07:06:22             6.0  2023-08-01    07:16:44
# 2189        07:16:12             6.0  2023-08-01    07:35:47
# ...              ...             ...         ...         ...
# 13734374    22:30:28             6.0  2024-01-31    22:48:18
# 13734654    22:51:46             6.0  2024-01-31    23:00:27
# 13734931    23:09:35             6.0  2024-01-31    23:15:34
# 13734940    22:31:46             6.0  2024-01-31    23:15:57
# 13735001    22:43:10             6.0  2024-01-31    23:18:46
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 523      2023-08-01 06:10:08 2023-08-01 06:00:00 2023-08-01 06:16:20
# 524      2023-08-01 06:09:50 2023-08-01 06:00:00 2023-08-01 06:16:21
# 646      2023-08-01 06:20:56 2023-08-01 06:00:00 2023-08-01 06:30:00
# 1675     2023-08-01 07:06:22 2023-08-01 07:00:00 2023-08-01 07:16:44
# 2189     2023-08-01 07:16:12 2023-08-01 07:00:00 2023-08-01 07:35:47
# ...                      ...                 ...                 ...
# 13734374 2024-01-31 22:30:28 2024-01-31 22:00:00 2024-01-31 22:48:18
# 13734654 2024-01-31 22:51:46 2024-01-31 22:00:00 2024-01-31 23:00:27
# 13734931 2024-01-31 23:09:35 2024-01-31 23:00:00 2024-01-31 23:15:34
# 13734940 2024-01-31 22:31:46 2024-01-31 22:00:00 2024-01-31 23:15:57
# 13735001 2024-01-31 22:43:10 2024-01-31 22:00:00 2024-01-31 23:18:46
#
#                 duration
# 523      0 days 00:06:12
# 524      0 days 00:06:31
# 646      0 days 00:09:04
# 1675     0 days 00:10:22
# 2189     0 days 00:19:35
# ...                  ...
# 13734374 0 days 00:17:50
# 13734654 0 days 00:08:41
# 13734931 0 days 00:05:59
# 13734940 0 days 00:44:11
# 13735001 0 days 00:35:36
#
# [49037 rows x 13 columns]

# %% [markdown]
# <b> Adding a feature indicating whether the day of rental was a business day or not</b>

# %%
# Map the hourly_aggregated to a new column indicating business day [1] or weekend/holiday [0]

# Public holidays in Mexico City:

public_holidays = [ # month and day
    '01-01', # new year's day
    '02-05', # consistution day
    '03-21', # Benito Juárez's Birthday
    '05-01', # Labour day
    '09-16', # Independence day
    '11-20', # Revolution day
    '12-25', # Christmas
]

# convert public_holidays to datetime format
public_holidays_dt = [datetime.strptime(holiday, '%m-%d') for holiday in public_holidays]

# use apply function to check whether datetime in 'hourly_aggregated' is a public holiday or weekend
clean_eco_bici_df['is_business_day'] = clean_eco_bici_df['hourly_aggregated'].apply(
    lambda x: 1 if (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] and (x.weekday() < 5) else 0
)

clean_eco_bici_df
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 0                  M      24.0  2252039             7.0  2023-07-31
# 1                  M      33.0  8626897           206.0  2023-07-31
# 2                  M      34.0  4940557           215.0  2023-07-31
# 3                  F      30.0  2036523           291.0  2023-07-31
# 4                  F      23.0  8079220           546.0  2023-07-31
# ...              ...       ...      ...             ...         ...
# 13735643           M      33.0  6683080            22.0  2024-01-31
# 13735644           M      28.0  2005171           150.0  2024-01-31
# 13735645           M      26.0  6842108           545.0  2024-01-31
# 13735646           M      53.0  5478714             7.0  2024-01-31
# 13735647           F      30.0  3046505           129.0  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 0           23:52:38             7.0  2023-08-01    00:00:03
# 1           23:48:01           206.0  2023-08-01    00:00:20
# 2           23:55:50           215.0  2023-08-01    00:00:30
# 3           23:32:42           291.0  2023-08-01    00:01:08
# 4           23:51:09           546.0  2023-08-01    00:01:21
# ...              ...             ...         ...         ...
# 13735643    23:47:55            22.0  2024-01-31    23:59:41
# 13735644    23:56:03           150.0  2024-01-31    23:59:53
# 13735645    23:48:34           545.0  2024-01-31    23:59:56
# 13735646    23:45:28             7.0  2024-01-31    23:59:58
# 13735647    23:48:47           129.0  2024-01-31    23:59:59
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 0        2023-07-31 23:52:38 2023-07-31 23:00:00 2023-08-01 00:00:03
# 1        2023-07-31 23:48:01 2023-07-31 23:00:00 2023-08-01 00:00:20
# 2        2023-07-31 23:55:50 2023-07-31 23:00:00 2023-08-01 00:00:30
# 3        2023-07-31 23:32:42 2023-07-31 23:00:00 2023-08-01 00:01:08
# 4        2023-07-31 23:51:09 2023-07-31 23:00:00 2023-08-01 00:01:21
# ...                      ...                 ...                 ...
# 13735643 2024-01-31 23:47:55 2024-01-31 23:00:00 2024-01-31 23:59:41
# 13735644 2024-01-31 23:56:03 2024-01-31 23:00:00 2024-01-31 23:59:53
# 13735645 2024-01-31 23:48:34 2024-01-31 23:00:00 2024-01-31 23:59:56
# 13735646 2024-01-31 23:45:28 2024-01-31 23:00:00 2024-01-31 23:59:58
# 13735647 2024-01-31 23:48:47 2024-01-31 23:00:00 2024-01-31 23:59:59
#
#                 duration  is_business_day
# 0        0 days 00:07:25                1
# 1        0 days 00:12:19                1
# 2        0 days 00:04:40                1
# 3        0 days 00:28:26                1
# 4        0 days 00:10:12                1
# ...                  ...              ...
# 13735643 0 days 00:11:46                1
# 13735644 0 days 00:03:50                1
# 13735645 0 days 00:11:22                1
# 13735646 0 days 00:14:30                1
# 13735647 0 days 00:11:12                1
#
# [13735453 rows x 14 columns]

# %%
clean_eco_bici_df = clean_eco_bici_df.sort_values(by='pickup_datetime')
clean_eco_bici_df.reset_index(drop=True, inplace=True)

# %%
clean_eco_bici_df = clean_eco_bici_df.dropna(subset=['pickup_station','return_station'])

# %%
null_check(clean_eco_bici_df)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735448    0
# 13735449    0
# 13735450    0
# 13735451    0
# 13735452    0
# Length: 13047307, dtype: int64
#
# Total null values per column:
# user_gender          0
# user_age             0
# bike_id              0
# pickup_station       0
# pickup_date          0
# pickup_time          0
# return_station       0
# return_date          0
# return_time          0
# pickup_datetime      0
# hourly_aggregated    0
# return_datetime      0
# duration             0
# is_business_day      0
# dtype: int64

# %%
# Define columns to convert to integers
columns_to_convert = ['user_age', 'pickup_station', 'return_station']

# Convert specified columns to integers
clean_eco_bici_df[columns_to_convert] = clean_eco_bici_df[columns_to_convert].astype(int)

data_frame_overview(clean_eco_bici_df)
# Out:
# Column names:
#  Index(['user_gender', 'user_age', 'bike_id', 'pickup_station', 'pickup_date',
#        'pickup_time', 'return_station', 'return_date', 'return_time',
#        'pickup_datetime', 'hourly_aggregated', 'return_datetime', 'duration',
#        'is_business_day'],
#       dtype='object')
#
# Dimensions: (13047307, 14)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 13047307 entries, 0 to 13735452
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_gender        object
#  1   user_age           int64
#  2   bike_id            int64
#  3   pickup_station     int64
#  4   pickup_date        datetime64[ns]
#  5   pickup_time        object
#  6   return_station     int64
#  7   return_date        datetime64[ns]
#  8   return_time        object
#  9   pickup_datetime    datetime64[ns]
#  10  hourly_aggregated  datetime64[ns]
#  11  return_datetime    datetime64[ns]
#  12  duration           timedelta64[ns]
#  13  is_business_day    int64
# dtypes: datetime64[ns](5), int64(5), object(3), timedelta64[ns](1)
# memory usage: 1.5+ GB
# None
#   user_gender  user_age  bike_id  pickup_station pickup_date    pickup_time  \
# 0           M        35  8908451              81  2022-09-03  18:45:42.3370
# 1   undefined        29  5380423              56  2022-09-30       12:24:36
# 2   undefined        32  5218094              56  2022-09-30  13:17:30.6120
# 3   undefined        25  7278658              56  2022-09-30  13:20:09.0510
# 4           M        48  4031258              22  2022-11-10  21:26:19.3790
# 5           F        30  3561073             287  2022-11-13  19:23:04.5660
# 6           M        29  8938029             302  2022-11-15       16:52:21
# 7           M        43  8296352              19  2022-11-18  21:11:36.3090
# 8           F        37  6537930             116  2022-11-28  15:07:47.0830
# 9           M        54  2502870             131  2022-12-04  13:04:07.8950
#
#    return_station return_date    return_time         pickup_datetime  \
# 0              81  2023-02-02  19:09:36.7840 2022-09-03 18:45:42.337
# 1              56  2023-11-24       15:13:34 2022-09-30 12:24:36.000
# 2              56  2023-02-09  13:14:13.9300 2022-09-30 13:17:30.612
# 3              56  2023-02-09  13:11:41.3290 2022-09-30 13:20:09.051
# 4              22  2023-02-02  19:11:23.2350 2022-11-10 21:26:19.379
# 5             287  2023-02-17  12:08:38.0860 2022-11-13 19:23:04.566
# 6             302  2023-03-06       20:20:00 2022-11-15 16:52:21.000
# 7              19  2023-01-17  17:17:07.2610 2022-11-18 21:11:36.309
# 8             116  2023-01-26  16:18:13.7580 2022-11-28 15:07:47.083
# 9             131  2023-01-17  17:40:14.5700 2022-12-04 13:04:07.895
#
#     hourly_aggregated         return_datetime                 duration  \
# 0 2022-09-03 18:00:00 2023-02-02 19:09:36.784 152 days 00:23:54.447000
# 1 2022-09-30 12:00:00 2023-11-24 15:13:34.000        420 days 02:48:58
# 2 2022-09-30 13:00:00 2023-02-09 13:14:13.930 131 days 23:56:43.318000
# 3 2022-09-30 13:00:00 2023-02-09 13:11:41.329 131 days 23:51:32.278000
# 4 2022-11-10 21:00:00 2023-02-02 19:11:23.235  83 days 21:45:03.856000
# 5 2022-11-13 19:00:00 2023-02-17 12:08:38.086  95 days 16:45:33.520000
# 6 2022-11-15 16:00:00 2023-03-06 20:20:00.000        111 days 03:27:39
# 7 2022-11-18 21:00:00 2023-01-17 17:17:07.261  59 days 20:05:30.952000
# 8 2022-11-28 15:00:00 2023-01-26 16:18:13.758  59 days 01:10:26.675000
# 9 2022-12-04 13:00:00 2023-01-17 17:40:14.570  44 days 04:36:06.675000
#
#    is_business_day
# 0                0
# 1                1
# 2                1
# 3                1
# 4                1
# 5                0
# 6                1
# 7                1
# 8                1
# 9                0

# %% [markdown]
# <b>Split dataset into individual dataframes per bike station</b>

# %%
# saving each individual dataframe into a dictionary, where station number is key and df is value
# access each df later by calling the station number as value in the dict, e.g. stations_dict['station_number']

stations_dict = {}

for station in pickup_stations: 
    stations_dict[station] = clean_eco_bici_df[(clean_eco_bici_df['pickup_station']==station)]
    print(f"Dataframe for station {station} was created.")
print(f"Number of new dataframes: {len(stations_dict)}")
# Out:
# Dataframe for station 7.0 was created.
# Dataframe for station 206.0 was created.
# Dataframe for station 215.0 was created.
# Dataframe for station 291.0 was created.
# Dataframe for station 546.0 was created.
# Dataframe for station 306.0 was created.
# Dataframe for station 65.0 was created.
# Dataframe for station 221.0 was created.
# Dataframe for station 394.0 was created.
# Dataframe for station 375.0 was created.
# Dataframe for station 74.0 was created.
# Dataframe for station 396.0 was created.
# Dataframe for station 136.0 was created.
# Dataframe for station 129.0 was created.
# Dataframe for station 283.0 was created.
# Dataframe for station 355.0 was created.
# Dataframe for station 12.0 was created.
# Dataframe for station 67.0 was created.
# Dataframe for station 187.0 was created.
# Dataframe for station 337.0 was created.
# Dataframe for station nan was created.
# Dataframe for station 503.0 was created.
# Dataframe for station 220.0 was created.
# Dataframe for station 43.0 was created.
# Dataframe for station 73.0 was created.
# Dataframe for station 59.0 was created.
# Dataframe for station 226.0 was created.
# Dataframe for station 372.0 was created.
# Dataframe for station 340.0 was created.
# Dataframe for station 174.0 was created.
# Dataframe for station 162.0 was created.
# Dataframe for station 163.0 was created.
# Dataframe for station 449.0 was created.
# Dataframe for station 64.0 was created.
# Dataframe for station 30.0 was created.
# Dataframe for station 398.0 was created.
# Dataframe for station 148.0 was created.
# Dataframe for station 61.0 was created.
# Dataframe for station 121.0 was created.
# Dataframe for station 32.0 was created.
# Dataframe for station 295.0 was created.
# Dataframe for station 551.0 was created.
# Dataframe for station 189.0 was created.
# Dataframe for station 31.0 was created.
# Dataframe for station 25.0 was created.
# Dataframe for station 52.0 was created.
# Dataframe for station 99.0 was created.
# Dataframe for station 86.0 was created.
# Dataframe for station 40.0 was created.
# Dataframe for station 69.0 was created.
# Dataframe for station 155.0 was created.
# Dataframe for station 76.0 was created.
# Dataframe for station 123.0 was created.
# Dataframe for station 393.0 was created.
# Dataframe for station 53.0 was created.
# Dataframe for station 507.0 was created.
# Dataframe for station 469.0 was created.
# Dataframe for station 11.0 was created.
# Dataframe for station 300.0 was created.
# Dataframe for station 550.0 was created.
# Dataframe for station 320.0 was created.
# Dataframe for station 132.0 was created.
# Dataframe for station 294.0 was created.
# Dataframe for station 41.0 was created.
# Dataframe for station 422.0 was created.
# Dataframe for station 280.0 was created.
# Dataframe for station 315.0 was created.
# Dataframe for station 1.0 was created.
# Dataframe for station 378.0 was created.
# Dataframe for station 114.0 was created.
# Dataframe for station 281.0 was created.
# Dataframe for station 81.0 was created.
# Dataframe for station 142.0 was created.
# Dataframe for station 554.0 was created.
# Dataframe for station 290.0 was created.
# Dataframe for station 208.0 was created.
# Dataframe for station 258.0 was created.
# Dataframe for station 341.0 was created.
# Dataframe for station 15.0 was created.
# Dataframe for station 16.0 was created.
# Dataframe for station 447.0 was created.
# Dataframe for station 82.0 was created.
# Dataframe for station 103.0 was created.
# Dataframe for station 92.0 was created.
# Dataframe for station 60.0 was created.
# Dataframe for station 80.0 was created.
# Dataframe for station 111.0 was created.
# Dataframe for station 420.0 was created.
# Dataframe for station 234.0 was created.
# Dataframe for station 223.0 was created.
# Dataframe for station 18.0 was created.
# Dataframe for station 90.0 was created.
# Dataframe for station 24.0 was created.
# Dataframe for station 248.0 was created.
# Dataframe for station 135.0 was created.
# Dataframe for station 359.0 was created.
# Dataframe for station 23.0 was created.
# Dataframe for station 96.0 was created.
# Dataframe for station 462.0 was created.
# Dataframe for station 270.0 was created.
# Dataframe for station 70.0 was created.
# Dataframe for station 54.0 was created.
# Dataframe for station 133.0 was created.
# Dataframe for station 105.0 was created.
# Dataframe for station 450.0 was created.
# Dataframe for station 427.0 was created.
# Dataframe for station 87.0 was created.
# Dataframe for station 164.0 was created.
# Dataframe for station 260.0 was created.
# Dataframe for station 144.0 was created.
# Dataframe for station 183.0 was created.
# Dataframe for station 143.0 was created.
# Dataframe for station 444.0 was created.
# Dataframe for station 285.0 was created.
# Dataframe for station 325.0 was created.
# Dataframe for station 310.0 was created.
# Dataframe for station 412.0 was created.
# Dataframe for station 150.0 was created.
# Dataframe for station 10.0 was created.
# Dataframe for station 541.0 was created.
# Dataframe for station 36.0 was created.
# Dataframe for station 154.0 was created.
# Dataframe for station 263.0 was created.
# Dataframe for station 324.0 was created.
# Dataframe for station 278.0 was created.
# Dataframe for station 321.0 was created.
# Dataframe for station 85.0 was created.
# Dataframe for station 33.0 was created.
# Dataframe for station 366.0 was created.
# Dataframe for station 499.0 was created.
# Dataframe for station 160.0 was created.
# Dataframe for station 17.0 was created.
# Dataframe for station 171.0 was created.
# Dataframe for station 255.0 was created.
# Dataframe for station 179.0 was created.
# Dataframe for station 145.0 was created.
# Dataframe for station 480.0 was created.
# Dataframe for station 555.0 was created.
# Dataframe for station 329.0 was created.
# Dataframe for station 37.0 was created.
# Dataframe for station 147.0 was created.
# Dataframe for station 38.0 was created.
# Dataframe for station 151.0 was created.
# Dataframe for station 140.0 was created.
# Dataframe for station 77.0 was created.
# Dataframe for station 384.0 was created.
# Dataframe for station 504.0 was created.
# Dataframe for station 354.0 was created.
# Dataframe for station 2.0 was created.
# Dataframe for station 318.0 was created.
# Dataframe for station 3.0 was created.
# Dataframe for station 175.0 was created.
# Dataframe for station 49.0 was created.
# Dataframe for station 185.0 was created.
# Dataframe for station 244.0 was created.
# Dataframe for station 138.0 was created.
# Dataframe for station 401.0 was created.
# Dataframe for station 351.0 was created.
# Dataframe for station 141.0 was created.
# Dataframe for station 553.0 was created.
# Dataframe for station 55.0 was created.
# Dataframe for station 72.0 was created.
# Dataframe for station 453.0 was created.
# Dataframe for station 478.0 was created.
# Dataframe for station 409.0 was created.
# Dataframe for station 405.0 was created.
# Dataframe for station 308.0 was created.
# Dataframe for station 470.0 was created.
# Dataframe for station 194.0 was created.
# Dataframe for station 42.0 was created.
# Dataframe for station 464.0 was created.
# Dataframe for station 173.0 was created.
# Dataframe for station 137.0 was created.
# Dataframe for station 477.0 was created.
# Dataframe for station 84.0 was created.
# Dataframe for station 27.0 was created.
# Dataframe for station 122.0 was created.
# Dataframe for station 28.0 was created.
# Dataframe for station 156.0 was created.
# Dataframe for station 207.0 was created.
# Dataframe for station 276.0 was created.
# Dataframe for station 229.0 was created.
# Dataframe for station 430.0 was created.
# Dataframe for station 4.0 was created.
# Dataframe for station 139.0 was created.
# Dataframe for station 704.0 was created.
# Dataframe for station 298.0 was created.
# Dataframe for station 277.0 was created.
# Dataframe for station 439.0 was created.
# Dataframe for station 432.0 was created.
# Dataframe for station 365.0 was created.
# Dataframe for station 118.0 was created.
# Dataframe for station 667.0 was created.
# Dataframe for station 402.0 was created.
# Dataframe for station 352.0 was created.
# Dataframe for station 543.0 was created.
# Dataframe for station 374.0 was created.
# Dataframe for station 22.0 was created.
# Dataframe for station 225.0 was created.
# Dataframe for station 182.0 was created.
# Dataframe for station 166.0 was created.
# Dataframe for station 335.0 was created.
# Dataframe for station 549.0 was created.
# Dataframe for station 125.0 was created.
# Dataframe for station 465.0 was created.
# Dataframe for station 358.0 was created.
# Dataframe for station 485.0 was created.
# Dataframe for station 102.0 was created.
# Dataframe for station 181.0 was created.
# Dataframe for station 482.0 was created.
# Dataframe for station 200.0 was created.
# Dataframe for station 360.0 was created.
# Dataframe for station 536.0 was created.
# Dataframe for station 211.0 was created.
# Dataframe for station 347.0 was created.
# Dataframe for station 256.0 was created.
# Dataframe for station 492.0 was created.
# Dataframe for station 131.0 was created.
# Dataframe for station 51.0 was created.
# Dataframe for station 302.0 was created.
# Dataframe for station 112.0 was created.
# Dataframe for station 9.0 was created.
# Dataframe for station 152.0 was created.
# Dataframe for station 172.0 was created.
# Dataframe for station 126.0 was created.
# Dataframe for station 305.0 was created.
# Dataframe for station 161.0 was created.
# Dataframe for station 134.0 was created.
# Dataframe for station 46.0 was created.
# Dataframe for station 204.0 was created.
# Dataframe for station 399.0 was created.
# Dataframe for station 460.0 was created.
# Dataframe for station 169.0 was created.
# Dataframe for station 317.0 was created.
# Dataframe for station 116.0 was created.
# Dataframe for station 296.0 was created.
# Dataframe for station 246.0 was created.
# Dataframe for station 20.0 was created.
# Dataframe for station 253.0 was created.
# Dataframe for station 361.0 was created.
# Dataframe for station 476.0 was created.
# Dataframe for station 104.0 was created.
# Dataframe for station 495.0 was created.
# Dataframe for station 251.0 was created.
# Dataframe for station 323.0 was created.
# Dataframe for station 39.0 was created.
# Dataframe for station 404.0 was created.
# Dataframe for station 288.0 was created.
# Dataframe for station 71.0 was created.
# Dataframe for station 124.0 was created.
# Dataframe for station 286.0 was created.
# Dataframe for station 356.0 was created.
# Dataframe for station 669.0 was created.
# Dataframe for station 496.0 was created.
# Dataframe for station 506.0 was created.
# Dataframe for station 483.0 was created.
# Dataframe for station 34.0 was created.
# Dataframe for station 217.0 was created.
# Dataframe for station 14.0 was created.
# Dataframe for station 249.0 was created.
# Dataframe for station 293.0 was created.
# Dataframe for station 369.0 was created.
# Dataframe for station 119.0 was created.
# Dataframe for station 670.0 was created.
# Dataframe for station 381.0 was created.
# Dataframe for station 6.0 was created.
# Dataframe for station 195.0 was created.
# Dataframe for station 247.0 was created.
# Dataframe for station 466.0 was created.
# Dataframe for station 313.0 was created.
# Dataframe for station 497.0 was created.
# Dataframe for station 205.0 was created.
# Dataframe for station 117.0 was created.
# Dataframe for station 380.0 was created.
# Dataframe for station 419.0 was created.
# Dataframe for station 467.0 was created.
# Dataframe for station 297.0 was created.
# Dataframe for station 657.0 was created.
# Dataframe for station 231.0 was created.
# Dataframe for station 423.0 was created.
# Dataframe for station 232.0 was created.
# Dataframe for station 79.0 was created.
# Dataframe for station 5.0 was created.
# Dataframe for station 214.0 was created.
# Dataframe for station 170.0 was created.
# Dataframe for station 97.0 was created.
# Dataframe for station 250.0 was created.
# Dataframe for station 110.0 was created.
# Dataframe for station 385.0 was created.
# Dataframe for station 282.0 was created.
# Dataframe for station 48.0 was created.
# Dataframe for station 120.0 was created.
# Dataframe for station 188.0 was created.
# Dataframe for station 66.0 was created.
# Dataframe for station 243.0 was created.
# Dataframe for station 327.0 was created.
# Dataframe for station 414.0 was created.
# Dataframe for station 343.0 was created.
# Dataframe for station 328.0 was created.
# Dataframe for station 259.0 was created.
# Dataframe for station 367.0 was created.
# Dataframe for station 254.0 was created.
# Dataframe for station 257.0 was created.
# Dataframe for station 287.0 was created.
# Dataframe for station 190.0 was created.
# Dataframe for station 212.0 was created.
# Dataframe for station 98.0 was created.
# Dataframe for station 387.0 was created.
# Dataframe for station 165.0 was created.
# Dataframe for station 149.0 was created.
# Dataframe for station 265.0 was created.
# Dataframe for station 91.0 was created.
# Dataframe for station 395.0 was created.
# Dataframe for station 127.0 was created.
# Dataframe for station 68.0 was created.
# Dataframe for station 301.0 was created.
# Dataframe for station 348.0 was created.
# Dataframe for station 336.0 was created.
# Dataframe for station 201.0 was created.
# Dataframe for station 434.0 was created.
# Dataframe for station 377.0 was created.
# Dataframe for station 474.0 was created.
# Dataframe for station 210.0 was created.
# Dataframe for station 153.0 was created.
# Dataframe for station 299.0 was created.
# Dataframe for station 146.0 was created.
# Dataframe for station 184.0 was created.
# Dataframe for station 115.0 was created.
# Dataframe for station 428.0 was created.
# Dataframe for station 330.0 was created.
# Dataframe for station 452.0 was created.
# Dataframe for station 62.0 was created.
# Dataframe for station 545.0 was created.
# Dataframe for station 471.0 was created.
# Dataframe for station 491.0 was created.
# Dataframe for station 658.0 was created.
# Dataframe for station 481.0 was created.
# Dataframe for station 75.0 was created.
# Dataframe for station 186.0 was created.
# Dataframe for station 331.0 was created.
# Dataframe for station 180.0 was created.
# Dataframe for station 424.0 was created.
# Dataframe for station 459.0 was created.
# Dataframe for station 706.0 was created.
# Dataframe for station 8.0 was created.
# Dataframe for station 47.0 was created.
# Dataframe for station 56.0 was created.
# Dataframe for station 219.0 was created.
# Dataframe for station 203.0 was created.
# Dataframe for station 314.0 was created.
# Dataframe for station 429.0 was created.
# Dataframe for station 228.0 was created.
# Dataframe for station 333.0 was created.
# Dataframe for station 326.0 was created.
# Dataframe for station 448.0 was created.
# Dataframe for station 178.0 was created.
# Dataframe for station 312.0 was created.
# Dataframe for station 552.0 was created.
# Dataframe for station 218.0 was created.
# Dataframe for station 540.0 was created.
# Dataframe for station 413.0 was created.
# Dataframe for station 373.0 was created.
# Dataframe for station 63.0 was created.
# Dataframe for station 437.0 was created.
# Dataframe for station 668.0 was created.
# Dataframe for station 392.0 was created.
# Dataframe for station 415.0 was created.
# Dataframe for station 407.0 was created.
# Dataframe for station 29.0 was created.
# Dataframe for station 168.0 was created.
# Dataframe for station 233.0 was created.
# Dataframe for station 673.0 was created.
# Dataframe for station 338.0 was created.
# Dataframe for station 209.0 was created.
# Dataframe for station 83.0 was created.
# Dataframe for station 50.0 was created.
# Dataframe for station 438.0 was created.
# Dataframe for station 93.0 was created.
# Dataframe for station 332.0 was created.
# Dataframe for station 472.0 was created.
# Dataframe for station 242.0 was created.
# Dataframe for station 26.0 was created.
# Dataframe for station 433.0 was created.
# Dataframe for station 362.0 was created.
# Dataframe for station 279.0 was created.
# Dataframe for station 130.0 was created.
# Dataframe for station 389.0 was created.
# Dataframe for station 475.0 was created.
# Dataframe for station 334.0 was created.
# Dataframe for station 196.0 was created.
# Dataframe for station 486.0 was created.
# Dataframe for station 455.0 was created.
# Dataframe for station 113.0 was created.
# Dataframe for station 157.0 was created.
# Dataframe for station 322.0 was created.
# Dataframe for station 473.0 was created.
# Dataframe for station 57.0 was created.
# Dataframe for station 386.0 was created.
# Dataframe for station 703.0 was created.
# Dataframe for station 339.0 was created.
# Dataframe for station 709.0 was created.
# Dataframe for station 371.0 was created.
# Dataframe for station 78.0 was created.
# Dataframe for station 128.0 was created.
# Dataframe for station 227.0 was created.
# Dataframe for station 241.0 was created.
# Dataframe for station 363.0 was created.
# Dataframe for station 342.0 was created.
# Dataframe for station 458.0 was created.
# Dataframe for station 417.0 was created.
# Dataframe for station 45.0 was created.
# Dataframe for station 370.0 was created.
# Dataframe for station 58.0 was created.
# Dataframe for station 461.0 was created.
# Dataframe for station 35.0 was created.
# Dataframe for station 349.0 was created.
# Dataframe for station 502.0 was created.
# Dataframe for station 100.0 was created.
# Dataframe for station 284.0 was created.
# Dataframe for station 167.0 was created.
# Dataframe for station 659.0 was created.
# Dataframe for station 239.0 was created.
# Dataframe for station 421.0 was created.
# Dataframe for station 44.0 was created.
# Dataframe for station 262.0 was created.
# Dataframe for station 316.0 was created.
# Dataframe for station 479.0 was created.
# Dataframe for station 292.0 was created.
# Dataframe for station 457.0 was created.
# Dataframe for station 454.0 was created.
# Dataframe for station 307.0 was created.
# Dataframe for station 656.0 was created.
# Dataframe for station 319.0 was created.
# Dataframe for station 357.0 was created.
# Dataframe for station 660.0 was created.
# Dataframe for station 498.0 was created.
# Dataframe for station 199.0 was created.
# Dataframe for station 245.0 was created.
# Dataframe for station 304.0 was created.
# Dataframe for station 109.0 was created.
# Dataframe for station 198.0 was created.
# Dataframe for station 230.0 was created.
# Dataframe for station 177.0 was created.
# Dataframe for station 224.0 was created.
# Dataframe for station 345.0 was created.
# Dataframe for station 309.0 was created.
# Dataframe for station 19.0 was created.
# Dataframe for station 191.0 was created.
# Dataframe for station 216.0 was created.
# Dataframe for station 252.0 was created.
# Dataframe for station 451.0 was created.
# Dataframe for station 537.0 was created.
# Dataframe for station 353.0 was created.
# Dataframe for station 21.0 was created.
# Dataframe for station 672.0 was created.
# Dataframe for station 176.0 was created.
# Dataframe for station 397.0 was created.
# Dataframe for station 416.0 was created.
# Dataframe for station 346.0 was created.
# Dataframe for station 202.0 was created.
# Dataframe for station 436.0 was created.
# Dataframe for station 222.0 was created.
# Dataframe for station 261.0 was created.
# Dataframe for station 13.0 was created.
# Dataframe for station 240.0 was created.
# Dataframe for station 441.0 was created.
# Dataframe for station 213.0 was created.
# Dataframe for station 443.0 was created.
# Dataframe for station 94.0 was created.
# Dataframe for station 425.0 was created.
# Dataframe for station 468.0 was created.
# Dataframe for station 702.0 was created.
# Dataframe for station 89.0 was created.
# Dataframe for station 88.0 was created.
# Dataframe for station 95.0 was created.
# Dataframe for station 456.0 was created.
# Dataframe for station 708.0 was created.
# Dataframe for station 303.0 was created.
# Dataframe for station 442.0 was created.
# Dataframe for station 700.0 was created.
# Dataframe for station 1000.0 was created.
# Dataframe for station 626.0 was created.
# Dataframe for station 696.0 was created.
# Dataframe for station 615.0 was created.
# Dataframe for station 597.0 was created.
# Dataframe for station 694.0 was created.
# Dataframe for station 630.0 was created.
# Dataframe for station 617.0 was created.
# Dataframe for station 691.0 was created.
# Dataframe for station 689.0 was created.
# Dataframe for station 692.0 was created.
# Dataframe for station 701.0 was created.
# Dataframe for station 618.0 was created.
# Dataframe for station 612.0 was created.
# Dataframe for station 661.0 was created.
# Dataframe for station 652.0 was created.
# Dataframe for station 688.0 was created.
# Dataframe for station 629.0 was created.
# Dataframe for station 651.0 was created.
# Dataframe for station 649.0 was created.
# Dataframe for station 602.0 was created.
# Dataframe for station 624.0 was created.
# Dataframe for station 611.0 was created.
# Dataframe for station 637.0 was created.
# Dataframe for station 639.0 was created.
# Dataframe for station 633.0 was created.
# Dataframe for station 592.0 was created.
# Dataframe for station 619.0 was created.
# Dataframe for station 623.0 was created.
# Dataframe for station 620.0 was created.
# Dataframe for station 562.0 was created.
# Dataframe for station 559.0 was created.
# Dataframe for station 634.0 was created.
# Dataframe for station 589.0 was created.
# Dataframe for station 560.0 was created.
# Dataframe for station 579.0 was created.
# Dataframe for station 568.0 was created.
# Dataframe for station 564.0 was created.
# Dataframe for station 577.0 was created.
# Dataframe for station 609.0 was created.
# Dataframe for station 567.0 was created.
# Dataframe for station 604.0 was created.
# Dataframe for station 494.0 was created.
# Dataframe for station 573.0 was created.
# Dataframe for station 501.0 was created.
# Dataframe for station 571.0 was created.
# Dataframe for station 580.0 was created.
# Dataframe for station 569.0 was created.
# Dataframe for station 643.0 was created.
# Dataframe for station 603.0 was created.
# Dataframe for station 578.0 was created.
# Dataframe for station 645.0 was created.
# Dataframe for station 563.0 was created.
# Dataframe for station 697.0 was created.
# Dataframe for station 575.0 was created.
# Dataframe for station 590.0 was created.
# Dataframe for station 556.0 was created.
# Dataframe for station 584.0 was created.
# Dataframe for station 463.0 was created.
# Dataframe for station 650.0 was created.
# Dataframe for station 679.0 was created.
# Dataframe for station 678.0 was created.
# Dataframe for station 664.0 was created.
# Dataframe for station 666.0 was created.
# Dataframe for station 663.0 was created.
# Dataframe for station 662.0 was created.
# Dataframe for station 686.0 was created.
# Dataframe for station 525.0 was created.
# Dataframe for station 527.0 was created.
# Dataframe for station 521.0 was created.
# Dataframe for station 519.0 was created.
# Dataframe for station 518.0 was created.
# Dataframe for station 517.0 was created.
# Dataframe for station 516.0 was created.
# Dataframe for station 531.0 was created.
# Dataframe for station 514.0 was created.
# Dataframe for station 655.0 was created.
# Dataframe for station 684.0 was created.
# Dataframe for station 665.0 was created.
# Dataframe for station 635.0 was created.
# Dataframe for station 613.0 was created.
# Dataframe for station 631.0 was created.
# Dataframe for station 594.0 was created.
# Dataframe for station 628.0 was created.
# Dataframe for station 557.0 was created.
# Dataframe for station 687.0 was created.
# Dataframe for station 512.0 was created.
# Dataframe for station 510.0 was created.
# Dataframe for station 548.0 was created.
# Dataframe for station 608.0 was created.
# Dataframe for station 539.0 was created.
# Dataframe for station 622.0 was created.
# Dataframe for station 642.0 was created.
# Dataframe for station 4422222.0 was created.
# Dataframe for station 595.0 was created.
# Dataframe for station 585.0 was created.
# Dataframe for station 561.0 was created.
# Dataframe for station 636.0 was created.
# Dataframe for station 596.0 was created.
# Dataframe for station 621.0 was created.
# Dataframe for station 598.0 was created.
# Dataframe for station 698.0 was created.
# Dataframe for station 607.0 was created.
# Dataframe for station 685.0 was created.
# Dataframe for station 699.0 was created.
# Dataframe for station 671.0 was created.
# Dataframe for station 542.0 was created.
# Dataframe for station 610.0 was created.
# Dataframe for station 493.0 was created.
# Dataframe for station 500.0 was created.
# Dataframe for station 583.0 was created.
# Dataframe for station 599.0 was created.
# Dataframe for station 644.0 was created.
# Dataframe for station 572.0 was created.
# Dataframe for station 591.0 was created.
# Dataframe for station 601.0 was created.
# Dataframe for station 695.0 was created.
# Dataframe for station 640.0 was created.
# Dataframe for station 484.0 was created.
# Dataframe for station 593.0 was created.
# Dataframe for station 490.0 was created.
# Dataframe for station 544.0 was created.
# Dataframe for station 106.0 was created.
# Dataframe for station 707.0 was created.
# Dataframe for station 693.0 was created.
# Dataframe for station 538.0 was created.
# Dataframe for station 487.0 was created.
# Dataframe for station 654.0 was created.
# Dataframe for station 648.0 was created.
# Dataframe for station 570.0 was created.
# Dataframe for station 674.0 was created.
# Dataframe for station 605.0 was created.
# Dataframe for station 653.0 was created.
# Dataframe for station 705.0 was created.
# Dataframe for station 600.0 was created.
# Dataframe for station 638.0 was created.
# Dataframe for station 505.0 was created.
# Dataframe for station 690.0 was created.
# Dataframe for station 627.0 was created.
# Dataframe for station 641.0 was created.
# Dataframe for station 646.0 was created.
# Dataframe for station 558.0 was created.
# Dataframe for station 576.0 was created.
# Dataframe for station 632.0 was created.
# Dataframe for station 197.0 was created.
# Dataframe for station 489.0 was created.
# Dataframe for station 614.0 was created.
# Dataframe for station 565.0 was created.
# Dataframe for station 566.0 was created.
# Dataframe for station 625.0 was created.
# Dataframe for station 581.0 was created.
# Dataframe for station 616.0 was created.
# Dataframe for station 586.0 was created.
# Dataframe for station 587.0 was created.
# Dataframe for station 574.0 was created.
# Dataframe for station 535.0 was created.
# Dataframe for station 582.0 was created.
# Dataframe for station 683.0 was created.
# Dataframe for station 488.0 was created.
# Dataframe for station 606.0 was created.
# Dataframe for station 547.0 was created.
# Dataframe for station 526.0 was created.
# Dataframe for station 523.0 was created.
# Dataframe for station 522.0 was created.
# Dataframe for station 528.0 was created.
# Number of new dataframes: 645

# %%
# calling dataframe for pickup_station 6
stations_dict[6]
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 192        undefined        37  5125273               6  2023-01-01
# 270                M        42  7262884               6  2023-01-01
# 537                M        58  5202841               6  2023-01-01
# 621                M        36  4868600               6  2023-01-01
# 701                M        35  8541591               6  2023-01-01
# ...              ...       ...      ...             ...         ...
# 13734089           F        33  3026184               6  2024-01-31
# 13734120           M        41  5299292               6  2024-01-31
# 13734389           M        33  8081168               6  2024-01-31
# 13734551           M        32  4277828               6  2024-01-31
# 13734899           F        29  6510093               6  2024-01-31
#
#             pickup_time  return_station return_date    return_time  \
# 192       07:20:32.0920               6  2023-01-01  07:26:50.6540
# 270       08:27:14.8460               6  2023-01-01  08:33:27.2050
# 537       10:15:45.9440               6  2023-01-01  10:51:12.3500
# 621       10:38:44.2660               6  2023-01-01  10:43:13.4200
# 701       10:58:21.0490               6  2023-01-01  11:06:10.2880
# ...                 ...             ...         ...            ...
# 13734089       22:30:28               6  2024-01-31       22:48:18
# 13734120       22:31:46               6  2024-01-31       23:15:57
# 13734389       22:43:10               6  2024-01-31       23:18:46
# 13734551       22:51:46               6  2024-01-31       23:00:27
# 13734899       23:09:35               6  2024-01-31       23:15:34
#
#                  pickup_datetime   hourly_aggregated         return_datetime  \
# 192      2023-01-01 07:20:32.092 2023-01-01 07:00:00 2023-01-01 07:26:50.654
# 270      2023-01-01 08:27:14.846 2023-01-01 08:00:00 2023-01-01 08:33:27.205
# 537      2023-01-01 10:15:45.944 2023-01-01 10:00:00 2023-01-01 10:51:12.350
# 621      2023-01-01 10:38:44.266 2023-01-01 10:00:00 2023-01-01 10:43:13.420
# 701      2023-01-01 10:58:21.049 2023-01-01 10:00:00 2023-01-01 11:06:10.288
# ...                          ...                 ...                     ...
# 13734089 2024-01-31 22:30:28.000 2024-01-31 22:00:00 2024-01-31 22:48:18.000
# 13734120 2024-01-31 22:31:46.000 2024-01-31 22:00:00 2024-01-31 23:15:57.000
# 13734389 2024-01-31 22:43:10.000 2024-01-31 22:00:00 2024-01-31 23:18:46.000
# 13734551 2024-01-31 22:51:46.000 2024-01-31 22:00:00 2024-01-31 23:00:27.000
# 13734899 2024-01-31 23:09:35.000 2024-01-31 23:00:00 2024-01-31 23:15:34.000
#
#                        duration  is_business_day
# 192      0 days 00:06:18.562000                0
# 270      0 days 00:06:12.359000                0
# 537      0 days 00:35:26.406000                0
# 621      0 days 00:04:29.154000                0
# 701      0 days 00:07:49.239000                0
# ...                         ...              ...
# 13734089        0 days 00:17:50                1
# 13734120        0 days 00:44:11                1
# 13734389        0 days 00:35:36                1
# 13734551        0 days 00:08:41                1
# 13734899        0 days 00:05:59                1
#
# [49037 rows x 14 columns]

# %%
data_frame_overview(clean_eco_bici_df)
# Out:
# Column names:
#  Index(['user_gender', 'user_age', 'bike_id', 'pickup_station', 'pickup_date',
#        'pickup_time', 'return_station', 'return_date', 'return_time',
#        'pickup_datetime', 'hourly_aggregated', 'return_datetime', 'duration',
#        'is_business_day'],
#       dtype='object')
#
# Dimensions: (13047307, 14)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 13047307 entries, 0 to 13735452
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   user_gender        object
#  1   user_age           int64
#  2   bike_id            int64
#  3   pickup_station     int64
#  4   pickup_date        datetime64[ns]
#  5   pickup_time        object
#  6   return_station     int64
#  7   return_date        datetime64[ns]
#  8   return_time        object
#  9   pickup_datetime    datetime64[ns]
#  10  hourly_aggregated  datetime64[ns]
#  11  return_datetime    datetime64[ns]
#  12  duration           timedelta64[ns]
#  13  is_business_day    int64
# dtypes: datetime64[ns](5), int64(5), object(3), timedelta64[ns](1)
# memory usage: 1.5+ GB
# None
#   user_gender  user_age  bike_id  pickup_station pickup_date    pickup_time  \
# 0           M        35  8908451              81  2022-09-03  18:45:42.3370
# 1   undefined        29  5380423              56  2022-09-30       12:24:36
# 2   undefined        32  5218094              56  2022-09-30  13:17:30.6120
# 3   undefined        25  7278658              56  2022-09-30  13:20:09.0510
# 4           M        48  4031258              22  2022-11-10  21:26:19.3790
# 5           F        30  3561073             287  2022-11-13  19:23:04.5660
# 6           M        29  8938029             302  2022-11-15       16:52:21
# 7           M        43  8296352              19  2022-11-18  21:11:36.3090
# 8           F        37  6537930             116  2022-11-28  15:07:47.0830
# 9           M        54  2502870             131  2022-12-04  13:04:07.8950
#
#    return_station return_date    return_time         pickup_datetime  \
# 0              81  2023-02-02  19:09:36.7840 2022-09-03 18:45:42.337
# 1              56  2023-11-24       15:13:34 2022-09-30 12:24:36.000
# 2              56  2023-02-09  13:14:13.9300 2022-09-30 13:17:30.612
# 3              56  2023-02-09  13:11:41.3290 2022-09-30 13:20:09.051
# 4              22  2023-02-02  19:11:23.2350 2022-11-10 21:26:19.379
# 5             287  2023-02-17  12:08:38.0860 2022-11-13 19:23:04.566
# 6             302  2023-03-06       20:20:00 2022-11-15 16:52:21.000
# 7              19  2023-01-17  17:17:07.2610 2022-11-18 21:11:36.309
# 8             116  2023-01-26  16:18:13.7580 2022-11-28 15:07:47.083
# 9             131  2023-01-17  17:40:14.5700 2022-12-04 13:04:07.895
#
#     hourly_aggregated         return_datetime                 duration  \
# 0 2022-09-03 18:00:00 2023-02-02 19:09:36.784 152 days 00:23:54.447000
# 1 2022-09-30 12:00:00 2023-11-24 15:13:34.000        420 days 02:48:58
# 2 2022-09-30 13:00:00 2023-02-09 13:14:13.930 131 days 23:56:43.318000
# 3 2022-09-30 13:00:00 2023-02-09 13:11:41.329 131 days 23:51:32.278000
# 4 2022-11-10 21:00:00 2023-02-02 19:11:23.235  83 days 21:45:03.856000
# 5 2022-11-13 19:00:00 2023-02-17 12:08:38.086  95 days 16:45:33.520000
# 6 2022-11-15 16:00:00 2023-03-06 20:20:00.000        111 days 03:27:39
# 7 2022-11-18 21:00:00 2023-01-17 17:17:07.261  59 days 20:05:30.952000
# 8 2022-11-28 15:00:00 2023-01-26 16:18:13.758  59 days 01:10:26.675000
# 9 2022-12-04 13:00:00 2023-01-17 17:40:14.570  44 days 04:36:06.675000
#
#    is_business_day
# 0                0
# 1                1
# 2                1
# 3                1
# 4                1
# 5                0
# 6                1
# 7                1
# 8                1
# 9                0

# %% [markdown]
# <b> Aggregating each station's df by hour</b>

# %%
# For each dataframe in stations_dict:
# Group by 'hourly_datetime' and aggregate the data using aggregating functions (mean, mode, etc.)
# set index to hour and reindex to get full index and insert empty rows for missing hours, fillna with 0
# saving each individual data frame into a dictionary, where station number is key and df is value

full_index = pd.date_range(start='2023-01-01 00:00:00', end='2024-02-01 00:00:00', freq='H')
stations_hourly_dict = {}

for key,value in stations_dict.items():
    station_aggregated = value.groupby('hourly_aggregated',as_index=False).agg(
        {'bike_id': 'count',
         'duration': 'mean',
        }
    )
    # reformat df columns and duration values, reset index
    station_aggregated.rename(columns={'hourly_aggregated':'hour','bike_id':'rental_counts','duration':'avg_rental_duration'},inplace=True)
    station_aggregated.set_index('hour', drop=False, inplace=True)
    station_aggregated = station_aggregated.reindex(full_index)
    station_aggregated.hour = station_aggregated.index
    station_aggregated.fillna(0, inplace=True)
    
    # convert avg rental duration from timedelta to float, representing minutes
    station_aggregated['avg_rental_duration'] = station_aggregated['avg_rental_duration'].apply(
    lambda x: round(float(x.total_seconds() / 60) if isinstance(x, pd.Timedelta) else x, 2))
    
    # add is_business_day
    station_aggregated['is_business_day'] = pd.to_datetime(station_aggregated['hour']).apply(
    lambda x: 1 if (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] and (x.weekday() < 5) else 0
    )
    station_aggregated.drop('hour', axis=1,inplace=True)
    
    stations_hourly_dict[key] = station_aggregated

    print(f"Aggregated dataframe for station {key} was created.")
    
print(f"Number of new dataframes: {len(stations_hourly_dict)}")
# Out:
# Aggregated dataframe for station 7.0 was created.
# Aggregated dataframe for station 206.0 was created.
# Aggregated dataframe for station 215.0 was created.
# Aggregated dataframe for station 291.0 was created.
# Aggregated dataframe for station 546.0 was created.
# Aggregated dataframe for station 306.0 was created.
# Aggregated dataframe for station 65.0 was created.
# Aggregated dataframe for station 221.0 was created.
# Aggregated dataframe for station 394.0 was created.
# Aggregated dataframe for station 375.0 was created.
# Aggregated dataframe for station 74.0 was created.
# Aggregated dataframe for station 396.0 was created.
# Aggregated dataframe for station 136.0 was created.
# Aggregated dataframe for station 129.0 was created.
# Aggregated dataframe for station 283.0 was created.
# Aggregated dataframe for station 355.0 was created.
# Aggregated dataframe for station 12.0 was created.
# Aggregated dataframe for station 67.0 was created.
# Aggregated dataframe for station 187.0 was created.
# Aggregated dataframe for station 337.0 was created.
# Aggregated dataframe for station nan was created.
# Aggregated dataframe for station 503.0 was created.
# Aggregated dataframe for station 220.0 was created.
# Aggregated dataframe for station 43.0 was created.
# Aggregated dataframe for station 73.0 was created.
# Aggregated dataframe for station 59.0 was created.
# Aggregated dataframe for station 226.0 was created.
# Aggregated dataframe for station 372.0 was created.
# Aggregated dataframe for station 340.0 was created.
# Aggregated dataframe for station 174.0 was created.
# Aggregated dataframe for station 162.0 was created.
# Aggregated dataframe for station 163.0 was created.
# Aggregated dataframe for station 449.0 was created.
# Aggregated dataframe for station 64.0 was created.
# Aggregated dataframe for station 30.0 was created.
# Aggregated dataframe for station 398.0 was created.
# Aggregated dataframe for station 148.0 was created.
# Aggregated dataframe for station 61.0 was created.
# Aggregated dataframe for station 121.0 was created.
# Aggregated dataframe for station 32.0 was created.
# Aggregated dataframe for station 295.0 was created.
# Aggregated dataframe for station 551.0 was created.
# Aggregated dataframe for station 189.0 was created.
# Aggregated dataframe for station 31.0 was created.
# Aggregated dataframe for station 25.0 was created.
# Aggregated dataframe for station 52.0 was created.
# Aggregated dataframe for station 99.0 was created.
# Aggregated dataframe for station 86.0 was created.
# Aggregated dataframe for station 40.0 was created.
# Aggregated dataframe for station 69.0 was created.
# Aggregated dataframe for station 155.0 was created.
# Aggregated dataframe for station 76.0 was created.
# Aggregated dataframe for station 123.0 was created.
# Aggregated dataframe for station 393.0 was created.
# Aggregated dataframe for station 53.0 was created.
# Aggregated dataframe for station 507.0 was created.
# Aggregated dataframe for station 469.0 was created.
# Aggregated dataframe for station 11.0 was created.
# Aggregated dataframe for station 300.0 was created.
# Aggregated dataframe for station 550.0 was created.
# Aggregated dataframe for station 320.0 was created.
# Aggregated dataframe for station 132.0 was created.
# Aggregated dataframe for station 294.0 was created.
# Aggregated dataframe for station 41.0 was created.
# Aggregated dataframe for station 422.0 was created.
# Aggregated dataframe for station 280.0 was created.
# Aggregated dataframe for station 315.0 was created.
# Aggregated dataframe for station 1.0 was created.
# Aggregated dataframe for station 378.0 was created.
# Aggregated dataframe for station 114.0 was created.
# Aggregated dataframe for station 281.0 was created.
# Aggregated dataframe for station 81.0 was created.
# Aggregated dataframe for station 142.0 was created.
# Aggregated dataframe for station 554.0 was created.
# Aggregated dataframe for station 290.0 was created.
# Aggregated dataframe for station 208.0 was created.
# Aggregated dataframe for station 258.0 was created.
# Aggregated dataframe for station 341.0 was created.
# Aggregated dataframe for station 15.0 was created.
# Aggregated dataframe for station 16.0 was created.
# Aggregated dataframe for station 447.0 was created.
# Aggregated dataframe for station 82.0 was created.
# Aggregated dataframe for station 103.0 was created.
# Aggregated dataframe for station 92.0 was created.
# Aggregated dataframe for station 60.0 was created.
# Aggregated dataframe for station 80.0 was created.
# Aggregated dataframe for station 111.0 was created.
# Aggregated dataframe for station 420.0 was created.
# Aggregated dataframe for station 234.0 was created.
# Aggregated dataframe for station 223.0 was created.
# Aggregated dataframe for station 18.0 was created.
# Aggregated dataframe for station 90.0 was created.
# Aggregated dataframe for station 24.0 was created.
# Aggregated dataframe for station 248.0 was created.
# Aggregated dataframe for station 135.0 was created.
# Aggregated dataframe for station 359.0 was created.
# Aggregated dataframe for station 23.0 was created.
# Aggregated dataframe for station 96.0 was created.
# Aggregated dataframe for station 462.0 was created.
# Aggregated dataframe for station 270.0 was created.
# Aggregated dataframe for station 70.0 was created.
# Aggregated dataframe for station 54.0 was created.
# Aggregated dataframe for station 133.0 was created.
# Aggregated dataframe for station 105.0 was created.
# Aggregated dataframe for station 450.0 was created.
# Aggregated dataframe for station 427.0 was created.
# Aggregated dataframe for station 87.0 was created.
# Aggregated dataframe for station 164.0 was created.
# Aggregated dataframe for station 260.0 was created.
# Aggregated dataframe for station 144.0 was created.
# Aggregated dataframe for station 183.0 was created.
# Aggregated dataframe for station 143.0 was created.
# Aggregated dataframe for station 444.0 was created.
# Aggregated dataframe for station 285.0 was created.
# Aggregated dataframe for station 325.0 was created.
# Aggregated dataframe for station 310.0 was created.
# Aggregated dataframe for station 412.0 was created.
# Aggregated dataframe for station 150.0 was created.
# Aggregated dataframe for station 10.0 was created.
# Aggregated dataframe for station 541.0 was created.
# Aggregated dataframe for station 36.0 was created.
# Aggregated dataframe for station 154.0 was created.
# Aggregated dataframe for station 263.0 was created.
# Aggregated dataframe for station 324.0 was created.
# Aggregated dataframe for station 278.0 was created.
# Aggregated dataframe for station 321.0 was created.
# Aggregated dataframe for station 85.0 was created.
# Aggregated dataframe for station 33.0 was created.
# Aggregated dataframe for station 366.0 was created.
# Aggregated dataframe for station 499.0 was created.
# Aggregated dataframe for station 160.0 was created.
# Aggregated dataframe for station 17.0 was created.
# Aggregated dataframe for station 171.0 was created.
# Aggregated dataframe for station 255.0 was created.
# Aggregated dataframe for station 179.0 was created.
# Aggregated dataframe for station 145.0 was created.
# Aggregated dataframe for station 480.0 was created.
# Aggregated dataframe for station 555.0 was created.
# Aggregated dataframe for station 329.0 was created.
# Aggregated dataframe for station 37.0 was created.
# Aggregated dataframe for station 147.0 was created.
# Aggregated dataframe for station 38.0 was created.
# Aggregated dataframe for station 151.0 was created.
# Aggregated dataframe for station 140.0 was created.
# Aggregated dataframe for station 77.0 was created.
# Aggregated dataframe for station 384.0 was created.
# Aggregated dataframe for station 504.0 was created.
# Aggregated dataframe for station 354.0 was created.
# Aggregated dataframe for station 2.0 was created.
# Aggregated dataframe for station 318.0 was created.
# Aggregated dataframe for station 3.0 was created.
# Aggregated dataframe for station 175.0 was created.
# Aggregated dataframe for station 49.0 was created.
# Aggregated dataframe for station 185.0 was created.
# Aggregated dataframe for station 244.0 was created.
# Aggregated dataframe for station 138.0 was created.
# Aggregated dataframe for station 401.0 was created.
# Aggregated dataframe for station 351.0 was created.
# Aggregated dataframe for station 141.0 was created.
# Aggregated dataframe for station 553.0 was created.
# Aggregated dataframe for station 55.0 was created.
# Aggregated dataframe for station 72.0 was created.
# Aggregated dataframe for station 453.0 was created.
# Aggregated dataframe for station 478.0 was created.
# Aggregated dataframe for station 409.0 was created.
# Aggregated dataframe for station 405.0 was created.
# Aggregated dataframe for station 308.0 was created.
# Aggregated dataframe for station 470.0 was created.
# Aggregated dataframe for station 194.0 was created.
# Aggregated dataframe for station 42.0 was created.
# Aggregated dataframe for station 464.0 was created.
# Aggregated dataframe for station 173.0 was created.
# Aggregated dataframe for station 137.0 was created.
# Aggregated dataframe for station 477.0 was created.
# Aggregated dataframe for station 84.0 was created.
# Aggregated dataframe for station 27.0 was created.
# Aggregated dataframe for station 122.0 was created.
# Aggregated dataframe for station 28.0 was created.
# Aggregated dataframe for station 156.0 was created.
# Aggregated dataframe for station 207.0 was created.
# Aggregated dataframe for station 276.0 was created.
# Aggregated dataframe for station 229.0 was created.
# Aggregated dataframe for station 430.0 was created.
# Aggregated dataframe for station 4.0 was created.
# Aggregated dataframe for station 139.0 was created.
# Aggregated dataframe for station 704.0 was created.
# Aggregated dataframe for station 298.0 was created.
# Aggregated dataframe for station 277.0 was created.
# Aggregated dataframe for station 439.0 was created.
# Aggregated dataframe for station 432.0 was created.
# Aggregated dataframe for station 365.0 was created.
# Aggregated dataframe for station 118.0 was created.
# Aggregated dataframe for station 667.0 was created.
# Aggregated dataframe for station 402.0 was created.
# Aggregated dataframe for station 352.0 was created.
# Aggregated dataframe for station 543.0 was created.
# Aggregated dataframe for station 374.0 was created.
# Aggregated dataframe for station 22.0 was created.
# Aggregated dataframe for station 225.0 was created.
# Aggregated dataframe for station 182.0 was created.
# Aggregated dataframe for station 166.0 was created.
# Aggregated dataframe for station 335.0 was created.
# Aggregated dataframe for station 549.0 was created.
# Aggregated dataframe for station 125.0 was created.
# Aggregated dataframe for station 465.0 was created.
# Aggregated dataframe for station 358.0 was created.
# Aggregated dataframe for station 485.0 was created.
# Aggregated dataframe for station 102.0 was created.
# Aggregated dataframe for station 181.0 was created.
# Aggregated dataframe for station 482.0 was created.
# Aggregated dataframe for station 200.0 was created.
# Aggregated dataframe for station 360.0 was created.
# Aggregated dataframe for station 536.0 was created.
# Aggregated dataframe for station 211.0 was created.
# Aggregated dataframe for station 347.0 was created.
# Aggregated dataframe for station 256.0 was created.
# Aggregated dataframe for station 492.0 was created.
# Aggregated dataframe for station 131.0 was created.
# Aggregated dataframe for station 51.0 was created.
# Aggregated dataframe for station 302.0 was created.
# Aggregated dataframe for station 112.0 was created.
# Aggregated dataframe for station 9.0 was created.
# Aggregated dataframe for station 152.0 was created.
# Aggregated dataframe for station 172.0 was created.
# Aggregated dataframe for station 126.0 was created.
# Aggregated dataframe for station 305.0 was created.
# Aggregated dataframe for station 161.0 was created.
# Aggregated dataframe for station 134.0 was created.
# Aggregated dataframe for station 46.0 was created.
# Aggregated dataframe for station 204.0 was created.
# Aggregated dataframe for station 399.0 was created.
# Aggregated dataframe for station 460.0 was created.
# Aggregated dataframe for station 169.0 was created.
# Aggregated dataframe for station 317.0 was created.
# Aggregated dataframe for station 116.0 was created.
# Aggregated dataframe for station 296.0 was created.
# Aggregated dataframe for station 246.0 was created.
# Aggregated dataframe for station 20.0 was created.
# Aggregated dataframe for station 253.0 was created.
# Aggregated dataframe for station 361.0 was created.
# Aggregated dataframe for station 476.0 was created.
# Aggregated dataframe for station 104.0 was created.
# Aggregated dataframe for station 495.0 was created.
# Aggregated dataframe for station 251.0 was created.
# Aggregated dataframe for station 323.0 was created.
# Aggregated dataframe for station 39.0 was created.
# Aggregated dataframe for station 404.0 was created.
# Aggregated dataframe for station 288.0 was created.
# Aggregated dataframe for station 71.0 was created.
# Aggregated dataframe for station 124.0 was created.
# Aggregated dataframe for station 286.0 was created.
# Aggregated dataframe for station 356.0 was created.
# Aggregated dataframe for station 669.0 was created.
# Aggregated dataframe for station 496.0 was created.
# Aggregated dataframe for station 506.0 was created.
# Aggregated dataframe for station 483.0 was created.
# Aggregated dataframe for station 34.0 was created.
# Aggregated dataframe for station 217.0 was created.
# Aggregated dataframe for station 14.0 was created.
# Aggregated dataframe for station 249.0 was created.
# Aggregated dataframe for station 293.0 was created.
# Aggregated dataframe for station 369.0 was created.
# Aggregated dataframe for station 119.0 was created.
# Aggregated dataframe for station 670.0 was created.
# Aggregated dataframe for station 381.0 was created.
# Aggregated dataframe for station 6.0 was created.
# Aggregated dataframe for station 195.0 was created.
# Aggregated dataframe for station 247.0 was created.
# Aggregated dataframe for station 466.0 was created.
# Aggregated dataframe for station 313.0 was created.
# Aggregated dataframe for station 497.0 was created.
# Aggregated dataframe for station 205.0 was created.
# Aggregated dataframe for station 117.0 was created.
# Aggregated dataframe for station 380.0 was created.
# Aggregated dataframe for station 419.0 was created.
# Aggregated dataframe for station 467.0 was created.
# Aggregated dataframe for station 297.0 was created.
# Aggregated dataframe for station 657.0 was created.
# Aggregated dataframe for station 231.0 was created.
# Aggregated dataframe for station 423.0 was created.
# Aggregated dataframe for station 232.0 was created.
# Aggregated dataframe for station 79.0 was created.
# Aggregated dataframe for station 5.0 was created.
# Aggregated dataframe for station 214.0 was created.
# Aggregated dataframe for station 170.0 was created.
# Aggregated dataframe for station 97.0 was created.
# Aggregated dataframe for station 250.0 was created.
# Aggregated dataframe for station 110.0 was created.
# Aggregated dataframe for station 385.0 was created.
# Aggregated dataframe for station 282.0 was created.
# Aggregated dataframe for station 48.0 was created.
# Aggregated dataframe for station 120.0 was created.
# Aggregated dataframe for station 188.0 was created.
# Aggregated dataframe for station 66.0 was created.
# Aggregated dataframe for station 243.0 was created.
# Aggregated dataframe for station 327.0 was created.
# Aggregated dataframe for station 414.0 was created.
# Aggregated dataframe for station 343.0 was created.
# Aggregated dataframe for station 328.0 was created.
# Aggregated dataframe for station 259.0 was created.
# Aggregated dataframe for station 367.0 was created.
# Aggregated dataframe for station 254.0 was created.
# Aggregated dataframe for station 257.0 was created.
# Aggregated dataframe for station 287.0 was created.
# Aggregated dataframe for station 190.0 was created.
# Aggregated dataframe for station 212.0 was created.
# Aggregated dataframe for station 98.0 was created.
# Aggregated dataframe for station 387.0 was created.
# Aggregated dataframe for station 165.0 was created.
# Aggregated dataframe for station 149.0 was created.
# Aggregated dataframe for station 265.0 was created.
# Aggregated dataframe for station 91.0 was created.
# Aggregated dataframe for station 395.0 was created.
# Aggregated dataframe for station 127.0 was created.
# Aggregated dataframe for station 68.0 was created.
# Aggregated dataframe for station 301.0 was created.
# Aggregated dataframe for station 348.0 was created.
# Aggregated dataframe for station 336.0 was created.
# Aggregated dataframe for station 201.0 was created.
# Aggregated dataframe for station 434.0 was created.
# Aggregated dataframe for station 377.0 was created.
# Aggregated dataframe for station 474.0 was created.
# Aggregated dataframe for station 210.0 was created.
# Aggregated dataframe for station 153.0 was created.
# Aggregated dataframe for station 299.0 was created.
# Aggregated dataframe for station 146.0 was created.
# Aggregated dataframe for station 184.0 was created.
# Aggregated dataframe for station 115.0 was created.
# Aggregated dataframe for station 428.0 was created.
# Aggregated dataframe for station 330.0 was created.
# Aggregated dataframe for station 452.0 was created.
# Aggregated dataframe for station 62.0 was created.
# Aggregated dataframe for station 545.0 was created.
# Aggregated dataframe for station 471.0 was created.
# Aggregated dataframe for station 491.0 was created.
# Aggregated dataframe for station 658.0 was created.
# Aggregated dataframe for station 481.0 was created.
# Aggregated dataframe for station 75.0 was created.
# Aggregated dataframe for station 186.0 was created.
# Aggregated dataframe for station 331.0 was created.
# Aggregated dataframe for station 180.0 was created.
# Aggregated dataframe for station 424.0 was created.
# Aggregated dataframe for station 459.0 was created.
# Aggregated dataframe for station 706.0 was created.
# Aggregated dataframe for station 8.0 was created.
# Aggregated dataframe for station 47.0 was created.
# Aggregated dataframe for station 56.0 was created.
# Aggregated dataframe for station 219.0 was created.
# Aggregated dataframe for station 203.0 was created.
# Aggregated dataframe for station 314.0 was created.
# Aggregated dataframe for station 429.0 was created.
# Aggregated dataframe for station 228.0 was created.
# Aggregated dataframe for station 333.0 was created.
# Aggregated dataframe for station 326.0 was created.
# Aggregated dataframe for station 448.0 was created.
# Aggregated dataframe for station 178.0 was created.
# Aggregated dataframe for station 312.0 was created.
# Aggregated dataframe for station 552.0 was created.
# Aggregated dataframe for station 218.0 was created.
# Aggregated dataframe for station 540.0 was created.
# Aggregated dataframe for station 413.0 was created.
# Aggregated dataframe for station 373.0 was created.
# Aggregated dataframe for station 63.0 was created.
# Aggregated dataframe for station 437.0 was created.
# Aggregated dataframe for station 668.0 was created.
# Aggregated dataframe for station 392.0 was created.
# Aggregated dataframe for station 415.0 was created.
# Aggregated dataframe for station 407.0 was created.
# Aggregated dataframe for station 29.0 was created.
# Aggregated dataframe for station 168.0 was created.
# Aggregated dataframe for station 233.0 was created.
# Aggregated dataframe for station 673.0 was created.
# Aggregated dataframe for station 338.0 was created.
# Aggregated dataframe for station 209.0 was created.
# Aggregated dataframe for station 83.0 was created.
# Aggregated dataframe for station 50.0 was created.
# Aggregated dataframe for station 438.0 was created.
# Aggregated dataframe for station 93.0 was created.
# Aggregated dataframe for station 332.0 was created.
# Aggregated dataframe for station 472.0 was created.
# Aggregated dataframe for station 242.0 was created.
# Aggregated dataframe for station 26.0 was created.
# Aggregated dataframe for station 433.0 was created.
# Aggregated dataframe for station 362.0 was created.
# Aggregated dataframe for station 279.0 was created.
# Aggregated dataframe for station 130.0 was created.
# Aggregated dataframe for station 389.0 was created.
# Aggregated dataframe for station 475.0 was created.
# Aggregated dataframe for station 334.0 was created.
# Aggregated dataframe for station 196.0 was created.
# Aggregated dataframe for station 486.0 was created.
# Aggregated dataframe for station 455.0 was created.
# Aggregated dataframe for station 113.0 was created.
# Aggregated dataframe for station 157.0 was created.
# Aggregated dataframe for station 322.0 was created.
# Aggregated dataframe for station 473.0 was created.
# Aggregated dataframe for station 57.0 was created.
# Aggregated dataframe for station 386.0 was created.
# Aggregated dataframe for station 703.0 was created.
# Aggregated dataframe for station 339.0 was created.
# Aggregated dataframe for station 709.0 was created.
# Aggregated dataframe for station 371.0 was created.
# Aggregated dataframe for station 78.0 was created.
# Aggregated dataframe for station 128.0 was created.
# Aggregated dataframe for station 227.0 was created.
# Aggregated dataframe for station 241.0 was created.
# Aggregated dataframe for station 363.0 was created.
# Aggregated dataframe for station 342.0 was created.
# Aggregated dataframe for station 458.0 was created.
# Aggregated dataframe for station 417.0 was created.
# Aggregated dataframe for station 45.0 was created.
# Aggregated dataframe for station 370.0 was created.
# Aggregated dataframe for station 58.0 was created.
# Aggregated dataframe for station 461.0 was created.
# Aggregated dataframe for station 35.0 was created.
# Aggregated dataframe for station 349.0 was created.
# Aggregated dataframe for station 502.0 was created.
# Aggregated dataframe for station 100.0 was created.
# Aggregated dataframe for station 284.0 was created.
# Aggregated dataframe for station 167.0 was created.
# Aggregated dataframe for station 659.0 was created.
# Aggregated dataframe for station 239.0 was created.
# Aggregated dataframe for station 421.0 was created.
# Aggregated dataframe for station 44.0 was created.
# Aggregated dataframe for station 262.0 was created.
# Aggregated dataframe for station 316.0 was created.
# Aggregated dataframe for station 479.0 was created.
# Aggregated dataframe for station 292.0 was created.
# Aggregated dataframe for station 457.0 was created.
# Aggregated dataframe for station 454.0 was created.
# Aggregated dataframe for station 307.0 was created.
# Aggregated dataframe for station 656.0 was created.
# Aggregated dataframe for station 319.0 was created.
# Aggregated dataframe for station 357.0 was created.
# Aggregated dataframe for station 660.0 was created.
# Aggregated dataframe for station 498.0 was created.
# Aggregated dataframe for station 199.0 was created.
# Aggregated dataframe for station 245.0 was created.
# Aggregated dataframe for station 304.0 was created.
# Aggregated dataframe for station 109.0 was created.
# Aggregated dataframe for station 198.0 was created.
# Aggregated dataframe for station 230.0 was created.
# Aggregated dataframe for station 177.0 was created.
# Aggregated dataframe for station 224.0 was created.
# Aggregated dataframe for station 345.0 was created.
# Aggregated dataframe for station 309.0 was created.
# Aggregated dataframe for station 19.0 was created.
# Aggregated dataframe for station 191.0 was created.
# Aggregated dataframe for station 216.0 was created.
# Aggregated dataframe for station 252.0 was created.
# Aggregated dataframe for station 451.0 was created.
# Aggregated dataframe for station 537.0 was created.
# Aggregated dataframe for station 353.0 was created.
# Aggregated dataframe for station 21.0 was created.
# Aggregated dataframe for station 672.0 was created.
# Aggregated dataframe for station 176.0 was created.
# Aggregated dataframe for station 397.0 was created.
# Aggregated dataframe for station 416.0 was created.
# Aggregated dataframe for station 346.0 was created.
# Aggregated dataframe for station 202.0 was created.
# Aggregated dataframe for station 436.0 was created.
# Aggregated dataframe for station 222.0 was created.
# Aggregated dataframe for station 261.0 was created.
# Aggregated dataframe for station 13.0 was created.
# Aggregated dataframe for station 240.0 was created.
# Aggregated dataframe for station 441.0 was created.
# Aggregated dataframe for station 213.0 was created.
# Aggregated dataframe for station 443.0 was created.
# Aggregated dataframe for station 94.0 was created.
# Aggregated dataframe for station 425.0 was created.
# Aggregated dataframe for station 468.0 was created.
# Aggregated dataframe for station 702.0 was created.
# Aggregated dataframe for station 89.0 was created.
# Aggregated dataframe for station 88.0 was created.
# Aggregated dataframe for station 95.0 was created.
# Aggregated dataframe for station 456.0 was created.
# Aggregated dataframe for station 708.0 was created.
# Aggregated dataframe for station 303.0 was created.
# Aggregated dataframe for station 442.0 was created.
# Aggregated dataframe for station 700.0 was created.
# Aggregated dataframe for station 1000.0 was created.
# Aggregated dataframe for station 626.0 was created.
# Aggregated dataframe for station 696.0 was created.
# Aggregated dataframe for station 615.0 was created.
# Aggregated dataframe for station 597.0 was created.
# Aggregated dataframe for station 694.0 was created.
# Aggregated dataframe for station 630.0 was created.
# Aggregated dataframe for station 617.0 was created.
# Aggregated dataframe for station 691.0 was created.
# Aggregated dataframe for station 689.0 was created.
# Aggregated dataframe for station 692.0 was created.
# Aggregated dataframe for station 701.0 was created.
# Aggregated dataframe for station 618.0 was created.
# Aggregated dataframe for station 612.0 was created.
# Aggregated dataframe for station 661.0 was created.
# Aggregated dataframe for station 652.0 was created.
# Aggregated dataframe for station 688.0 was created.
# Aggregated dataframe for station 629.0 was created.
# Aggregated dataframe for station 651.0 was created.
# Aggregated dataframe for station 649.0 was created.
# Aggregated dataframe for station 602.0 was created.
# Aggregated dataframe for station 624.0 was created.
# Aggregated dataframe for station 611.0 was created.
# Aggregated dataframe for station 637.0 was created.
# Aggregated dataframe for station 639.0 was created.
# Aggregated dataframe for station 633.0 was created.
# Aggregated dataframe for station 592.0 was created.
# Aggregated dataframe for station 619.0 was created.
# Aggregated dataframe for station 623.0 was created.
# Aggregated dataframe for station 620.0 was created.
# Aggregated dataframe for station 562.0 was created.
# Aggregated dataframe for station 559.0 was created.
# Aggregated dataframe for station 634.0 was created.
# Aggregated dataframe for station 589.0 was created.
# Aggregated dataframe for station 560.0 was created.
# Aggregated dataframe for station 579.0 was created.
# Aggregated dataframe for station 568.0 was created.
# Aggregated dataframe for station 564.0 was created.
# Aggregated dataframe for station 577.0 was created.
# Aggregated dataframe for station 609.0 was created.
# Aggregated dataframe for station 567.0 was created.
# Aggregated dataframe for station 604.0 was created.
# Aggregated dataframe for station 494.0 was created.
# Aggregated dataframe for station 573.0 was created.
# Aggregated dataframe for station 501.0 was created.
# Aggregated dataframe for station 571.0 was created.
# Aggregated dataframe for station 580.0 was created.
# Aggregated dataframe for station 569.0 was created.
# Aggregated dataframe for station 643.0 was created.
# Aggregated dataframe for station 603.0 was created.
# Aggregated dataframe for station 578.0 was created.
# Aggregated dataframe for station 645.0 was created.
# Aggregated dataframe for station 563.0 was created.
# Aggregated dataframe for station 697.0 was created.
# Aggregated dataframe for station 575.0 was created.
# Aggregated dataframe for station 590.0 was created.
# Aggregated dataframe for station 556.0 was created.
# Aggregated dataframe for station 584.0 was created.
# Aggregated dataframe for station 463.0 was created.
# Aggregated dataframe for station 650.0 was created.
# Aggregated dataframe for station 679.0 was created.
# Aggregated dataframe for station 678.0 was created.
# Aggregated dataframe for station 664.0 was created.
# Aggregated dataframe for station 666.0 was created.
# Aggregated dataframe for station 663.0 was created.
# Aggregated dataframe for station 662.0 was created.
# Aggregated dataframe for station 686.0 was created.
# Aggregated dataframe for station 525.0 was created.
# Aggregated dataframe for station 527.0 was created.
# Aggregated dataframe for station 521.0 was created.
# Aggregated dataframe for station 519.0 was created.
# Aggregated dataframe for station 518.0 was created.
# Aggregated dataframe for station 517.0 was created.
# Aggregated dataframe for station 516.0 was created.
# Aggregated dataframe for station 531.0 was created.
# Aggregated dataframe for station 514.0 was created.
# Aggregated dataframe for station 655.0 was created.
# Aggregated dataframe for station 684.0 was created.
# Aggregated dataframe for station 665.0 was created.
# Aggregated dataframe for station 635.0 was created.
# Aggregated dataframe for station 613.0 was created.
# Aggregated dataframe for station 631.0 was created.
# Aggregated dataframe for station 594.0 was created.
# Aggregated dataframe for station 628.0 was created.
# Aggregated dataframe for station 557.0 was created.
# Aggregated dataframe for station 687.0 was created.
# Aggregated dataframe for station 512.0 was created.
# Aggregated dataframe for station 510.0 was created.
# Aggregated dataframe for station 548.0 was created.
# Aggregated dataframe for station 608.0 was created.
# Aggregated dataframe for station 539.0 was created.
# Aggregated dataframe for station 622.0 was created.
# Aggregated dataframe for station 642.0 was created.
# Aggregated dataframe for station 4422222.0 was created.
# Aggregated dataframe for station 595.0 was created.
# Aggregated dataframe for station 585.0 was created.
# Aggregated dataframe for station 561.0 was created.
# Aggregated dataframe for station 636.0 was created.
# Aggregated dataframe for station 596.0 was created.
# Aggregated dataframe for station 621.0 was created.
# Aggregated dataframe for station 598.0 was created.
# Aggregated dataframe for station 698.0 was created.
# Aggregated dataframe for station 607.0 was created.
# Aggregated dataframe for station 685.0 was created.
# Aggregated dataframe for station 699.0 was created.
# Aggregated dataframe for station 671.0 was created.
# Aggregated dataframe for station 542.0 was created.
# Aggregated dataframe for station 610.0 was created.
# Aggregated dataframe for station 493.0 was created.
# Aggregated dataframe for station 500.0 was created.
# Aggregated dataframe for station 583.0 was created.
# Aggregated dataframe for station 599.0 was created.
# Aggregated dataframe for station 644.0 was created.
# Aggregated dataframe for station 572.0 was created.
# Aggregated dataframe for station 591.0 was created.
# Aggregated dataframe for station 601.0 was created.
# Aggregated dataframe for station 695.0 was created.
# Aggregated dataframe for station 640.0 was created.
# Aggregated dataframe for station 484.0 was created.
# Aggregated dataframe for station 593.0 was created.
# Aggregated dataframe for station 490.0 was created.
# Aggregated dataframe for station 544.0 was created.
# Aggregated dataframe for station 106.0 was created.
# Aggregated dataframe for station 707.0 was created.
# Aggregated dataframe for station 693.0 was created.
# Aggregated dataframe for station 538.0 was created.
# Aggregated dataframe for station 487.0 was created.
# Aggregated dataframe for station 654.0 was created.
# Aggregated dataframe for station 648.0 was created.
# Aggregated dataframe for station 570.0 was created.
# Aggregated dataframe for station 674.0 was created.
# Aggregated dataframe for station 605.0 was created.
# Aggregated dataframe for station 653.0 was created.
# Aggregated dataframe for station 705.0 was created.
# Aggregated dataframe for station 600.0 was created.
# Aggregated dataframe for station 638.0 was created.
# Aggregated dataframe for station 505.0 was created.
# Aggregated dataframe for station 690.0 was created.
# Aggregated dataframe for station 627.0 was created.
# Aggregated dataframe for station 641.0 was created.
# Aggregated dataframe for station 646.0 was created.
# Aggregated dataframe for station 558.0 was created.
# Aggregated dataframe for station 576.0 was created.
# Aggregated dataframe for station 632.0 was created.
# Aggregated dataframe for station 197.0 was created.
# Aggregated dataframe for station 489.0 was created.
# Aggregated dataframe for station 614.0 was created.
# Aggregated dataframe for station 565.0 was created.
# Aggregated dataframe for station 566.0 was created.
# Aggregated dataframe for station 625.0 was created.
# Aggregated dataframe for station 581.0 was created.
# Aggregated dataframe for station 616.0 was created.
# Aggregated dataframe for station 586.0 was created.
# Aggregated dataframe for station 587.0 was created.
# Aggregated dataframe for station 574.0 was created.
# Aggregated dataframe for station 535.0 was created.
# Aggregated dataframe for station 582.0 was created.
# Aggregated dataframe for station 683.0 was created.
# Aggregated dataframe for station 488.0 was created.
# Aggregated dataframe for station 606.0 was created.
# Aggregated dataframe for station 547.0 was created.
# Aggregated dataframe for station 526.0 was created.
# Aggregated dataframe for station 523.0 was created.
# Aggregated dataframe for station 522.0 was created.
# Aggregated dataframe for station 528.0 was created.
# Number of new dataframes: 645

# %%
# calling aggregated dataframe for pickup_station 27
# check if is_business_day imputed correctly
stations_hourly_dict[6].head(50)

## should we filter out pickups with high duration? i.e. > 1 day??
# Out:
#                      rental_counts  avg_rental_duration  is_business_day
# 2023-01-01 00:00:00            0.0                 0.00                0
# 2023-01-01 01:00:00            0.0                 0.00                0
# 2023-01-01 02:00:00            0.0                 0.00                0
# 2023-01-01 03:00:00            0.0                 0.00                0
# 2023-01-01 04:00:00            0.0                 0.00                0
# 2023-01-01 05:00:00            0.0                 0.00                0
# 2023-01-01 06:00:00            0.0                 0.00                0
# 2023-01-01 07:00:00            1.0                 6.31                0
# 2023-01-01 08:00:00            1.0                 6.21                0
# 2023-01-01 09:00:00            0.0                 0.00                0
# 2023-01-01 10:00:00            3.0                15.92                0
# 2023-01-01 11:00:00            1.0                 6.84                0
# 2023-01-01 12:00:00            3.0                19.26                0
# 2023-01-01 13:00:00            3.0                30.74                0
# 2023-01-01 14:00:00            4.0                17.32                0
# 2023-01-01 15:00:00            6.0                18.35                0
# 2023-01-01 16:00:00            1.0                 5.04                0
# 2023-01-01 17:00:00            4.0                10.72                0
# 2023-01-01 18:00:00            2.0                24.09                0
# 2023-01-01 19:00:00            3.0                20.32                0
# 2023-01-01 20:00:00            0.0                 0.00                0
# 2023-01-01 21:00:00            0.0                 0.00                0
# 2023-01-01 22:00:00            3.0                20.54                0
# 2023-01-01 23:00:00            1.0                13.61                0
# 2023-01-02 00:00:00            0.0                 0.00                1
# 2023-01-02 01:00:00            0.0                 0.00                1
# 2023-01-02 02:00:00            0.0                 0.00                1
# 2023-01-02 03:00:00            0.0                 0.00                1
# 2023-01-02 04:00:00            0.0                 0.00                1
# 2023-01-02 05:00:00            1.0                 3.64                1
# 2023-01-02 06:00:00            0.0                 0.00                1
# 2023-01-02 07:00:00            3.0                17.15                1
# 2023-01-02 08:00:00            9.0                12.14                1
# 2023-01-02 09:00:00            6.0                11.36                1
# 2023-01-02 10:00:00            6.0                18.25                1
# 2023-01-02 11:00:00            8.0                11.85                1
# 2023-01-02 12:00:00            6.0                14.41                1
# 2023-01-02 13:00:00            5.0                14.33                1
# 2023-01-02 14:00:00            9.0                17.58                1
# 2023-01-02 15:00:00            7.0                11.13                1
# 2023-01-02 16:00:00            2.0                21.96                1
# 2023-01-02 17:00:00           14.0                14.25                1
# 2023-01-02 18:00:00           18.0                20.18                1
# 2023-01-02 19:00:00           12.0                15.17                1
# 2023-01-02 20:00:00            6.0                26.18                1
# 2023-01-02 21:00:00            0.0                 0.00                1
# 2023-01-02 22:00:00            4.0                17.98                1
# 2023-01-02 23:00:00            0.0                 0.00                1
# 2023-01-03 00:00:00            0.0                 0.00                1
# 2023-01-03 01:00:00            0.0                 0.00                1

# %%
stations_hourly_dict[6].to_csv('st6_ecobici.csv')
station_6 = pd.read_csv('st6_ecobici.csv')
station_6
# Out:
#                Unnamed: 0  rental_counts  avg_rental_duration  is_business_day
# 0     2023-01-01 00:00:00            0.0                 0.00                0
# 1     2023-01-01 01:00:00            0.0                 0.00                0
# 2     2023-01-01 02:00:00            0.0                 0.00                0
# 3     2023-01-01 03:00:00            0.0                 0.00                0
# 4     2023-01-01 04:00:00            0.0                 0.00                0
# ...                   ...            ...                  ...              ...
# 9500  2024-01-31 20:00:00            7.0                17.41                1
# 9501  2024-01-31 21:00:00            7.0                12.78                1
# 9502  2024-01-31 22:00:00            9.0                15.53                1
# 9503  2024-01-31 23:00:00            1.0                 5.98                1
# 9504  2024-02-01 00:00:00            0.0                 0.00                1
#
# [9505 rows x 4 columns]

# %%
clean_eco_bici_df
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 0                  M        35  8908451              81  2022-09-03
# 1          undefined        29  5380423              56  2022-09-30
# 2          undefined        32  5218094              56  2022-09-30
# 3          undefined        25  7278658              56  2022-09-30
# 4                  M        48  4031258              22  2022-11-10
# ...              ...       ...      ...             ...         ...
# 13735448           M        26  4085452             111  2024-01-31
# 13735449           M        21  8516015             548  2024-01-31
# 13735450           M        28  2005171             150  2024-01-31
# 13735451           F        31  2132561             115  2024-01-31
# 13735452           M        35  2760585             115  2024-01-31
#
#             pickup_time  return_station return_date    return_time  \
# 0         18:45:42.3370              81  2023-02-02  19:09:36.7840
# 1              12:24:36              56  2023-11-24       15:13:34
# 2         13:17:30.6120              56  2023-02-09  13:14:13.9300
# 3         13:20:09.0510              56  2023-02-09  13:11:41.3290
# 4         21:26:19.3790              22  2023-02-02  19:11:23.2350
# ...                 ...             ...         ...            ...
# 13735448       23:53:22             111  2024-01-31       23:57:06
# 13735449       23:55:31             548  2024-01-31       23:59:05
# 13735450       23:56:03             150  2024-01-31       23:59:53
# 13735451       23:56:06             115  2024-01-31       23:58:25
# 13735452       23:56:09             115  2024-01-31       23:58:26
#
#                  pickup_datetime   hourly_aggregated         return_datetime  \
# 0        2022-09-03 18:45:42.337 2022-09-03 18:00:00 2023-02-02 19:09:36.784
# 1        2022-09-30 12:24:36.000 2022-09-30 12:00:00 2023-11-24 15:13:34.000
# 2        2022-09-30 13:17:30.612 2022-09-30 13:00:00 2023-02-09 13:14:13.930
# 3        2022-09-30 13:20:09.051 2022-09-30 13:00:00 2023-02-09 13:11:41.329
# 4        2022-11-10 21:26:19.379 2022-11-10 21:00:00 2023-02-02 19:11:23.235
# ...                          ...                 ...                     ...
# 13735448 2024-01-31 23:53:22.000 2024-01-31 23:00:00 2024-01-31 23:57:06.000
# 13735449 2024-01-31 23:55:31.000 2024-01-31 23:00:00 2024-01-31 23:59:05.000
# 13735450 2024-01-31 23:56:03.000 2024-01-31 23:00:00 2024-01-31 23:59:53.000
# 13735451 2024-01-31 23:56:06.000 2024-01-31 23:00:00 2024-01-31 23:58:25.000
# 13735452 2024-01-31 23:56:09.000 2024-01-31 23:00:00 2024-01-31 23:58:26.000
#
#                          duration  is_business_day
# 0        152 days 00:23:54.447000                0
# 1               420 days 02:48:58                1
# 2        131 days 23:56:43.318000                1
# 3        131 days 23:51:32.278000                1
# 4         83 days 21:45:03.856000                1
# ...                           ...              ...
# 13735448          0 days 00:03:44                1
# 13735449          0 days 00:03:34                1
# 13735450          0 days 00:03:50                1
# 13735451          0 days 00:02:19                1
# 13735452          0 days 00:02:17                1
#
# [13047307 rows x 14 columns]

# %% [markdown]
# ### incorporating/merging weather data

# %%
mexico_city_weather = pd.read_csv("DATA/open-meteo-hourly-mexico-city_2020-12-02_2024-01-31.csv", skiprows=3)
mexico_city_weather.drop(columns= ['snowfall (cm)','weather_code (wmo code)'], axis=1, inplace=True) # no snow in mexico city
data_frame_overview(mexico_city_weather)
# Out:
# Column names:
#  Index(['time', 'temperature_2m (°C)', 'relative_humidity_2m (%)',
#        'apparent_temperature (°C)', 'rain (mm)', 'cloud_cover (%)',
#        'wind_speed_10m (km/h)', 'is_day ()'],
#       dtype='object')
#
# Dimensions: (27744, 8)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27744 entries, 0 to 27743
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       27744 non-null  object
#  1   temperature_2m (°C)        27744 non-null  float64
#  2   relative_humidity_2m (%)   27744 non-null  int64
#  3   apparent_temperature (°C)  27744 non-null  float64
#  4   rain (mm)                  27744 non-null  float64
#  5   cloud_cover (%)            27744 non-null  int64
#  6   wind_speed_10m (km/h)      27744 non-null  float64
#  7   is_day ()                  27744 non-null  int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 1.7+ MB
# None
#                time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0  2020-12-02T00:00                 18.8                        43
# 1  2020-12-02T01:00                 17.1                        59
# 2  2020-12-02T02:00                 15.8                        60
# 3  2020-12-02T03:00                 14.3                        67
# 4  2020-12-02T04:00                 12.7                        76
# 5  2020-12-02T05:00                 11.6                        80
# 6  2020-12-02T06:00                 10.6                        83
# 7  2020-12-02T07:00                  9.9                        83
# 8  2020-12-02T08:00                  9.6                        79
# 9  2020-12-02T09:00                  8.7                        81
#
#    apparent_temperature (°C)  rain (mm)  cloud_cover (%)  \
# 0                       17.0        0.0               38
# 1                       16.3        0.0               22
# 2                       13.9        0.0               16
# 3                       12.4        0.0               12
# 4                       11.5        0.0                9
# 5                       10.5        0.0               18
# 6                        9.4        0.0               23
# 7                        8.5        0.0               25
# 8                        8.1        0.0               25
# 9                        7.0        0.0               28
#
#    wind_speed_10m (km/h)  is_day ()
# 0                    5.5          0
# 1                    3.5          0
# 2                    9.5          0
# 3                    9.7          0
# 4                    5.7          0
# 5                    5.1          0
# 6                    4.4          0
# 7                    4.3          0
# 8                    3.6          0
# 9                    4.3          0

# %%
weather_columns = {
    'time': 'hour', 
    'temperature_2m_(°c)': 'temperature_C', 
    'relative_humidity_2m_(%)': 'rel_humidity_perc',
    'apparent_temperature_(°c)': 'feels_like_temp_C', 
    'rain_(mm)': 'rain_mm', 
    'cloud_cover_(%)': 'cloud_cover_perc', 
    'wind_speed_10m_(km/h)': 'wind_speed_kmh',
    'is_day_()':'is_day'
}
mexico_city_weather.columns = [name.strip().replace(" ", "_").lower() for name in mexico_city_weather.columns]
mexico_city_weather.rename(columns=weather_columns, inplace=True)

# %%
mexico_city_weather
# Out:
#                    hour  temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 0      2020-12-02T00:00           18.8                 43               17.0
# 1      2020-12-02T01:00           17.1                 59               16.3
# 2      2020-12-02T02:00           15.8                 60               13.9
# 3      2020-12-02T03:00           14.3                 67               12.4
# 4      2020-12-02T04:00           12.7                 76               11.5
# ...                 ...            ...                ...                ...
# 27739  2024-01-31T19:00           18.8                 26               15.5
# 27740  2024-01-31T20:00           20.8                 20               17.2
# 27741  2024-01-31T21:00           21.7                 20               18.4
# 27742  2024-01-31T22:00           21.7                 20               18.3
# 27743  2024-01-31T23:00           21.4                 21               18.1
#
#        rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 0          0.0                38             5.5       0
# 1          0.0                22             3.5       0
# 2          0.0                16             9.5       0
# 3          0.0                12             9.7       0
# 4          0.0                 9             5.7       0
# ...        ...               ...             ...     ...
# 27739      0.0                75             6.6       1
# 27740      0.0                85             7.5       1
# 27741      0.0                79             6.9       1
# 27742      0.0                85             6.8       1
# 27743      0.0                62             6.5       1
#
# [27744 rows x 8 columns]

# %%
# reformat the hour column to match our aggregated ecobici df and set as index
mexico_city_weather['hour'] = pd.to_datetime(mexico_city_weather['hour'], format='%Y-%m-%dT%H:%M')
mexico_city_weather.set_index('hour', inplace=True)

# %%
# aggregate clean_eco_bici_df for general exploratory data analysis
eco_bici_hourly_count = clean_eco_bici_df.groupby('hourly_aggregated',as_index=False).agg(
        {'bike_id': 'count',
         'duration': 'mean',
        }
    )

# reformat df columns and duration values
eco_bici_hourly_count.rename(columns={'hourly_aggregated':'hour','bike_id':'rental_counts','duration':'avg_rental_duration'},inplace=True)
eco_bici_hourly_count.avg_rental_duration = eco_bici_hourly_count.avg_rental_duration.apply(
    lambda x: round(float(x.total_seconds() / 60) if isinstance(x, pd.Timedelta) else x, 2))

# reindex
eco_bici_hourly_count.set_index('hour', drop=False, inplace=True)
eco_bici_hourly_count = eco_bici_hourly_count.reindex(full_index)
eco_bici_hourly_count.fillna(0, inplace=True)

# add is_business_day column and pickup statation
eco_bici_hourly_count['is_business_day'] = pd.to_datetime(eco_bici_hourly_count['hour']).apply(
    lambda x: 1 if (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] and (x.weekday() < 5) else 0
)

eco_bici_hourly_count.drop('hour', axis=1, inplace=True)

data_frame_overview(eco_bici_hourly_count)
# Out:
# Column names:
#  Index(['rental_counts', 'avg_rental_duration', 'is_business_day'], dtype='object')
#
# Dimensions: (9505, 3)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9505 entries, 2023-01-01 00:00:00 to 2024-02-01 00:00:00
# Freq: H
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rental_counts        9505 non-null   float64
#  1   avg_rental_duration  9505 non-null   float64
#  2   is_business_day      9505 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 297.0 KB
# None
#                      rental_counts  avg_rental_duration  is_business_day
# 2023-01-01 00:00:00           59.0                17.60                0
# 2023-01-01 01:00:00            0.0                 0.00                0
# 2023-01-01 02:00:00            0.0                 0.00                0
# 2023-01-01 03:00:00            0.0                 0.00                0
# 2023-01-01 04:00:00            0.0                 0.00                0
# 2023-01-01 05:00:00           26.0                14.52                0
# 2023-01-01 06:00:00           43.0                22.39                0
# 2023-01-01 07:00:00           63.0                14.85                0
# 2023-01-01 08:00:00           78.0                25.75                0
# 2023-01-01 09:00:00          160.0                22.71                0

# %%
# concatenate weather df with eco_bici_hourly_count dataframe for general exploratory data analysis

hourly_weather_rentals = eco_bici_hourly_count.merge(mexico_city_weather, left_index=True, right_index=True, how='inner')

# %%
data_frame_overview(hourly_weather_rentals)
# Out:
# Column names:
#  Index(['rental_counts', 'avg_rental_duration', 'is_business_day',
#        'temperature_C', 'rel_humidity_perc', 'feels_like_temp_C', 'rain_mm',
#        'cloud_cover_perc', 'wind_speed_kmh', 'is_day'],
#       dtype='object')
#
# Dimensions: (9504, 10)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9504 entries, 2023-01-01 00:00:00 to 2024-01-31 23:00:00
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rental_counts        9504 non-null   float64
#  1   avg_rental_duration  9504 non-null   float64
#  2   is_business_day      9504 non-null   int64
#  3   temperature_C        9504 non-null   float64
#  4   rel_humidity_perc    9504 non-null   int64
#  5   feels_like_temp_C    9504 non-null   float64
#  6   rain_mm              9504 non-null   float64
#  7   cloud_cover_perc     9504 non-null   int64
#  8   wind_speed_kmh       9504 non-null   float64
#  9   is_day               9504 non-null   int64
# dtypes: float64(6), int64(4)
# memory usage: 816.8 KB
# None
#                      rental_counts  avg_rental_duration  is_business_day  \
# 2023-01-01 00:00:00           59.0                17.60                0
# 2023-01-01 01:00:00            0.0                 0.00                0
# 2023-01-01 02:00:00            0.0                 0.00                0
# 2023-01-01 03:00:00            0.0                 0.00                0
# 2023-01-01 04:00:00            0.0                 0.00                0
# 2023-01-01 05:00:00           26.0                14.52                0
# 2023-01-01 06:00:00           43.0                22.39                0
# 2023-01-01 07:00:00           63.0                14.85                0
# 2023-01-01 08:00:00           78.0                25.75                0
# 2023-01-01 09:00:00          160.0                22.71                0
#
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 2023-01-01 00:00:00           16.6                 65               15.9
# 2023-01-01 01:00:00           15.9                 62               14.2
# 2023-01-01 02:00:00           14.3                 66               12.3
# 2023-01-01 03:00:00           12.6                 75               11.3
# 2023-01-01 04:00:00           12.9                 65               11.7
# 2023-01-01 05:00:00           10.8                 77                9.4
# 2023-01-01 06:00:00            9.4                 84                7.4
# 2023-01-01 07:00:00            8.6                 86                6.3
# 2023-01-01 08:00:00            8.1                 87                6.0
# 2023-01-01 09:00:00            7.8                 86                6.0
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 2023-01-01 00:00:00      0.0                32             5.1       1
# 2023-01-01 01:00:00      0.0                23             9.6       0
# 2023-01-01 02:00:00      0.0                14            10.5       0
# 2023-01-01 03:00:00      0.0                 0             5.6       0
# 2023-01-01 04:00:00      0.0                 3             2.2       0
# 2023-01-01 05:00:00      0.0                 0             4.2       0
# 2023-01-01 06:00:00      0.0                 0             8.0       0
# 2023-01-01 07:00:00      0.0                 0             9.5       0
# 2023-01-01 08:00:00      0.0                 0             7.9       0
# 2023-01-01 09:00:00      0.0                 0             5.0       0

# %%
# for each station df in stations_hourly_dict, with key = station number
# merge weather df with aggregated station dataframes
# save the merged dfs into a stations_weather_rentals dictionary

#full_index = pd.date_range(start='2023-01-01 00:00:00', end='2024-02-01 00:00:00', freq='H')
stations_weather_rentals = {}

for key, value in stations_hourly_dict.items():
    merged_df = value.merge(mexico_city_weather, left_index=True, right_index=True, how='inner')
    stations_weather_rentals[key] = merged_df    
    print(f"Merged rental count and weather dataframe for station {key} was created.")
    
print(f"Number of new dataframes: {len(stations_weather_rentals)}")
# Out:
# Merged rental count and weather dataframe for station 7.0 was created.
# Merged rental count and weather dataframe for station 206.0 was created.
# Merged rental count and weather dataframe for station 215.0 was created.
# Merged rental count and weather dataframe for station 291.0 was created.
# Merged rental count and weather dataframe for station 546.0 was created.
# Merged rental count and weather dataframe for station 306.0 was created.
# Merged rental count and weather dataframe for station 65.0 was created.
# Merged rental count and weather dataframe for station 221.0 was created.
# Merged rental count and weather dataframe for station 394.0 was created.
# Merged rental count and weather dataframe for station 375.0 was created.
# Merged rental count and weather dataframe for station 74.0 was created.
# Merged rental count and weather dataframe for station 396.0 was created.
# Merged rental count and weather dataframe for station 136.0 was created.
# Merged rental count and weather dataframe for station 129.0 was created.
# Merged rental count and weather dataframe for station 283.0 was created.
# Merged rental count and weather dataframe for station 355.0 was created.
# Merged rental count and weather dataframe for station 12.0 was created.
# Merged rental count and weather dataframe for station 67.0 was created.
# Merged rental count and weather dataframe for station 187.0 was created.
# Merged rental count and weather dataframe for station 337.0 was created.
# Merged rental count and weather dataframe for station nan was created.
# Merged rental count and weather dataframe for station 503.0 was created.
# Merged rental count and weather dataframe for station 220.0 was created.
# Merged rental count and weather dataframe for station 43.0 was created.
# Merged rental count and weather dataframe for station 73.0 was created.
# Merged rental count and weather dataframe for station 59.0 was created.
# Merged rental count and weather dataframe for station 226.0 was created.
# Merged rental count and weather dataframe for station 372.0 was created.
# Merged rental count and weather dataframe for station 340.0 was created.
# Merged rental count and weather dataframe for station 174.0 was created.
# Merged rental count and weather dataframe for station 162.0 was created.
# Merged rental count and weather dataframe for station 163.0 was created.
# Merged rental count and weather dataframe for station 449.0 was created.
# Merged rental count and weather dataframe for station 64.0 was created.
# Merged rental count and weather dataframe for station 30.0 was created.
# Merged rental count and weather dataframe for station 398.0 was created.
# Merged rental count and weather dataframe for station 148.0 was created.
# Merged rental count and weather dataframe for station 61.0 was created.
# Merged rental count and weather dataframe for station 121.0 was created.
# Merged rental count and weather dataframe for station 32.0 was created.
# Merged rental count and weather dataframe for station 295.0 was created.
# Merged rental count and weather dataframe for station 551.0 was created.
# Merged rental count and weather dataframe for station 189.0 was created.
# Merged rental count and weather dataframe for station 31.0 was created.
# Merged rental count and weather dataframe for station 25.0 was created.
# Merged rental count and weather dataframe for station 52.0 was created.
# Merged rental count and weather dataframe for station 99.0 was created.
# Merged rental count and weather dataframe for station 86.0 was created.
# Merged rental count and weather dataframe for station 40.0 was created.
# Merged rental count and weather dataframe for station 69.0 was created.
# Merged rental count and weather dataframe for station 155.0 was created.
# Merged rental count and weather dataframe for station 76.0 was created.
# Merged rental count and weather dataframe for station 123.0 was created.
# Merged rental count and weather dataframe for station 393.0 was created.
# Merged rental count and weather dataframe for station 53.0 was created.
# Merged rental count and weather dataframe for station 507.0 was created.
# Merged rental count and weather dataframe for station 469.0 was created.
# Merged rental count and weather dataframe for station 11.0 was created.
# Merged rental count and weather dataframe for station 300.0 was created.
# Merged rental count and weather dataframe for station 550.0 was created.
# Merged rental count and weather dataframe for station 320.0 was created.
# Merged rental count and weather dataframe for station 132.0 was created.
# Merged rental count and weather dataframe for station 294.0 was created.
# Merged rental count and weather dataframe for station 41.0 was created.
# Merged rental count and weather dataframe for station 422.0 was created.
# Merged rental count and weather dataframe for station 280.0 was created.
# Merged rental count and weather dataframe for station 315.0 was created.
# Merged rental count and weather dataframe for station 1.0 was created.
# Merged rental count and weather dataframe for station 378.0 was created.
# Merged rental count and weather dataframe for station 114.0 was created.
# Merged rental count and weather dataframe for station 281.0 was created.
# Merged rental count and weather dataframe for station 81.0 was created.
# Merged rental count and weather dataframe for station 142.0 was created.
# Merged rental count and weather dataframe for station 554.0 was created.
# Merged rental count and weather dataframe for station 290.0 was created.
# Merged rental count and weather dataframe for station 208.0 was created.
# Merged rental count and weather dataframe for station 258.0 was created.
# Merged rental count and weather dataframe for station 341.0 was created.
# Merged rental count and weather dataframe for station 15.0 was created.
# Merged rental count and weather dataframe for station 16.0 was created.
# Merged rental count and weather dataframe for station 447.0 was created.
# Merged rental count and weather dataframe for station 82.0 was created.
# Merged rental count and weather dataframe for station 103.0 was created.
# Merged rental count and weather dataframe for station 92.0 was created.
# Merged rental count and weather dataframe for station 60.0 was created.
# Merged rental count and weather dataframe for station 80.0 was created.
# Merged rental count and weather dataframe for station 111.0 was created.
# Merged rental count and weather dataframe for station 420.0 was created.
# Merged rental count and weather dataframe for station 234.0 was created.
# Merged rental count and weather dataframe for station 223.0 was created.
# Merged rental count and weather dataframe for station 18.0 was created.
# Merged rental count and weather dataframe for station 90.0 was created.
# Merged rental count and weather dataframe for station 24.0 was created.
# Merged rental count and weather dataframe for station 248.0 was created.
# Merged rental count and weather dataframe for station 135.0 was created.
# Merged rental count and weather dataframe for station 359.0 was created.
# Merged rental count and weather dataframe for station 23.0 was created.
# Merged rental count and weather dataframe for station 96.0 was created.
# Merged rental count and weather dataframe for station 462.0 was created.
# Merged rental count and weather dataframe for station 270.0 was created.
# Merged rental count and weather dataframe for station 70.0 was created.
# Merged rental count and weather dataframe for station 54.0 was created.
# Merged rental count and weather dataframe for station 133.0 was created.
# Merged rental count and weather dataframe for station 105.0 was created.
# Merged rental count and weather dataframe for station 450.0 was created.
# Merged rental count and weather dataframe for station 427.0 was created.
# Merged rental count and weather dataframe for station 87.0 was created.
# Merged rental count and weather dataframe for station 164.0 was created.
# Merged rental count and weather dataframe for station 260.0 was created.
# Merged rental count and weather dataframe for station 144.0 was created.
# Merged rental count and weather dataframe for station 183.0 was created.
# Merged rental count and weather dataframe for station 143.0 was created.
# Merged rental count and weather dataframe for station 444.0 was created.
# Merged rental count and weather dataframe for station 285.0 was created.
# Merged rental count and weather dataframe for station 325.0 was created.
# Merged rental count and weather dataframe for station 310.0 was created.
# Merged rental count and weather dataframe for station 412.0 was created.
# Merged rental count and weather dataframe for station 150.0 was created.
# Merged rental count and weather dataframe for station 10.0 was created.
# Merged rental count and weather dataframe for station 541.0 was created.
# Merged rental count and weather dataframe for station 36.0 was created.
# Merged rental count and weather dataframe for station 154.0 was created.
# Merged rental count and weather dataframe for station 263.0 was created.
# Merged rental count and weather dataframe for station 324.0 was created.
# Merged rental count and weather dataframe for station 278.0 was created.
# Merged rental count and weather dataframe for station 321.0 was created.
# Merged rental count and weather dataframe for station 85.0 was created.
# Merged rental count and weather dataframe for station 33.0 was created.
# Merged rental count and weather dataframe for station 366.0 was created.
# Merged rental count and weather dataframe for station 499.0 was created.
# Merged rental count and weather dataframe for station 160.0 was created.
# Merged rental count and weather dataframe for station 17.0 was created.
# Merged rental count and weather dataframe for station 171.0 was created.
# Merged rental count and weather dataframe for station 255.0 was created.
# Merged rental count and weather dataframe for station 179.0 was created.
# Merged rental count and weather dataframe for station 145.0 was created.
# Merged rental count and weather dataframe for station 480.0 was created.
# Merged rental count and weather dataframe for station 555.0 was created.
# Merged rental count and weather dataframe for station 329.0 was created.
# Merged rental count and weather dataframe for station 37.0 was created.
# Merged rental count and weather dataframe for station 147.0 was created.
# Merged rental count and weather dataframe for station 38.0 was created.
# Merged rental count and weather dataframe for station 151.0 was created.
# Merged rental count and weather dataframe for station 140.0 was created.
# Merged rental count and weather dataframe for station 77.0 was created.
# Merged rental count and weather dataframe for station 384.0 was created.
# Merged rental count and weather dataframe for station 504.0 was created.
# Merged rental count and weather dataframe for station 354.0 was created.
# Merged rental count and weather dataframe for station 2.0 was created.
# Merged rental count and weather dataframe for station 318.0 was created.
# Merged rental count and weather dataframe for station 3.0 was created.
# Merged rental count and weather dataframe for station 175.0 was created.
# Merged rental count and weather dataframe for station 49.0 was created.
# Merged rental count and weather dataframe for station 185.0 was created.
# Merged rental count and weather dataframe for station 244.0 was created.
# Merged rental count and weather dataframe for station 138.0 was created.
# Merged rental count and weather dataframe for station 401.0 was created.
# Merged rental count and weather dataframe for station 351.0 was created.
# Merged rental count and weather dataframe for station 141.0 was created.
# Merged rental count and weather dataframe for station 553.0 was created.
# Merged rental count and weather dataframe for station 55.0 was created.
# Merged rental count and weather dataframe for station 72.0 was created.
# Merged rental count and weather dataframe for station 453.0 was created.
# Merged rental count and weather dataframe for station 478.0 was created.
# Merged rental count and weather dataframe for station 409.0 was created.
# Merged rental count and weather dataframe for station 405.0 was created.
# Merged rental count and weather dataframe for station 308.0 was created.
# Merged rental count and weather dataframe for station 470.0 was created.
# Merged rental count and weather dataframe for station 194.0 was created.
# Merged rental count and weather dataframe for station 42.0 was created.
# Merged rental count and weather dataframe for station 464.0 was created.
# Merged rental count and weather dataframe for station 173.0 was created.
# Merged rental count and weather dataframe for station 137.0 was created.
# Merged rental count and weather dataframe for station 477.0 was created.
# Merged rental count and weather dataframe for station 84.0 was created.
# Merged rental count and weather dataframe for station 27.0 was created.
# Merged rental count and weather dataframe for station 122.0 was created.
# Merged rental count and weather dataframe for station 28.0 was created.
# Merged rental count and weather dataframe for station 156.0 was created.
# Merged rental count and weather dataframe for station 207.0 was created.
# Merged rental count and weather dataframe for station 276.0 was created.
# Merged rental count and weather dataframe for station 229.0 was created.
# Merged rental count and weather dataframe for station 430.0 was created.
# Merged rental count and weather dataframe for station 4.0 was created.
# Merged rental count and weather dataframe for station 139.0 was created.
# Merged rental count and weather dataframe for station 704.0 was created.
# Merged rental count and weather dataframe for station 298.0 was created.
# Merged rental count and weather dataframe for station 277.0 was created.
# Merged rental count and weather dataframe for station 439.0 was created.
# Merged rental count and weather dataframe for station 432.0 was created.
# Merged rental count and weather dataframe for station 365.0 was created.
# Merged rental count and weather dataframe for station 118.0 was created.
# Merged rental count and weather dataframe for station 667.0 was created.
# Merged rental count and weather dataframe for station 402.0 was created.
# Merged rental count and weather dataframe for station 352.0 was created.
# Merged rental count and weather dataframe for station 543.0 was created.
# Merged rental count and weather dataframe for station 374.0 was created.
# Merged rental count and weather dataframe for station 22.0 was created.
# Merged rental count and weather dataframe for station 225.0 was created.
# Merged rental count and weather dataframe for station 182.0 was created.
# Merged rental count and weather dataframe for station 166.0 was created.
# Merged rental count and weather dataframe for station 335.0 was created.
# Merged rental count and weather dataframe for station 549.0 was created.
# Merged rental count and weather dataframe for station 125.0 was created.
# Merged rental count and weather dataframe for station 465.0 was created.
# Merged rental count and weather dataframe for station 358.0 was created.
# Merged rental count and weather dataframe for station 485.0 was created.
# Merged rental count and weather dataframe for station 102.0 was created.
# Merged rental count and weather dataframe for station 181.0 was created.
# Merged rental count and weather dataframe for station 482.0 was created.
# Merged rental count and weather dataframe for station 200.0 was created.
# Merged rental count and weather dataframe for station 360.0 was created.
# Merged rental count and weather dataframe for station 536.0 was created.
# Merged rental count and weather dataframe for station 211.0 was created.
# Merged rental count and weather dataframe for station 347.0 was created.
# Merged rental count and weather dataframe for station 256.0 was created.
# Merged rental count and weather dataframe for station 492.0 was created.
# Merged rental count and weather dataframe for station 131.0 was created.
# Merged rental count and weather dataframe for station 51.0 was created.
# Merged rental count and weather dataframe for station 302.0 was created.
# Merged rental count and weather dataframe for station 112.0 was created.
# Merged rental count and weather dataframe for station 9.0 was created.
# Merged rental count and weather dataframe for station 152.0 was created.
# Merged rental count and weather dataframe for station 172.0 was created.
# Merged rental count and weather dataframe for station 126.0 was created.
# Merged rental count and weather dataframe for station 305.0 was created.
# Merged rental count and weather dataframe for station 161.0 was created.
# Merged rental count and weather dataframe for station 134.0 was created.
# Merged rental count and weather dataframe for station 46.0 was created.
# Merged rental count and weather dataframe for station 204.0 was created.
# Merged rental count and weather dataframe for station 399.0 was created.
# Merged rental count and weather dataframe for station 460.0 was created.
# Merged rental count and weather dataframe for station 169.0 was created.
# Merged rental count and weather dataframe for station 317.0 was created.
# Merged rental count and weather dataframe for station 116.0 was created.
# Merged rental count and weather dataframe for station 296.0 was created.
# Merged rental count and weather dataframe for station 246.0 was created.
# Merged rental count and weather dataframe for station 20.0 was created.
# Merged rental count and weather dataframe for station 253.0 was created.
# Merged rental count and weather dataframe for station 361.0 was created.
# Merged rental count and weather dataframe for station 476.0 was created.
# Merged rental count and weather dataframe for station 104.0 was created.
# Merged rental count and weather dataframe for station 495.0 was created.
# Merged rental count and weather dataframe for station 251.0 was created.
# Merged rental count and weather dataframe for station 323.0 was created.
# Merged rental count and weather dataframe for station 39.0 was created.
# Merged rental count and weather dataframe for station 404.0 was created.
# Merged rental count and weather dataframe for station 288.0 was created.
# Merged rental count and weather dataframe for station 71.0 was created.
# Merged rental count and weather dataframe for station 124.0 was created.
# Merged rental count and weather dataframe for station 286.0 was created.
# Merged rental count and weather dataframe for station 356.0 was created.
# Merged rental count and weather dataframe for station 669.0 was created.
# Merged rental count and weather dataframe for station 496.0 was created.
# Merged rental count and weather dataframe for station 506.0 was created.
# Merged rental count and weather dataframe for station 483.0 was created.
# Merged rental count and weather dataframe for station 34.0 was created.
# Merged rental count and weather dataframe for station 217.0 was created.
# Merged rental count and weather dataframe for station 14.0 was created.
# Merged rental count and weather dataframe for station 249.0 was created.
# Merged rental count and weather dataframe for station 293.0 was created.
# Merged rental count and weather dataframe for station 369.0 was created.
# Merged rental count and weather dataframe for station 119.0 was created.
# Merged rental count and weather dataframe for station 670.0 was created.
# Merged rental count and weather dataframe for station 381.0 was created.
# Merged rental count and weather dataframe for station 6.0 was created.
# Merged rental count and weather dataframe for station 195.0 was created.
# Merged rental count and weather dataframe for station 247.0 was created.
# Merged rental count and weather dataframe for station 466.0 was created.
# Merged rental count and weather dataframe for station 313.0 was created.
# Merged rental count and weather dataframe for station 497.0 was created.
# Merged rental count and weather dataframe for station 205.0 was created.
# Merged rental count and weather dataframe for station 117.0 was created.
# Merged rental count and weather dataframe for station 380.0 was created.
# Merged rental count and weather dataframe for station 419.0 was created.
# Merged rental count and weather dataframe for station 467.0 was created.
# Merged rental count and weather dataframe for station 297.0 was created.
# Merged rental count and weather dataframe for station 657.0 was created.
# Merged rental count and weather dataframe for station 231.0 was created.
# Merged rental count and weather dataframe for station 423.0 was created.
# Merged rental count and weather dataframe for station 232.0 was created.
# Merged rental count and weather dataframe for station 79.0 was created.
# Merged rental count and weather dataframe for station 5.0 was created.
# Merged rental count and weather dataframe for station 214.0 was created.
# Merged rental count and weather dataframe for station 170.0 was created.
# Merged rental count and weather dataframe for station 97.0 was created.
# Merged rental count and weather dataframe for station 250.0 was created.
# Merged rental count and weather dataframe for station 110.0 was created.
# Merged rental count and weather dataframe for station 385.0 was created.
# Merged rental count and weather dataframe for station 282.0 was created.
# Merged rental count and weather dataframe for station 48.0 was created.
# Merged rental count and weather dataframe for station 120.0 was created.
# Merged rental count and weather dataframe for station 188.0 was created.
# Merged rental count and weather dataframe for station 66.0 was created.
# Merged rental count and weather dataframe for station 243.0 was created.
# Merged rental count and weather dataframe for station 327.0 was created.
# Merged rental count and weather dataframe for station 414.0 was created.
# Merged rental count and weather dataframe for station 343.0 was created.
# Merged rental count and weather dataframe for station 328.0 was created.
# Merged rental count and weather dataframe for station 259.0 was created.
# Merged rental count and weather dataframe for station 367.0 was created.
# Merged rental count and weather dataframe for station 254.0 was created.
# Merged rental count and weather dataframe for station 257.0 was created.
# Merged rental count and weather dataframe for station 287.0 was created.
# Merged rental count and weather dataframe for station 190.0 was created.
# Merged rental count and weather dataframe for station 212.0 was created.
# Merged rental count and weather dataframe for station 98.0 was created.
# Merged rental count and weather dataframe for station 387.0 was created.
# Merged rental count and weather dataframe for station 165.0 was created.
# Merged rental count and weather dataframe for station 149.0 was created.
# Merged rental count and weather dataframe for station 265.0 was created.
# Merged rental count and weather dataframe for station 91.0 was created.
# Merged rental count and weather dataframe for station 395.0 was created.
# Merged rental count and weather dataframe for station 127.0 was created.
# Merged rental count and weather dataframe for station 68.0 was created.
# Merged rental count and weather dataframe for station 301.0 was created.
# Merged rental count and weather dataframe for station 348.0 was created.
# Merged rental count and weather dataframe for station 336.0 was created.
# Merged rental count and weather dataframe for station 201.0 was created.
# Merged rental count and weather dataframe for station 434.0 was created.
# Merged rental count and weather dataframe for station 377.0 was created.
# Merged rental count and weather dataframe for station 474.0 was created.
# Merged rental count and weather dataframe for station 210.0 was created.
# Merged rental count and weather dataframe for station 153.0 was created.
# Merged rental count and weather dataframe for station 299.0 was created.
# Merged rental count and weather dataframe for station 146.0 was created.
# Merged rental count and weather dataframe for station 184.0 was created.
# Merged rental count and weather dataframe for station 115.0 was created.
# Merged rental count and weather dataframe for station 428.0 was created.
# Merged rental count and weather dataframe for station 330.0 was created.
# Merged rental count and weather dataframe for station 452.0 was created.
# Merged rental count and weather dataframe for station 62.0 was created.
# Merged rental count and weather dataframe for station 545.0 was created.
# Merged rental count and weather dataframe for station 471.0 was created.
# Merged rental count and weather dataframe for station 491.0 was created.
# Merged rental count and weather dataframe for station 658.0 was created.
# Merged rental count and weather dataframe for station 481.0 was created.
# Merged rental count and weather dataframe for station 75.0 was created.
# Merged rental count and weather dataframe for station 186.0 was created.
# Merged rental count and weather dataframe for station 331.0 was created.
# Merged rental count and weather dataframe for station 180.0 was created.
# Merged rental count and weather dataframe for station 424.0 was created.
# Merged rental count and weather dataframe for station 459.0 was created.
# Merged rental count and weather dataframe for station 706.0 was created.
# Merged rental count and weather dataframe for station 8.0 was created.
# Merged rental count and weather dataframe for station 47.0 was created.
# Merged rental count and weather dataframe for station 56.0 was created.
# Merged rental count and weather dataframe for station 219.0 was created.
# Merged rental count and weather dataframe for station 203.0 was created.
# Merged rental count and weather dataframe for station 314.0 was created.
# Merged rental count and weather dataframe for station 429.0 was created.
# Merged rental count and weather dataframe for station 228.0 was created.
# Merged rental count and weather dataframe for station 333.0 was created.
# Merged rental count and weather dataframe for station 326.0 was created.
# Merged rental count and weather dataframe for station 448.0 was created.
# Merged rental count and weather dataframe for station 178.0 was created.
# Merged rental count and weather dataframe for station 312.0 was created.
# Merged rental count and weather dataframe for station 552.0 was created.
# Merged rental count and weather dataframe for station 218.0 was created.
# Merged rental count and weather dataframe for station 540.0 was created.
# Merged rental count and weather dataframe for station 413.0 was created.
# Merged rental count and weather dataframe for station 373.0 was created.
# Merged rental count and weather dataframe for station 63.0 was created.
# Merged rental count and weather dataframe for station 437.0 was created.
# Merged rental count and weather dataframe for station 668.0 was created.
# Merged rental count and weather dataframe for station 392.0 was created.
# Merged rental count and weather dataframe for station 415.0 was created.
# Merged rental count and weather dataframe for station 407.0 was created.
# Merged rental count and weather dataframe for station 29.0 was created.
# Merged rental count and weather dataframe for station 168.0 was created.
# Merged rental count and weather dataframe for station 233.0 was created.
# Merged rental count and weather dataframe for station 673.0 was created.
# Merged rental count and weather dataframe for station 338.0 was created.
# Merged rental count and weather dataframe for station 209.0 was created.
# Merged rental count and weather dataframe for station 83.0 was created.
# Merged rental count and weather dataframe for station 50.0 was created.
# Merged rental count and weather dataframe for station 438.0 was created.
# Merged rental count and weather dataframe for station 93.0 was created.
# Merged rental count and weather dataframe for station 332.0 was created.
# Merged rental count and weather dataframe for station 472.0 was created.
# Merged rental count and weather dataframe for station 242.0 was created.
# Merged rental count and weather dataframe for station 26.0 was created.
# Merged rental count and weather dataframe for station 433.0 was created.
# Merged rental count and weather dataframe for station 362.0 was created.
# Merged rental count and weather dataframe for station 279.0 was created.
# Merged rental count and weather dataframe for station 130.0 was created.
# Merged rental count and weather dataframe for station 389.0 was created.
# Merged rental count and weather dataframe for station 475.0 was created.
# Merged rental count and weather dataframe for station 334.0 was created.
# Merged rental count and weather dataframe for station 196.0 was created.
# Merged rental count and weather dataframe for station 486.0 was created.
# Merged rental count and weather dataframe for station 455.0 was created.
# Merged rental count and weather dataframe for station 113.0 was created.
# Merged rental count and weather dataframe for station 157.0 was created.
# Merged rental count and weather dataframe for station 322.0 was created.
# Merged rental count and weather dataframe for station 473.0 was created.
# Merged rental count and weather dataframe for station 57.0 was created.
# Merged rental count and weather dataframe for station 386.0 was created.
# Merged rental count and weather dataframe for station 703.0 was created.
# Merged rental count and weather dataframe for station 339.0 was created.
# Merged rental count and weather dataframe for station 709.0 was created.
# Merged rental count and weather dataframe for station 371.0 was created.
# Merged rental count and weather dataframe for station 78.0 was created.
# Merged rental count and weather dataframe for station 128.0 was created.
# Merged rental count and weather dataframe for station 227.0 was created.
# Merged rental count and weather dataframe for station 241.0 was created.
# Merged rental count and weather dataframe for station 363.0 was created.
# Merged rental count and weather dataframe for station 342.0 was created.
# Merged rental count and weather dataframe for station 458.0 was created.
# Merged rental count and weather dataframe for station 417.0 was created.
# Merged rental count and weather dataframe for station 45.0 was created.
# Merged rental count and weather dataframe for station 370.0 was created.
# Merged rental count and weather dataframe for station 58.0 was created.
# Merged rental count and weather dataframe for station 461.0 was created.
# Merged rental count and weather dataframe for station 35.0 was created.
# Merged rental count and weather dataframe for station 349.0 was created.
# Merged rental count and weather dataframe for station 502.0 was created.
# Merged rental count and weather dataframe for station 100.0 was created.
# Merged rental count and weather dataframe for station 284.0 was created.
# Merged rental count and weather dataframe for station 167.0 was created.
# Merged rental count and weather dataframe for station 659.0 was created.
# Merged rental count and weather dataframe for station 239.0 was created.
# Merged rental count and weather dataframe for station 421.0 was created.
# Merged rental count and weather dataframe for station 44.0 was created.
# Merged rental count and weather dataframe for station 262.0 was created.
# Merged rental count and weather dataframe for station 316.0 was created.
# Merged rental count and weather dataframe for station 479.0 was created.
# Merged rental count and weather dataframe for station 292.0 was created.
# Merged rental count and weather dataframe for station 457.0 was created.
# Merged rental count and weather dataframe for station 454.0 was created.
# Merged rental count and weather dataframe for station 307.0 was created.
# Merged rental count and weather dataframe for station 656.0 was created.
# Merged rental count and weather dataframe for station 319.0 was created.
# Merged rental count and weather dataframe for station 357.0 was created.
# Merged rental count and weather dataframe for station 660.0 was created.
# Merged rental count and weather dataframe for station 498.0 was created.
# Merged rental count and weather dataframe for station 199.0 was created.
# Merged rental count and weather dataframe for station 245.0 was created.
# Merged rental count and weather dataframe for station 304.0 was created.
# Merged rental count and weather dataframe for station 109.0 was created.
# Merged rental count and weather dataframe for station 198.0 was created.
# Merged rental count and weather dataframe for station 230.0 was created.
# Merged rental count and weather dataframe for station 177.0 was created.
# Merged rental count and weather dataframe for station 224.0 was created.
# Merged rental count and weather dataframe for station 345.0 was created.
# Merged rental count and weather dataframe for station 309.0 was created.
# Merged rental count and weather dataframe for station 19.0 was created.
# Merged rental count and weather dataframe for station 191.0 was created.
# Merged rental count and weather dataframe for station 216.0 was created.
# Merged rental count and weather dataframe for station 252.0 was created.
# Merged rental count and weather dataframe for station 451.0 was created.
# Merged rental count and weather dataframe for station 537.0 was created.
# Merged rental count and weather dataframe for station 353.0 was created.
# Merged rental count and weather dataframe for station 21.0 was created.
# Merged rental count and weather dataframe for station 672.0 was created.
# Merged rental count and weather dataframe for station 176.0 was created.
# Merged rental count and weather dataframe for station 397.0 was created.
# Merged rental count and weather dataframe for station 416.0 was created.
# Merged rental count and weather dataframe for station 346.0 was created.
# Merged rental count and weather dataframe for station 202.0 was created.
# Merged rental count and weather dataframe for station 436.0 was created.
# Merged rental count and weather dataframe for station 222.0 was created.
# Merged rental count and weather dataframe for station 261.0 was created.
# Merged rental count and weather dataframe for station 13.0 was created.
# Merged rental count and weather dataframe for station 240.0 was created.
# Merged rental count and weather dataframe for station 441.0 was created.
# Merged rental count and weather dataframe for station 213.0 was created.
# Merged rental count and weather dataframe for station 443.0 was created.
# Merged rental count and weather dataframe for station 94.0 was created.
# Merged rental count and weather dataframe for station 425.0 was created.
# Merged rental count and weather dataframe for station 468.0 was created.
# Merged rental count and weather dataframe for station 702.0 was created.
# Merged rental count and weather dataframe for station 89.0 was created.
# Merged rental count and weather dataframe for station 88.0 was created.
# Merged rental count and weather dataframe for station 95.0 was created.
# Merged rental count and weather dataframe for station 456.0 was created.
# Merged rental count and weather dataframe for station 708.0 was created.
# Merged rental count and weather dataframe for station 303.0 was created.
# Merged rental count and weather dataframe for station 442.0 was created.
# Merged rental count and weather dataframe for station 700.0 was created.
# Merged rental count and weather dataframe for station 1000.0 was created.
# Merged rental count and weather dataframe for station 626.0 was created.
# Merged rental count and weather dataframe for station 696.0 was created.
# Merged rental count and weather dataframe for station 615.0 was created.
# Merged rental count and weather dataframe for station 597.0 was created.
# Merged rental count and weather dataframe for station 694.0 was created.
# Merged rental count and weather dataframe for station 630.0 was created.
# Merged rental count and weather dataframe for station 617.0 was created.
# Merged rental count and weather dataframe for station 691.0 was created.
# Merged rental count and weather dataframe for station 689.0 was created.
# Merged rental count and weather dataframe for station 692.0 was created.
# Merged rental count and weather dataframe for station 701.0 was created.
# Merged rental count and weather dataframe for station 618.0 was created.
# Merged rental count and weather dataframe for station 612.0 was created.
# Merged rental count and weather dataframe for station 661.0 was created.
# Merged rental count and weather dataframe for station 652.0 was created.
# Merged rental count and weather dataframe for station 688.0 was created.
# Merged rental count and weather dataframe for station 629.0 was created.
# Merged rental count and weather dataframe for station 651.0 was created.
# Merged rental count and weather dataframe for station 649.0 was created.
# Merged rental count and weather dataframe for station 602.0 was created.
# Merged rental count and weather dataframe for station 624.0 was created.
# Merged rental count and weather dataframe for station 611.0 was created.
# Merged rental count and weather dataframe for station 637.0 was created.
# Merged rental count and weather dataframe for station 639.0 was created.
# Merged rental count and weather dataframe for station 633.0 was created.
# Merged rental count and weather dataframe for station 592.0 was created.
# Merged rental count and weather dataframe for station 619.0 was created.
# Merged rental count and weather dataframe for station 623.0 was created.
# Merged rental count and weather dataframe for station 620.0 was created.
# Merged rental count and weather dataframe for station 562.0 was created.
# Merged rental count and weather dataframe for station 559.0 was created.
# Merged rental count and weather dataframe for station 634.0 was created.
# Merged rental count and weather dataframe for station 589.0 was created.
# Merged rental count and weather dataframe for station 560.0 was created.
# Merged rental count and weather dataframe for station 579.0 was created.
# Merged rental count and weather dataframe for station 568.0 was created.
# Merged rental count and weather dataframe for station 564.0 was created.
# Merged rental count and weather dataframe for station 577.0 was created.
# Merged rental count and weather dataframe for station 609.0 was created.
# Merged rental count and weather dataframe for station 567.0 was created.
# Merged rental count and weather dataframe for station 604.0 was created.
# Merged rental count and weather dataframe for station 494.0 was created.
# Merged rental count and weather dataframe for station 573.0 was created.
# Merged rental count and weather dataframe for station 501.0 was created.
# Merged rental count and weather dataframe for station 571.0 was created.
# Merged rental count and weather dataframe for station 580.0 was created.
# Merged rental count and weather dataframe for station 569.0 was created.
# Merged rental count and weather dataframe for station 643.0 was created.
# Merged rental count and weather dataframe for station 603.0 was created.
# Merged rental count and weather dataframe for station 578.0 was created.
# Merged rental count and weather dataframe for station 645.0 was created.
# Merged rental count and weather dataframe for station 563.0 was created.
# Merged rental count and weather dataframe for station 697.0 was created.
# Merged rental count and weather dataframe for station 575.0 was created.
# Merged rental count and weather dataframe for station 590.0 was created.
# Merged rental count and weather dataframe for station 556.0 was created.
# Merged rental count and weather dataframe for station 584.0 was created.
# Merged rental count and weather dataframe for station 463.0 was created.
# Merged rental count and weather dataframe for station 650.0 was created.
# Merged rental count and weather dataframe for station 679.0 was created.
# Merged rental count and weather dataframe for station 678.0 was created.
# Merged rental count and weather dataframe for station 664.0 was created.
# Merged rental count and weather dataframe for station 666.0 was created.
# Merged rental count and weather dataframe for station 663.0 was created.
# Merged rental count and weather dataframe for station 662.0 was created.
# Merged rental count and weather dataframe for station 686.0 was created.
# Merged rental count and weather dataframe for station 525.0 was created.
# Merged rental count and weather dataframe for station 527.0 was created.
# Merged rental count and weather dataframe for station 521.0 was created.
# Merged rental count and weather dataframe for station 519.0 was created.
# Merged rental count and weather dataframe for station 518.0 was created.
# Merged rental count and weather dataframe for station 517.0 was created.
# Merged rental count and weather dataframe for station 516.0 was created.
# Merged rental count and weather dataframe for station 531.0 was created.
# Merged rental count and weather dataframe for station 514.0 was created.
# Merged rental count and weather dataframe for station 655.0 was created.
# Merged rental count and weather dataframe for station 684.0 was created.
# Merged rental count and weather dataframe for station 665.0 was created.
# Merged rental count and weather dataframe for station 635.0 was created.
# Merged rental count and weather dataframe for station 613.0 was created.
# Merged rental count and weather dataframe for station 631.0 was created.
# Merged rental count and weather dataframe for station 594.0 was created.
# Merged rental count and weather dataframe for station 628.0 was created.
# Merged rental count and weather dataframe for station 557.0 was created.
# Merged rental count and weather dataframe for station 687.0 was created.
# Merged rental count and weather dataframe for station 512.0 was created.
# Merged rental count and weather dataframe for station 510.0 was created.
# Merged rental count and weather dataframe for station 548.0 was created.
# Merged rental count and weather dataframe for station 608.0 was created.
# Merged rental count and weather dataframe for station 539.0 was created.
# Merged rental count and weather dataframe for station 622.0 was created.
# Merged rental count and weather dataframe for station 642.0 was created.
# Merged rental count and weather dataframe for station 4422222.0 was created.
# Merged rental count and weather dataframe for station 595.0 was created.
# Merged rental count and weather dataframe for station 585.0 was created.
# Merged rental count and weather dataframe for station 561.0 was created.
# Merged rental count and weather dataframe for station 636.0 was created.
# Merged rental count and weather dataframe for station 596.0 was created.
# Merged rental count and weather dataframe for station 621.0 was created.
# Merged rental count and weather dataframe for station 598.0 was created.
# Merged rental count and weather dataframe for station 698.0 was created.
# Merged rental count and weather dataframe for station 607.0 was created.
# Merged rental count and weather dataframe for station 685.0 was created.
# Merged rental count and weather dataframe for station 699.0 was created.
# Merged rental count and weather dataframe for station 671.0 was created.
# Merged rental count and weather dataframe for station 542.0 was created.
# Merged rental count and weather dataframe for station 610.0 was created.
# Merged rental count and weather dataframe for station 493.0 was created.
# Merged rental count and weather dataframe for station 500.0 was created.
# Merged rental count and weather dataframe for station 583.0 was created.
# Merged rental count and weather dataframe for station 599.0 was created.
# Merged rental count and weather dataframe for station 644.0 was created.
# Merged rental count and weather dataframe for station 572.0 was created.
# Merged rental count and weather dataframe for station 591.0 was created.
# Merged rental count and weather dataframe for station 601.0 was created.
# Merged rental count and weather dataframe for station 695.0 was created.
# Merged rental count and weather dataframe for station 640.0 was created.
# Merged rental count and weather dataframe for station 484.0 was created.
# Merged rental count and weather dataframe for station 593.0 was created.
# Merged rental count and weather dataframe for station 490.0 was created.
# Merged rental count and weather dataframe for station 544.0 was created.
# Merged rental count and weather dataframe for station 106.0 was created.
# Merged rental count and weather dataframe for station 707.0 was created.
# Merged rental count and weather dataframe for station 693.0 was created.
# Merged rental count and weather dataframe for station 538.0 was created.
# Merged rental count and weather dataframe for station 487.0 was created.
# Merged rental count and weather dataframe for station 654.0 was created.
# Merged rental count and weather dataframe for station 648.0 was created.
# Merged rental count and weather dataframe for station 570.0 was created.
# Merged rental count and weather dataframe for station 674.0 was created.
# Merged rental count and weather dataframe for station 605.0 was created.
# Merged rental count and weather dataframe for station 653.0 was created.
# Merged rental count and weather dataframe for station 705.0 was created.
# Merged rental count and weather dataframe for station 600.0 was created.
# Merged rental count and weather dataframe for station 638.0 was created.
# Merged rental count and weather dataframe for station 505.0 was created.
# Merged rental count and weather dataframe for station 690.0 was created.
# Merged rental count and weather dataframe for station 627.0 was created.
# Merged rental count and weather dataframe for station 641.0 was created.
# Merged rental count and weather dataframe for station 646.0 was created.
# Merged rental count and weather dataframe for station 558.0 was created.
# Merged rental count and weather dataframe for station 576.0 was created.
# Merged rental count and weather dataframe for station 632.0 was created.
# Merged rental count and weather dataframe for station 197.0 was created.
# Merged rental count and weather dataframe for station 489.0 was created.
# Merged rental count and weather dataframe for station 614.0 was created.
# Merged rental count and weather dataframe for station 565.0 was created.
# Merged rental count and weather dataframe for station 566.0 was created.
# Merged rental count and weather dataframe for station 625.0 was created.
# Merged rental count and weather dataframe for station 581.0 was created.
# Merged rental count and weather dataframe for station 616.0 was created.
# Merged rental count and weather dataframe for station 586.0 was created.
# Merged rental count and weather dataframe for station 587.0 was created.
# Merged rental count and weather dataframe for station 574.0 was created.
# Merged rental count and weather dataframe for station 535.0 was created.
# Merged rental count and weather dataframe for station 582.0 was created.
# Merged rental count and weather dataframe for station 683.0 was created.
# Merged rental count and weather dataframe for station 488.0 was created.
# Merged rental count and weather dataframe for station 606.0 was created.
# Merged rental count and weather dataframe for station 547.0 was created.
# Merged rental count and weather dataframe for station 526.0 was created.
# Merged rental count and weather dataframe for station 523.0 was created.
# Merged rental count and weather dataframe for station 522.0 was created.
# Merged rental count and weather dataframe for station 528.0 was created.
# Number of new dataframes: 645

# %%
# calling aggregated dataframe merged with weather for pickup_station 6
stations_weather_rentals[6].tail(50)
# Out:
#                      rental_counts  avg_rental_duration  is_business_day  \
# 2024-01-29 22:00:00            3.0                 9.22                1
# 2024-01-29 23:00:00            0.0                 0.00                1
# 2024-01-30 00:00:00            4.0                18.48                1
# 2024-01-30 01:00:00            0.0                 0.00                1
# 2024-01-30 02:00:00            0.0                 0.00                1
# 2024-01-30 03:00:00            0.0                 0.00                1
# 2024-01-30 04:00:00            0.0                 0.00                1
# 2024-01-30 05:00:00            2.0                 7.97                1
# 2024-01-30 06:00:00            8.0                12.11                1
# 2024-01-30 07:00:00           11.0                12.62                1
# 2024-01-30 08:00:00           13.0                12.25                1
# 2024-01-30 09:00:00            6.0                17.38                1
# 2024-01-30 10:00:00           15.0                16.44                1
# 2024-01-30 11:00:00            8.0                11.08                1
# 2024-01-30 12:00:00            4.0                18.72                1
# 2024-01-30 13:00:00            8.0                17.27                1
# 2024-01-30 14:00:00            7.0                14.68                1
# 2024-01-30 15:00:00           17.0                13.06                1
# 2024-01-30 16:00:00           16.0                12.98                1
# 2024-01-30 17:00:00           16.0                11.36                1
# 2024-01-30 18:00:00           18.0                16.23                1
# 2024-01-30 19:00:00            8.0                17.41                1
# 2024-01-30 20:00:00            5.0                12.99                1
# 2024-01-30 21:00:00            8.0                17.08                1
# 2024-01-30 22:00:00            4.0                11.44                1
# 2024-01-30 23:00:00            2.0                12.46                1
# 2024-01-31 00:00:00            3.0                18.76                1
# 2024-01-31 01:00:00            0.0                 0.00                1
# 2024-01-31 02:00:00            0.0                 0.00                1
# 2024-01-31 03:00:00            0.0                 0.00                1
# 2024-01-31 04:00:00            0.0                 0.00                1
# 2024-01-31 05:00:00            2.0                 7.38                1
# 2024-01-31 06:00:00            8.0                11.64                1
# 2024-01-31 07:00:00           10.0                11.20                1
# 2024-01-31 08:00:00           11.0                13.96                1
# 2024-01-31 09:00:00           12.0                13.03                1
# 2024-01-31 10:00:00            6.0                21.04                1
# 2024-01-31 11:00:00            5.0                13.41                1
# 2024-01-31 12:00:00            7.0                11.45                1
# 2024-01-31 13:00:00           13.0                18.89                1
# 2024-01-31 14:00:00           11.0                14.54                1
# 2024-01-31 15:00:00           18.0                13.44                1
# 2024-01-31 16:00:00           12.0                13.16                1
# 2024-01-31 17:00:00           19.0                14.26                1
# 2024-01-31 18:00:00           19.0                17.82                1
# 2024-01-31 19:00:00           12.0                19.37                1
# 2024-01-31 20:00:00            7.0                17.41                1
# 2024-01-31 21:00:00            7.0                12.78                1
# 2024-01-31 22:00:00            9.0                15.53                1
# 2024-01-31 23:00:00            1.0                 5.98                1
#
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 2024-01-29 22:00:00           21.6                 14               17.3
# 2024-01-29 23:00:00           21.3                 15               16.6
# 2024-01-30 00:00:00           19.8                 22               15.1
# 2024-01-30 01:00:00           17.7                 34               13.4
# 2024-01-30 02:00:00           16.2                 41               12.6
# 2024-01-30 03:00:00           14.7                 47               11.3
# 2024-01-30 04:00:00           13.7                 48               10.4
# 2024-01-30 05:00:00           13.0                 50                9.7
# 2024-01-30 06:00:00           12.2                 53                9.3
# 2024-01-30 07:00:00           11.4                 57                8.8
# 2024-01-30 08:00:00           10.5                 61                8.1
# 2024-01-30 09:00:00           10.3                 61                7.7
# 2024-01-30 10:00:00            9.3                 65                6.7
# 2024-01-30 11:00:00            8.8                 67                6.3
# 2024-01-30 12:00:00            7.8                 72                5.2
# 2024-01-30 13:00:00            7.8                 71                5.2
# 2024-01-30 14:00:00            8.9                 67                6.6
# 2024-01-30 15:00:00           11.2                 55                9.2
# 2024-01-30 16:00:00           13.2                 47               11.4
# 2024-01-30 17:00:00           15.4                 40               13.1
# 2024-01-30 18:00:00           18.0                 30               15.7
# 2024-01-30 19:00:00           19.8                 24               16.6
# 2024-01-30 20:00:00           21.4                 19               17.3
# 2024-01-30 21:00:00           21.4                 17               16.2
# 2024-01-30 22:00:00           19.5                 20               13.4
# 2024-01-30 23:00:00           18.4                 23               12.9
# 2024-01-31 00:00:00           17.7                 23               12.6
# 2024-01-31 01:00:00           17.3                 18               12.5
# 2024-01-31 02:00:00           16.6                 21               12.4
# 2024-01-31 03:00:00           16.0                 22               11.9
# 2024-01-31 04:00:00           15.0                 25               11.2
# 2024-01-31 05:00:00           14.3                 30               11.0
# 2024-01-31 06:00:00           13.5                 38               10.7
# 2024-01-31 07:00:00           13.2                 42               10.8
# 2024-01-31 08:00:00           12.7                 44               10.5
# 2024-01-31 09:00:00           11.9                 39                9.0
# 2024-01-31 10:00:00           11.5                 41                8.7
# 2024-01-31 11:00:00           11.3                 44                8.7
# 2024-01-31 12:00:00           11.1                 55                9.2
# 2024-01-31 13:00:00           10.9                 59                8.9
# 2024-01-31 14:00:00           11.4                 53                9.4
# 2024-01-31 15:00:00           12.9                 47               10.7
# 2024-01-31 16:00:00           15.2                 36               12.8
# 2024-01-31 17:00:00           16.4                 32               13.7
# 2024-01-31 18:00:00           17.9                 28               14.9
# 2024-01-31 19:00:00           18.8                 26               15.5
# 2024-01-31 20:00:00           20.8                 20               17.2
# 2024-01-31 21:00:00           21.7                 20               18.4
# 2024-01-31 22:00:00           21.7                 20               18.3
# 2024-01-31 23:00:00           21.4                 21               18.1
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 2024-01-29 22:00:00      0.0                87             8.9       1
# 2024-01-29 23:00:00      0.0                87            11.9       1
# 2024-01-30 00:00:00      0.0                85            14.7       1
# 2024-01-30 01:00:00      0.0                88            16.9       0
# 2024-01-30 02:00:00      0.0                87            13.1       0
# 2024-01-30 03:00:00      0.0                89            12.4       0
# 2024-01-30 04:00:00      0.0                90            11.6       0
# 2024-01-30 05:00:00      0.0                90            11.4       0
# 2024-01-30 06:00:00      0.0                80             8.7       0
# 2024-01-30 07:00:00      0.0                35             6.8       0
# 2024-01-30 08:00:00      0.0                85             5.9       0
# 2024-01-30 09:00:00      0.0                35             6.3       0
# 2024-01-30 10:00:00      0.0                37             7.3       0
# 2024-01-30 11:00:00      0.0                37             6.6       0
# 2024-01-30 12:00:00      0.0                43             6.6       0
# 2024-01-30 13:00:00      0.0                84             7.1       0
# 2024-01-30 14:00:00      0.0                90             4.8       1
# 2024-01-30 15:00:00      0.0                90             1.9       1
# 2024-01-30 16:00:00      0.0                86             0.5       1
# 2024-01-30 17:00:00      0.0                70             3.4       1
# 2024-01-30 18:00:00      0.0                80             4.7       1
# 2024-01-30 19:00:00      0.0                85             7.7       1
# 2024-01-30 20:00:00      0.0                89            12.5       1
# 2024-01-30 21:00:00      0.0                89            16.9       1
# 2024-01-30 22:00:00      0.0                88            23.0       1
# 2024-01-30 23:00:00      0.0                86            20.4       1
# 2024-01-31 00:00:00      0.0                64            16.9       1
# 2024-01-31 01:00:00      0.0                90            12.0       0
# 2024-01-31 02:00:00      0.0                90             8.9       0
# 2024-01-31 03:00:00      0.0                58             8.2       0
# 2024-01-31 04:00:00      0.0                86             7.2       0
# 2024-01-31 05:00:00      0.0                85             5.3       0
# 2024-01-31 06:00:00      0.0                90             4.0       0
# 2024-01-31 07:00:00      0.1                90             2.6       0
# 2024-01-31 08:00:00      0.0                89             1.8       0
# 2024-01-31 09:00:00      0.0                90             3.9       0
# 2024-01-31 10:00:00      0.0                89             3.3       0
# 2024-01-31 11:00:00      0.0                90             3.0       0
# 2024-01-31 12:00:00      0.0                88             1.1       0
# 2024-01-31 13:00:00      0.0                84             3.3       0
# 2024-01-31 14:00:00      0.0                81             1.4       1
# 2024-01-31 15:00:00      0.0                71             2.5       1
# 2024-01-31 16:00:00      0.0                68             1.8       1
# 2024-01-31 17:00:00      0.0                85             3.5       1
# 2024-01-31 18:00:00      0.0                84             5.5       1
# 2024-01-31 19:00:00      0.0                75             6.6       1
# 2024-01-31 20:00:00      0.0                85             7.5       1
# 2024-01-31 21:00:00      0.0                79             6.9       1
# 2024-01-31 22:00:00      0.0                85             6.8       1
# 2024-01-31 23:00:00      0.0                62             6.5       1

# %%
# Cycle stations: they are available to take bikes 365 days a year from 05:00 to 00:30.
stations_weather_rentals[6].index
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                ...
#                '2024-01-31 14:00:00', '2024-01-31 15:00:00',
#                '2024-01-31 16:00:00', '2024-01-31 17:00:00',
#                '2024-01-31 18:00:00', '2024-01-31 19:00:00',
#                '2024-01-31 20:00:00', '2024-01-31 21:00:00',
#                '2024-01-31 22:00:00', '2024-01-31 23:00:00'],
#               dtype='datetime64[ns]', length=9504, freq=None)

# %% [markdown]
# <b>Data frames to be used for SARIMA modelling</b>

# %%
# stored in a dictionary as values: 
#     stations_weather_rentals['station number']
# station numbers stored in an array: 
#     pickup_stations

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import matplotlib.dates as mdates
import statsmodels.api as sm
from statsmodels.tsa.api import SARIMAX
InteractiveShell.ast_node_interactivity = "all"

# %%
# outliers in dataset?

# maybe outliers in rental duration but likely not relevant to our rental count modelling
# 10045 minutes? 0 minutes?
hourly_weather_rentals['avg_rental_duration'].sort_values(ascending=False).head(10)
hourly_weather_rentals['avg_rental_duration'].sort_values(ascending=True).head(20)

# no major outliers detected for rental_counts...
hourly_weather_rentals['rental_counts'].sort_values(ascending=False).head(20)
hourly_weather_rentals['rental_counts'].sort_values(ascending=True).head(10)
# Out:
# 2023-02-03 23:00:00    1245.66
# 2023-07-15 22:00:00     412.62
# 2023-04-29 14:00:00     211.69
# 2023-04-28 14:00:00     187.76
# 2023-06-19 06:00:00     170.01
# 2023-05-18 18:00:00     125.49
# 2023-03-09 12:00:00     106.27
# 2023-04-01 13:00:00     103.55
# 2023-06-09 18:00:00      96.62
# 2023-02-07 15:00:00      84.51
# Name: avg_rental_duration, dtype: float64
# 2023-11-01 04:00:00    0.0
# 2023-10-25 04:00:00    0.0
# 2023-10-25 03:00:00    0.0
# 2023-10-25 02:00:00    0.0
# 2023-10-25 01:00:00    0.0
# 2023-05-13 01:00:00    0.0
# 2023-05-13 02:00:00    0.0
# 2023-12-24 01:00:00    0.0
# 2023-12-24 02:00:00    0.0
# 2023-12-24 03:00:00    0.0
# 2023-12-24 04:00:00    0.0
# 2023-02-20 01:00:00    0.0
# 2023-05-13 03:00:00    0.0
# 2023-10-24 04:00:00    0.0
# 2023-05-14 01:00:00    0.0
# 2023-05-14 02:00:00    0.0
# 2023-05-14 03:00:00    0.0
# 2023-05-14 04:00:00    0.0
# 2023-10-24 03:00:00    0.0
# 2023-02-19 04:00:00    0.0
# Name: avg_rental_duration, dtype: float64
# 2024-01-30 18:00:00    6538.0
# 2024-01-31 18:00:00    6527.0
# 2024-01-25 18:00:00    6426.0
# 2024-01-17 18:00:00    6410.0
# 2024-01-24 18:00:00    6408.0
# 2024-01-23 18:00:00    6357.0
# 2024-01-16 18:00:00    6316.0
# 2024-01-15 18:00:00    6217.0
# 2024-01-29 18:00:00    6163.0
# 2024-01-22 18:00:00    6057.0
# 2024-01-18 18:00:00    5996.0
# 2024-01-10 18:00:00    5845.0
# 2024-01-11 18:00:00    5810.0
# 2024-01-08 18:00:00    5755.0
# 2024-01-09 18:00:00    5754.0
# 2023-12-05 18:00:00    5678.0
# 2023-11-07 18:00:00    5560.0
# 2024-01-25 17:00:00    5544.0
# 2023-11-21 18:00:00    5524.0
# 2024-01-31 17:00:00    5518.0
# Name: rental_counts, dtype: float64
# 2023-03-20 01:00:00    0.0
# 2023-10-12 04:00:00    0.0
# 2023-06-21 02:00:00    0.0
# 2023-06-21 01:00:00    0.0
# 2023-10-13 01:00:00    0.0
# 2023-10-13 02:00:00    0.0
# 2023-10-13 03:00:00    0.0
# 2023-10-13 04:00:00    0.0
# 2023-06-20 04:00:00    0.0
# 2023-06-20 03:00:00    0.0
# Name: rental_counts, dtype: float64

# %%
# general check on all columns. Seems plausible.
pd.DataFrame(hourly_weather_rentals).describe()
# Out:
#        rental_counts  avg_rental_duration  is_business_day  temperature_C  \
# count    9504.000000          9504.000000      9504.000000    9504.000000
# mean     1372.818182            13.227283         0.584912      17.058544
# std      1196.952721            15.390757         0.492763       5.645082
# min         0.000000             0.000000         0.000000       1.600000
# 25%       250.000000            12.707500         0.000000      13.000000
# 50%      1245.000000            14.530000         1.000000      16.400000
# 75%      2146.000000            16.140000         1.000000      21.400000
# max      6538.000000          1245.660000         1.000000      33.900000
#
#        rel_humidity_perc  feels_like_temp_C      rain_mm  cloud_cover_perc  \
# count        9504.000000        9504.000000  9504.000000       9504.000000
# mean           58.279987          15.700168     0.087742         32.619108
# std            24.873807           5.806799     0.512445         31.790070
# min             3.000000          -1.000000     0.000000          0.000000
# 25%            38.000000          11.800000     0.000000          3.000000
# 50%            60.000000          15.300000     0.000000         26.000000
# 75%            80.000000          19.800000     0.000000         51.000000
# max           100.000000          32.200000    10.500000        100.000000
#
#        wind_speed_kmh       is_day
# count     9504.000000  9504.000000
# mean         7.635953     0.500526
# std          5.522959     0.500026
# min          0.000000     0.000000
# 25%          3.700000     0.000000
# 50%          6.100000     1.000000
# 75%         10.100000     1.000000
# max         38.500000     1.000000

# %%
# filter out rental durations greater than 1000 minutes? 
filter_ = hourly_weather_rentals['avg_rental_duration'] < 1000
hourly_weather_rentals_filtered = hourly_weather_rentals[filter_]
hourly_weather_rentals_filtered.sort_values(by='avg_rental_duration', ascending=False)
# original dimensions of hourly_weather_rentals: (12485, 11)
# filtered = (12466, 11)
# filtered out 19 rows
# Do we want to filter it out in our modelling and analysis??
# Out:
#                      rental_counts  avg_rental_duration  is_business_day  \
# 2023-07-15 22:00:00          693.0               412.62                0
# 2023-04-29 14:00:00         1636.0               211.69                0
# 2023-04-28 14:00:00         1849.0               187.76                1
# 2023-06-19 06:00:00          844.0               170.01                1
# 2023-05-18 18:00:00         2625.0               125.49                1
# ...                            ...                  ...              ...
# 2023-07-02 03:00:00            0.0                 0.00                0
# 2023-07-02 04:00:00            0.0                 0.00                0
# 2023-07-03 01:00:00            0.0                 0.00                0
# 2023-07-03 02:00:00            0.0                 0.00                0
# 2023-05-28 01:00:00            0.0                 0.00                0
#
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 2023-07-15 22:00:00           26.2                 30               25.1
# 2023-04-29 14:00:00           16.3                 32               13.4
# 2023-04-28 14:00:00           15.9                 36               13.5
# 2023-06-19 06:00:00           20.7                 37               18.3
# 2023-05-18 18:00:00           23.5                 29               23.8
# ...                            ...                ...                ...
# 2023-07-02 03:00:00           18.6                 68               18.1
# 2023-07-02 04:00:00           17.8                 73               17.6
# 2023-07-03 01:00:00           21.4                 55               20.5
# 2023-07-03 02:00:00           19.6                 66               19.3
# 2023-05-28 01:00:00           21.0                 55               19.1
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 2023-07-15 22:00:00      0.0                46             6.0       1
# 2023-04-29 14:00:00      0.0                 0             4.7       1
# 2023-04-28 14:00:00      0.0                 0             2.8       1
# 2023-06-19 06:00:00      0.0                 0             8.7       0
# 2023-05-18 18:00:00      0.0                19             5.3       1
# ...                      ...               ...             ...     ...
# 2023-07-02 03:00:00      0.0                58             9.7       0
# 2023-07-02 04:00:00      0.0                17             7.7       0
# 2023-07-03 01:00:00      0.0                20            10.3       1
# 2023-07-03 02:00:00      0.0                24             8.6       0
# 2023-05-28 01:00:00      0.3                72            16.7       1
#
# [9503 rows x 10 columns]

# %%
# visualize the data: rental counts and rental duration over entire timeframe

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(hourly_weather_rentals_filtered.index, hourly_weather_rentals_filtered['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axis that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(hourly_weather_rentals_filtered.index, hourly_weather_rentals_filtered['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %%
# Filter the data for the specified date range
year_2021 = hourly_weather_rentals[(hourly_weather_rentals.index >= '2023-01-01 00:00:00') & (hourly_weather_rentals.index <= '2024-01-31 23:00:00')]

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(year_2021.index, year_2021['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axis that shares the same x-axis (add is business day)
color = 'tab:red'

ax2.tick_params(axis='y', labelcolor=color)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# business days definitely look busier
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')

# %%
# visualize the data: rental counts and rental duration over one business day in 2023
# Feb 11 2021 = Thursday

# Filter the data for the specified date range
random_day = hourly_weather_rentals[(
    hourly_weather_rentals.index >= '2023-02-09 00:00:00') & (hourly_weather_rentals.index <= '2023-02-09 23:00:00'
                                                               )]

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(random_day.index, random_day['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(random_day.index, random_day['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %%
# visualize the data: rental counts and rental duration over one business day for one station in 2021
# Feb 09 2021 = Tuesday
# station 27 third highest pickup counts

# Filter the data for the specified date range
random_day = stations_weather_rentals[6][(
    stations_weather_rentals[6].index >= '2023-02-09 05:00:00') & (stations_weather_rentals[6].index <= '2023-02-10 00:00:00'
                                                               )]

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(random_day.index, random_day['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(random_day.index, random_day['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %% [markdown]
# <b>Observation:</b> Station 6 seems to follow a "normal" work day seasonality. Station 6 is closer to offices/businesses.

# %% [markdown]
# ## SARIMAX
# <b>Hyperparametres</b><br>

# %% [markdown]
# First three from ARIMA:<br>
# - <b>p</b>: Order of the AR term – relationship between an observation and a number of lagged observations (auto-regression); captures the effect of past values on current values
# - <b>d</b>: Degree of differencing – differencing of raw observations to make the time series stationary (i.e., removing trends or seasonality); represents the number of differences needed to make the series stationary.
# - <b>q</b>: Order of the MA term – relationship between the residual error and the lagged observations; captures the dependency between an observation and a residual error from a moving average model.

# %% [markdown]
# Last four for SARIMAX, similar to ARIMA hyperparamatres but with seasonal component:<br>
# - <b>P</b>: Order of the seasonal AR term.
# - <b>D</b>: Degree of seasonal differencing.
# - <b>Q</b>: Order of the seasonal MA term.
# - <b>m</b>: Seasonal length of the time series (e.g., 12 for monthly data, 4 for quarterly data)

# %% [markdown]
# ### Seasonal decomposition
# Checking out the presence of a seasonal component for one station<br>
# <br>
# <i>Parameters:</i>
# - <b>x</b>: The time series data to be decomposed.
# - <b>model</b>: This specifies the type of seasonal decomposition model to be used. It can be either 'additive' or 'multiplicative'.
#     - With the 'additive' model, the components are combined linearly, while with the 'multiplicative' model, the components are combined multiplicatively.
# - <b>filt</b>: This is an array filtering the trend component. By default, an evenly sized window will be used.
# - <b>period</b>: An integer representing the periodicity of the series, i.e. number of observations per cycle. For example, 24 for daily data with hourly observations or 12 for monthly data with yearly observations. This parameter influences the seasonal component of the decomposition.
# - <b>two_sided</b>: If True, moving averages are calculated symmetrically. If False, moving averages will be calculated using past values only.

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
rental_counts_st6 = pd.Series(stations_weather_rentals[6]['rental_counts'].values, index=stations_weather_rentals[6].index)

# %%
rental_counts_st6[:48]
# Out:
# 2023-01-01 00:00:00     0.0
# 2023-01-01 01:00:00     0.0
# 2023-01-01 02:00:00     0.0
# 2023-01-01 03:00:00     0.0
# 2023-01-01 04:00:00     0.0
# 2023-01-01 05:00:00     0.0
# 2023-01-01 06:00:00     0.0
# 2023-01-01 07:00:00     1.0
# 2023-01-01 08:00:00     1.0
# 2023-01-01 09:00:00     0.0
# 2023-01-01 10:00:00     3.0
# 2023-01-01 11:00:00     1.0
# 2023-01-01 12:00:00     3.0
# 2023-01-01 13:00:00     3.0
# 2023-01-01 14:00:00     4.0
# 2023-01-01 15:00:00     6.0
# 2023-01-01 16:00:00     1.0
# 2023-01-01 17:00:00     4.0
# 2023-01-01 18:00:00     2.0
# 2023-01-01 19:00:00     3.0
# 2023-01-01 20:00:00     0.0
# 2023-01-01 21:00:00     0.0
# 2023-01-01 22:00:00     3.0
# 2023-01-01 23:00:00     1.0
# 2023-01-02 00:00:00     0.0
# 2023-01-02 01:00:00     0.0
# 2023-01-02 02:00:00     0.0
# 2023-01-02 03:00:00     0.0
# 2023-01-02 04:00:00     0.0
# 2023-01-02 05:00:00     1.0
# 2023-01-02 06:00:00     0.0
# 2023-01-02 07:00:00     3.0
# 2023-01-02 08:00:00     9.0
# 2023-01-02 09:00:00     6.0
# 2023-01-02 10:00:00     6.0
# 2023-01-02 11:00:00     8.0
# 2023-01-02 12:00:00     6.0
# 2023-01-02 13:00:00     5.0
# 2023-01-02 14:00:00     9.0
# 2023-01-02 15:00:00     7.0
# 2023-01-02 16:00:00     2.0
# 2023-01-02 17:00:00    14.0
# 2023-01-02 18:00:00    18.0
# 2023-01-02 19:00:00    12.0
# 2023-01-02 20:00:00     6.0
# 2023-01-02 21:00:00     0.0
# 2023-01-02 22:00:00     4.0
# 2023-01-02 23:00:00     0.0
# dtype: float64

# %%
rental_counts_st6.fillna(0,inplace=True)

# %%
rental_counts_st6.shape
# Out:
# (9504,)

# %%
# decompose from observation #8000 onwards so that we can actually see the trends and seasonalities
decomposition = sm.tsa.seasonal_decompose(rental_counts_st6[8000:], 
                                          model='additive',  # no reason (yet) to believe magnitude of variation changes significantly with time
                                         period=24) # since we have hourly data

# Extract the decomposed components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the decomposed components
decomposition.plot()
plt.show()

# Trending upwards
# seasonality looks to be daily given the density of the plot
# resid is stable looking

# %%
# closer examination at the seasonality, definitely looks daily
seasonal = decomposition.seasonal
plt.figure(figsize=(20, 6))
seasonal.plot()
plt.show()

# %% [markdown]
# ### ACF and PACF
# ACF (Autocorrelation Function) and PACF (Partial Autocorrelation Function) plots are used to diagnose patterns of autocorrelation in time series data, which can help in identifying the proper hyperparameters for models such as ARIMA and SARIMA, i.e. the order of AR, MA, and ARMA models.<br>
# 1. <b>Autocorrelation Function (ACF) Plot:</b>
#     - The ACF plot shows the autocorrelation of the time series with its own lagged values. Each bar on the plot represents the correlation between the series and its lagged values at various lags.
#     - Interpretation: In an ACF plot, significant autocorrelations that extend beyond the critical boundaries indicate the presence of autoregressive (AR) components in the data. For example, if the ACF values decay exponentially, it may indicate the series is stationary and lends itself to an ARIMA model.
# <br><br>
# 2. <b>Partial Autocorrelation Function (PACF) Plot:</b>
#     - The PACF plot displays the partial correlation of the time series with its own lagged values, while controlling for the values of the intervening lags.
#     - Interpretation: In a PACF plot, significant partial autocorrelations that extend beyond the critical boundaries imply the presence of a moving average (MA) component in the data.

# %%
# check the ACF and PACF plots and confirm the presence of seasonality and the seasonal period
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF
fig, ax = plt.subplots(figsize=(8, 3))
plot_acf(rental_counts_st6[9000:], ax=ax, lags=48)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF)')
plt.show()

# Plot PACF
fig, ax = plt.subplots(figsize=(8, 3))
plot_pacf(rental_counts_st6[9000:], ax=ax, lags=48)
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %%
stations_weather_rentals[6].columns
# Out:
# Index(['rental_counts', 'avg_rental_duration', 'is_business_day',
#        'temperature_C', 'rel_humidity_perc', 'feels_like_temp_C', 'rain_mm',
#        'cloud_cover_perc', 'wind_speed_kmh', 'is_day'],
#       dtype='object')

# %% [markdown]
# ### Splitting the data
# starting with station 6

# %%
# split our timeseries dataset into train/test sets

def SARIMA_train_test_split(df, test_percentage): # df = dataframe, test_percentage = proportion of df we want to keep for testing
    n_test = int(round(len(df)*test_percentage, 0))
    train = df.iloc[:-n_test]
    test = df.iloc[-n_test:]
    return train, test

#'temperature_C', 'feels_like_temp_C'

# %%
train_full, test_full = SARIMA_train_test_split(
    stations_weather_rentals[6].drop(columns = ['avg_rental_duration',
                                                'cloud_cover_perc',
                                               'rel_humidity_perc'],axis=1), 0.20)
test_full
# Out:
#                      rental_counts  is_business_day  temperature_C  \
# 2023-11-13 19:00:00           12.0                1           22.8
# 2023-11-13 20:00:00            7.0                1           23.7
# 2023-11-13 21:00:00            9.0                1           24.1
# 2023-11-13 22:00:00            7.0                1           23.1
# 2023-11-13 23:00:00            1.0                1           22.2
# ...                            ...              ...            ...
# 2024-01-31 19:00:00           12.0                1           18.8
# 2024-01-31 20:00:00            7.0                1           20.8
# 2024-01-31 21:00:00            7.0                1           21.7
# 2024-01-31 22:00:00            9.0                1           21.7
# 2024-01-31 23:00:00            1.0                1           21.4
#
#                      rel_humidity_perc  feels_like_temp_C  rain_mm  \
# 2023-11-13 19:00:00                 44               22.9      0.1
# 2023-11-13 20:00:00                 40               23.4      0.0
# 2023-11-13 21:00:00                 38               23.1      0.0
# 2023-11-13 22:00:00                 40               20.6      0.0
# 2023-11-13 23:00:00                 42               19.8      0.0
# ...                                ...                ...      ...
# 2024-01-31 19:00:00                 26               15.5      0.0
# 2024-01-31 20:00:00                 20               17.2      0.0
# 2024-01-31 21:00:00                 20               18.4      0.0
# 2024-01-31 22:00:00                 20               18.3      0.0
# 2024-01-31 23:00:00                 21               18.1      0.0
#
#                      wind_speed_kmh  is_day
# 2023-11-13 19:00:00             9.2       1
# 2023-11-13 20:00:00             8.5       1
# 2023-11-13 21:00:00             8.7       1
# 2023-11-13 22:00:00            15.1       1
# 2023-11-13 23:00:00            14.2       1
# ...                             ...     ...
# 2024-01-31 19:00:00             6.6       1
# 2024-01-31 20:00:00             7.5       1
# 2024-01-31 21:00:00             6.9       1
# 2024-01-31 22:00:00             6.8       1
# 2024-01-31 23:00:00             6.5       1
#
# [1901 rows x 8 columns]

# %%
train_full.columns
# Out:
# Index(['rental_counts', 'is_business_day', 'temperature_C',
#        'rel_humidity_perc', 'feels_like_temp_C', 'rain_mm', 'wind_speed_kmh',
#        'is_day'],
#       dtype='object')

# %%
# scale our exogenous variables
scaler = MinMaxScaler()
scaler.fit(train_full.drop('rental_counts',axis=1))
exog_train = scaler.transform(train_full.drop('rental_counts',axis=1))
exog_test = scaler.transform(test_full.drop('rental_counts',axis=1))
# Out:
# MinMaxScaler()

# %%
# scale our endogenous / target variable

endog_train = pd.DataFrame(train_full['rental_counts'])
endog_test = pd.DataFrame(test_full['rental_counts'])

pt = PowerTransformer()
pt.fit(pd.DataFrame(train_full['rental_counts']))

endog_train = pt.transform(endog_train)
endog_test = pt.transform(endog_test)
# Out:
# PowerTransformer()

# %%
# reset dataframe and column names for endog and exog train and test sets
column_names = ['is_business_day', 'temperature_C', 'feels_like_temp_C', 'rain_mm', # 'rel_humidity_perc',
       'wind_speed_kmh', 'is_day']


exog_train = pd.DataFrame(exog_train, columns=column_names)
exog_test = pd.DataFrame(exog_test, columns=column_names)

endog_train = pd.DataFrame(endog_train, columns=['rental_counts'])
endog_test = pd.DataFrame(endog_test, columns=['rental_counts'])

endog_train
# Out:
#       rental_counts
# 0         -1.362494
# 1         -1.362494
# 2         -1.362494
# 3         -1.362494
# 4         -1.362494
# ...             ...
# 7598       1.368187
# 7599       0.667415
# 7600       1.459954
# 7601       1.629594
# 7602       1.708440
#
# [7603 rows x 1 columns]

# %%
# reset index to datetime

train_index = pd.date_range(start='2023-01-01 00:00:00', end='2023-11-13 18:00:00', freq='H')
test_index = pd.date_range(start='2023-11-13 19:00:00', end='2024-01-31 23:00:00', freq='H')

exog_train['date']= train_index
exog_train.set_index('date', inplace=True)

exog_test['date']= test_index
exog_test.set_index('date', inplace=True)

endog_train['date']= train_index
endog_train.set_index('date', inplace=True)

endog_test['date']= test_index
endog_test.set_index('date', inplace=True)

# %% [markdown]
# ### Grid search for best hyperparameters

# %%
import itertools
import math
import warnings
warnings.filterwarnings('ignore')

# %%
# Define the range of values for p, d, q, P, D, Q, and m
p_values = range(0, 2)  # Autoregressive order
d_values = [0]          # Differencing order
q_values = range(0, 2)  # Moving average order
P_values = range(0, 2)  # Seasonal autoregressive order
D_values = range(0, 1)  # Seasonal differencing order
Q_values = range(0, 2)  # Seasonal moving average order
m_values = [24]         # Seasonal period

# Create all possible combinations of SARIMA parameters
param_combinations = list(itertools.product(p_values, 
                                            d_values, 
                                            q_values, 
                                            P_values, 
                                            D_values, 
                                            Q_values, 
                                            m_values))

# Initialize AIC with a large value (positive infinity = "inf")
best_aic = float("inf")  
best_params = None

# Perform grid search
for params in param_combinations:
    order = params[:3]
    seasonal_order = params[3:]
    
    try:
        model = sm.tsa.SARIMAX(endog=endog_train, 
                               exog=exog_train, 
                               order=order, 
                               seasonal_order=seasonal_order)
        result = model.fit(disp=False, method='nm')
        aic = result.aic
        
        # Ensure the convergence of the model
        if not math.isinf(result.zvalues.mean()):
            print(order, seasonal_order, aic)
        
            if aic < best_aic:
                best_aic = aic
                best_params = params
                
        else:
            print(order, seasonal_order, 'not converged')

    except:
        continue

# Print the best parameters and AIC
print("Best Parameters:", best_params)
print("Best AIC:", best_aic)
# Out:
# (0, 0, 0) (0, 0, 0, 24) 19789.207124595476
# (0, 0, 0) (0, 0, 1, 24) 16185.473980330764
# (0, 0, 0) (1, 0, 0, 24) 14516.078954181507
# (0, 0, 0) (1, 0, 1, 24) 13058.57717222716
# (0, 0, 1) (0, 0, 0, 24) 16361.404216764826
# (0, 0, 1) (0, 0, 1, 24) 15329.450628717726
# (0, 0, 1) (1, 0, 0, 24) 14772.793586826137
# (0, 0, 1) (1, 0, 1, 24) 13408.399302997092
# (1, 0, 0) (0, 0, 0, 24) 15188.323292153716
# (1, 0, 0) (0, 0, 1, 24) 14666.627579265267
# (1, 0, 0) (1, 0, 0, 24) 14440.2536856109
# (1, 0, 0) (1, 0, 1, 24) 13458.133382411906
# (1, 0, 1) (0, 0, 0, 24) 15127.158453256212
# (1, 0, 1) (0, 0, 1, 24) 14376.300101699882
# (1, 0, 1) (1, 0, 0, 24) 14328.478149910265
# (1, 0, 1) (1, 0, 1, 24) 13064.015560052638
# Best Parameters: (0, 0, 0, 1, 0, 1, 24)
# Best AIC: 13058.57717222716

# %% [markdown]
# ### Fitting SARIMAX + Predictions

# %%
# Assuming 'endog' contains the time series variable and 'exog' contains the exogenous variables
# Assuming 'y' is the rental_counts variable
# change the solver when fitting, L-BFGS-B is better for small datasets
    ## NOTE: Need to re-run the grid search to fit with method='nm'


# Fit the SARIMAX model
model = sm.tsa.SARIMAX(endog_train, \
                       exog=exog_train, order=(0, 0, 0), seasonal_order=(1, 0, 1, 24))
results = model.fit(method='nm')

# %%
results.summary()

# The “P>|z|” column provides the p-value associated with each coefficient, 
# for all cases they are lower than 0.05, our significance level, except for temperature
# which means that all of them are statistically significant.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  SARIMAX Results
# ==================================================================================
# Dep. Variable:              rental_counts   No. Observations:                 7603
# Model:             SARIMAX(1, 0, [1], 24)   Log Likelihood               -6519.289
# Date:                    Thu, 07 Mar 2024   AIC                          13058.577
# Time:                            15:19:44   BIC                          13127.940
# Sample:                        01-01-2023   HQIC                         13082.380
#                              - 11-13-2023
# Covariance Type:                      opg
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# is_business_day       0.6165      0.014     43.058      0.000       0.588       0.645
# temperature_C        -4.9949      0.534     -9.349      0.000      -6.042      -3.948
# feels_like_temp_C     0.1113      0.078      1.427      0.154      -0.042       0.264
# rain_mm               3.0967      0.507      6.108      0.000       2.103       4.090
# rel_humidity_perc    -1.9952      0.090    -22.096      0.000      -2.172      -1.818
# wind_speed_kmh        0.2798      0.118      2.375      0.018       0.049       0.511
# is_day                0.7261      0.069     10.553      0.000       0.591       0.861
# ar.S.L24              0.9476      0.004    213.039      0.000       0.939       0.956
# ma.S.L24             -0.7282      0.012    -59.749      0.000      -0.752      -0.704
# sigma2                0.3651      0.007     51.673      0.000       0.351       0.379
# ===================================================================================
# Ljung-Box (L1) (Q):                 566.71   Jarque-Bera (JB):                48.58
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -0.11
# Prob(H) (two-sided):                  0.15   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# mean error: on average, the model tends to overestimate the target values by 0.92 units
# mean squared error: A mean squared error of 20.66 indicates the average squared magnitude of the prediction errors. It provides a sense of the overall variability or dispersion of the errors.
# mean absolute error: A mean absolute error of 3.46 signifies the average magnitude of the errors without considering their direction.
# root mean squared error: An RMSE of 4.55 suggests the typical size of the errors (standard deviations) generated by the model.
# 12:34
# ### Assessing our SARIMAX model
# In our summary, the <b>“P>|z|”</b> provides the p-value associated with each coefficient. For the coefficient to be significant, they should be lower than our significance level of 0.05.<br>
# <br>
# Examining our model's <b>plot diagnostics</b>, we want to see:
# 1. The standardized residual shouldn’t have any obvious patterns, i.e. random noise, data with a zero mean and a uniform variance. The residuals should be uncorrelated with Gaussian noise centered on zero.
# 2. The histogram plus KDE estimate should look similar to a normal distribution
# 3. In the Normal Q-Q graph, we should observe the majority of the points lying on the straight line, indicating a normal distribution of the residuals.
#     - <i>(quantile-quantile graph: graphical comparison between the empirical quantiles of the data and the quantiles of the theoretical distribution)</i>
# 4. In the ACF or correlogram, 95% of correlations for lag greater than one should be within the confidence band, i.e. not significant.

# %%
fig = results.plot_diagnostics(figsize=(8, 8))
fig.autofmt_xdate()
plt.show()

# 1. standardized residual looks heavier for the first half
# 2. histogram and KDE are somewhat normally distributed
# 3. In the Normal Q-Q graph, points don't completely lie on the straight line
# 4. 1st and last lags not within confidence band

# %%
import pickle
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Save the model to a file
with open('sarimax_model_7.pkl', 'wb') as f:
    pickle.dump(results, f)
    
# Save the scaler to a file
with open('scaler_7.pkl', 'wb') as f:
    pickle.dump(scaler, f)
    
# Save the transformer to a file
with open('transformer_7.pkl', 'wb') as f:
    pickle.dump(pt, f)

# Load the model from the file
with open('sarimax_model_7.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
pd.DataFrame(predictions)
# Out:
#                      predicted_mean
# 2023-11-13 19:00:00        0.994764
# 2023-11-13 20:00:00        0.753408
# 2023-11-13 21:00:00        0.448278
# 2023-11-13 22:00:00        0.235675
# 2023-11-13 23:00:00        0.227596
# ...                             ...
# 2024-01-31 19:00:00        0.358622
# 2024-01-31 20:00:00        0.196826
# 2024-01-31 21:00:00        0.159498
# 2024-01-31 22:00:00        0.146583
# 2024-01-31 23:00:00        0.173686
#
# [1901 rows x 1 columns]

# %%
# get predictions for test set
# set prediction period 
start_datetime = pd.Timestamp('2023-11-13 19:00:00')
end_datetime = pd.Timestamp('2024-01-31 23:00:00')

# Make predictions and inverse transform
predictions = pd.DataFrame(results.predict(start=start_datetime, end=end_datetime, exog=exog_test))
predictions = predictions.rename(columns={'predicted_mean': 'rental_counts'})
predictions_inv = pd.DataFrame(pt.inverse_transform(predictions))

# reset index and column names for predictions
predictions_inv = predictions_inv.rename(columns={0: 'rental_counts'})
predictions_inv['date'] = test_index
predictions_inv.set_index('date', inplace=True)
predictions_inv = pd.Series(predictions_inv.rental_counts)

# %%
# Plot test predictions with training data

ax = train_full['rental_counts'][8000:].plot(figsize=(12,5))
predictions_inv.plot()
test_full['rental_counts'].plot(ax=ax)
# plt.fill_between(predictions.index, 
#                  confidence_intervals['lower tmax'], 
#                  confidence_intervals['upper tmax'], 
#                  color='blue',
#                  alpha=0.15)
plt.legend(['Training rental counts', 
            'Predicted rental counts', 
            'Actual rental counts'], 
           loc='upper left')
plt.xlabel('Date & Hour')
plt.ylabel('Number of rentals')
plt.grid(alpha=0.5)
plt.show()
# Out:
# <Axes: xlabel='date'>
# <Axes: xlabel='date'>
# Text(0.5, 0, 'Date & Hour')
# Text(0, 0.5, 'Number of rentals')

# %%
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae
# calculate residuals of our test data and predictions
test_residuals = pd.DataFrame({'rental_counts': test_full['rental_counts'], 'predictions': predictions_inv.rental_counts.values}, index=predictions_inv.index)
test_residuals['residuals'] = test_residuals['rental_counts']-test_residuals['predictions']
test_residuals

# calculating error metrics for test data

me_test = round(test_residuals.residuals.mean(),2)
print(f'mean error of test: {me_test}')

mse_test = round(mse(test1['rental_counts'],predictions),2) # mean squared error
print(f'mean squared error of test: {mse_test}')

mae_test = round(mae(test1['rental_counts'],predictions),2) # mean absolute error
print(f'mean absolute error of test: {mae_test}')

rmse_test = round(mse(test1['rental_counts'],predictions,squared=False),2) # root mean squared error
print(f'root mean squared error of test: {rmse_test}')
# Out:
#                      rental_counts  predictions  residuals
# date
# 2023-11-13 19:00:00           12.0     9.468887   2.531113
# 2023-11-13 20:00:00            7.0     7.597443  -0.597443
# 2023-11-13 21:00:00            9.0     5.627551   3.372449
# 2023-11-13 22:00:00            7.0     4.484076   2.515924
# 2023-11-13 23:00:00            1.0     4.443996  -3.443996
# ...                            ...          ...        ...
# 2024-01-31 19:00:00           12.0     5.123991   6.876009
# 2024-01-31 20:00:00            7.0     4.293499   2.706501
# 2024-01-31 21:00:00            7.0     4.115447   2.884553
# 2024-01-31 22:00:00            9.0     4.054982   4.945018
# 2024-01-31 23:00:00            1.0     4.182548  -3.182548
#
# [1901 rows x 3 columns]
# mean error of test: 0.66
# mean squared error of test: 55.37
# mean absolute error of test: 5.48
# root mean squared error of test: 7.44

# %%
confidence_intervals
# Out:
#                      lower rental_counts  upper rental_counts
# 2023-11-13 19:00:00            -0.189569             2.179096
# 2023-11-13 20:00:00            -0.430924             1.937741
# 2023-11-13 21:00:00            -0.736055             1.632610
# 2023-11-13 22:00:00            -0.948657             1.420008
# 2023-11-13 23:00:00            -0.956736             1.411929
# ...                                  ...                  ...
# 2024-01-31 19:00:00            -1.078066             1.795309
# 2024-01-31 20:00:00            -1.239862             1.633514
# 2024-01-31 21:00:00            -1.277190             1.596185
# 2024-01-31 22:00:00            -1.290105             1.583270
# 2024-01-31 23:00:00            -1.263001             1.610374
#
# [1901 rows x 2 columns]

# %%
# CAN'T FIGURE OUT CONFIDENCE INTERVALS WITH TRANSFORMED DATA
# # Plot test forecast with training data (same as above but diff function, with confidence intervals)

# forecast = results.get_forecast(steps=1901, exog=exog_test) # steps = number of rows in test set
# confidence_intervals = forecast.conf_int()
# forecast = pd.DataFrame(forecast.predicted_mean)

# # inverse transform, reset index and column names for forecast
# forecast = forecast.rename(columns={'predicted_mean': 'rental_counts'})
# forecast_inv = pd.DataFrame(pt.inverse_transform(forecast))
# forecast_inv = forecast_inv.rename(columns={0: 'rental_counts'})
# forecast_inv['date'] = test_index
# forecast_inv.set_index('date', inplace=True)
# forecast_inv = pd.Series(forecast_inv.rental_counts)

# # plot
# ax = train_full['rental_counts'][8000:].plot(figsize=(12,5))
# forecast_inv.plot()
# test_full['rental_counts'].plot(ax=ax)
# plt.fill_between(forecast.index, 
#                  confidence_intervals['lower rental_counts'], 
#                  confidence_intervals['upper rental_counts'], 
#                  color='blue',
#                  alpha=0.15)
# plt.legend(['Training rental counts', 
#             'Predicted rental counts', 
#             'Actual rental counts'], 
#            loc='upper left')
# plt.xlabel('Date & Hour')
# plt.ylabel('Number of rentals')
# plt.grid(alpha=0.5)
# plt.show()
