# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.datasets import fetch_california_housing
from sklearn.datasets import load_iris, load_breast_cancer
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
# %matplotlib inline 
#Importing our defined functions to clean
from clean_data_functions import *
from scipy.stats import mode

import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', None) 
sns.set_theme(style ="whitegrid")

# %matplotlib inline

# %%
eco_bici = pd.read_csv("DATA/year_ecobici_df.csv")

# %%
dropna_rows_cols(eco_bici, 6, 1500000)
# Out:
# Deleted 0 rows
# Deleted 0 columns
#          Genero_Usuario  Edad_Usuario     Bici Ciclo_Estacion_Retiro  \
# 0                     M          24.0  2252039                   007
# 1                     M          33.0  8626897                   206
# 2                     M          34.0  4940557                   215
# 3                     F          30.0  2036523                   291
# 4                     F          23.0  8079220                   546
# ...                 ...           ...      ...                   ...
# 13735643              M          33.0  6683080                   022
# 13735644              M          28.0  2005171                   150
# 13735645              M          26.0  6842108                   545
# 13735646              M          53.0  5478714                   007
# 13735647              F          30.0  3046505                   129
#
#          Fecha_Retiro Hora_Retiro Ciclo_EstacionArribo Fecha Arribo  \
# 0          31/07/2023    23:52:38                  064   01/08/2023
# 1          31/07/2023    23:48:01                  212   01/08/2023
# 2          31/07/2023    23:55:50                  212   01/08/2023
# 3          31/07/2023    23:32:42                  082   01/08/2023
# 4          31/07/2023    23:51:09                  498   01/08/2023
# ...               ...         ...                  ...          ...
# 13735643   31/01/2024    23:47:55                  041   31/01/2024
# 13735644   31/01/2024    23:56:03                  155   31/01/2024
# 13735645   31/01/2024    23:48:34                  115   31/01/2024
# 13735646   31/01/2024    23:45:28                  151   31/01/2024
# 13735647   31/01/2024    23:48:47                  072   31/01/2024
#
#          Hora_Arribo
# 0           00:00:03
# 1           00:00:20
# 2           00:00:30
# 3           00:01:08
# 4           00:01:21
# ...              ...
# 13735643    23:59:41
# 13735644    23:59:53
# 13735645    23:59:56
# 13735646    23:59:58
# 13735647    23:59:59
#
# [13735648 rows x 9 columns]

# %%
eco_bici_df= eco_bici.rename(columns={'Genero_Usuario': 'user_gender',
                                       'Edad_Usuario': 'user_age',
                                       'Bici': 'bike_id',
                                       'Ciclo_Estacion_Retiro': 'pickup_station',
                                       'Fecha_Retiro': 'pickup_date',
                                       'Hora_Retiro': 'pickup_time',
                                       'Ciclo_EstacionArribo': 'return_station',
                                       'Fecha Arribo': 'return_date',
                                       'Hora_Arribo': 'return_time'})

# %%
eco_bici_df.columns
# Out:
# Index(['user_gender', 'user_age', 'bike_id', 'pickup_station', 'pickup_date',
#        'pickup_time', 'return_station', 'return_date', 'return_time'],
#       dtype='object')

# %%
eco_bici_df["user_gender"] = eco_bici_df["user_gender"].fillna('undefined')

# %%
clean_eco_bici_df= eco_bici_df.dropna(subset=['return_station', 'return_date', 'return_time'])
clean_eco_bici_df['user_gender'] = clean_eco_bici_df['user_gender'].replace(['O', '?'], 'undefined')
clean_eco_bici_df["user_gender"] = clean_eco_bici_df["user_gender"].fillna('undefined')

# %%
clean_eco_bici_df['user_gender'].unique()
# Out:
# array(['M', 'F', 'undefined'], dtype=object)

# %%
clean_eco_bici_df1= clean_eco_bici_df.dropna(subset=['user_age'])
null_check(clean_eco_bici_df1)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735643    0
# 13735644    0
# 13735645    0
# 13735646    0
# 13735647    0
# Length: 13735453, dtype: int64
#
# Total null values per column:
# user_gender       0
# user_age          0
# bike_id           0
# pickup_station    0
# pickup_date       0
# pickup_time       0
# return_station    0
# return_date       0
# return_time       0
# dtype: int64

# %%
# #Interesting data in case we want to show the unknown cases where the bikes where not returned, time, age, or finding patterns
# ecobicis_never_returned = eco_bici_df[eco_bici_df['return_station'].isna() | eco_bici_df['return_date'].isna() | eco_bici_df['return_time'].isna()]
# ecobicis_never_returned

# %%
clean_eco_bici_df1

# %% [markdown]
# ### wrangling ecobici df and creating aggregated df

# %%
clean_eco_bici_df1['pickup_time'] = clean_eco_bici_df1['pickup_time'].apply(lambda x: '{:02d}:{:02d}:00'.format(*map(int, x.replace('.', ':').split(':'))))
clean_eco_bici_df1['return_time'] = clean_eco_bici_df1['return_time'].apply(lambda x: '{:02d}:{:02d}:00'.format(*map(int, x.replace('.', ':').split(':'))))
clean_eco_bici_df1
# Out:
#          user_gender  user_age  bike_id pickup_station pickup_date  \
# 0                  M      24.0  2252039            007  31/07/2023
# 1                  M      33.0  8626897            206  31/07/2023
# 2                  M      34.0  4940557            215  31/07/2023
# 3                  F      30.0  2036523            291  31/07/2023
# 4                  F      23.0  8079220            546  31/07/2023
# ...              ...       ...      ...            ...         ...
# 13735643           M      33.0  6683080            022  31/01/2024
# 13735644           M      28.0  2005171            150  31/01/2024
# 13735645           M      26.0  6842108            545  31/01/2024
# 13735646           M      53.0  5478714            007  31/01/2024
# 13735647           F      30.0  3046505            129  31/01/2024
#
#          pickup_time return_station return_date return_time
# 0           23:52:00            064  01/08/2023    00:00:00
# 1           23:48:00            212  01/08/2023    00:00:00
# 2           23:55:00            212  01/08/2023    00:00:00
# 3           23:32:00            082  01/08/2023    00:01:00
# 4           23:51:00            498  01/08/2023    00:01:00
# ...              ...            ...         ...         ...
# 13735643    23:47:00            041  31/01/2024    23:59:00
# 13735644    23:56:00            155  31/01/2024    23:59:00
# 13735645    23:48:00            115  31/01/2024    23:59:00
# 13735646    23:45:00            151  31/01/2024    23:59:00
# 13735647    23:48:00            072  31/01/2024    23:59:00
#
# [13735453 rows x 9 columns]

# %%
# clean_eco_bici_df1['pickup_time'].apply(lambda x: datetime.strptime(x, "%H:%M:%S"))
# clean_eco_bici_df1['pickup_time'] 
# pd.to_timedelta(clean_eco_bici_df1['pickup_time'])

# clean_eco_bici_df1.isna().sum()

# %%
#Convert the time column to datetime format
clean_eco_bici_df1['pickup_time']= pd.to_datetime(clean_eco_bici_df1['pickup_time'], format='%H:%M:%S', errors='coerce').dt.time
clean_eco_bici_df1['return_time']= pd.to_datetime(clean_eco_bici_df1['return_time'], format='%H:%M:%S', errors='coerce').dt.time

clean_eco_bici_df1
# Out:
#          user_gender  user_age  bike_id pickup_station pickup_date  \
# 0                  M      24.0  2252039            007  31/07/2023
# 1                  M      33.0  8626897            206  31/07/2023
# 2                  M      34.0  4940557            215  31/07/2023
# 3                  F      30.0  2036523            291  31/07/2023
# 4                  F      23.0  8079220            546  31/07/2023
# ...              ...       ...      ...            ...         ...
# 13735643           M      33.0  6683080            022  31/01/2024
# 13735644           M      28.0  2005171            150  31/01/2024
# 13735645           M      26.0  6842108            545  31/01/2024
# 13735646           M      53.0  5478714            007  31/01/2024
# 13735647           F      30.0  3046505            129  31/01/2024
#
#          pickup_time return_station return_date return_time
# 0           23:52:00            064  01/08/2023    00:00:00
# 1           23:48:00            212  01/08/2023    00:00:00
# 2           23:55:00            212  01/08/2023    00:00:00
# 3           23:32:00            082  01/08/2023    00:01:00
# 4           23:51:00            498  01/08/2023    00:01:00
# ...              ...            ...         ...         ...
# 13735643    23:47:00            041  31/01/2024    23:59:00
# 13735644    23:56:00            155  31/01/2024    23:59:00
# 13735645    23:48:00            115  31/01/2024    23:59:00
# 13735646    23:45:00            151  31/01/2024    23:59:00
# 13735647    23:48:00            072  31/01/2024    23:59:00
#
# [13735453 rows x 9 columns]

# %%
clean_eco_bici_df= clean_eco_bici_df1.dropna(subset=['pickup_time','return_time'])

# %%
clean_eco_bici_df['pickup_date'] = pd.to_datetime(clean_eco_bici_df['pickup_date'], format='%d/%m/%Y', errors='coerce')
#clean_eco_bici_df['pickup_time'] = pd.to_datetime(clean_eco_bici_df['pickup_time'], format='%H:%M:%S', errors='coerce').dt.time
clean_eco_bici_df['return_date'] = pd.to_datetime(clean_eco_bici_df['return_date'], format='%d/%m/%Y', errors='coerce')
#clean_eco_bici_df['return_time'] = pd.to_datetime(clean_eco_bici_df['return_time'], format='%H:%M:%S', errors='coerce').dt.time
null_check(clean_eco_bici_df)
# Out:
# Total null values per row:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 13735643    0
# 13735644    0
# 13735645    0
# 13735646    0
# 13735647    0
# Length: 13735453, dtype: int64
#
# Total null values per column:
# user_gender       0
# user_age          0
# bike_id           0
# pickup_station    0
# pickup_date       0
# pickup_time       0
# return_station    0
# return_date       0
# return_time       0
# dtype: int64

# %%
clean_eco_bici_df= clean_eco_bici_df.dropna(subset=['pickup_date','return_date'])

# %%
clean_eco_bici_df['pickup_station'] = pd.to_numeric(clean_eco_bici_df['pickup_station'], errors='coerce', downcast='integer')
clean_eco_bici_df['return_station'] = pd.to_numeric(clean_eco_bici_df['pickup_station'], errors='coerce')

# %%
# Concatenate 'pickup_date' and 'pickup_time' to create a new combined datetime column
clean_eco_bici_df['pickup_datetime'] = pd.to_datetime(clean_eco_bici_df['pickup_date'] + pd.to_timedelta(clean_eco_bici_df['pickup_time'].astype(str)))
# Map the combined datetime to a new hourly datetime column
clean_eco_bici_df['hourly_aggregated'] = clean_eco_bici_df['pickup_datetime'].dt.floor('H')
# Calculate duration of the rental
clean_eco_bici_df['return_datetime'] = pd.to_datetime(clean_eco_bici_df['return_date'] + pd.to_timedelta(clean_eco_bici_df['return_time'].astype(str)))
clean_eco_bici_df['duration'] = clean_eco_bici_df['return_datetime'] - clean_eco_bici_df['pickup_datetime']

# %%
stations_df = pd.DataFrame(clean_eco_bici_df.pickup_station.value_counts()).reset_index()
stations_df.tail(10)
# station 271, 1, 27, 182 and 64 have highest pickup counts
# what's up with the last 6 pick up stations?
# Out:
#      pickup_station  count
# 634           606.0    336
# 635           693.0    333
# 636           523.0    330
# 637       4422222.0    323
# 638           581.0    317
# 639           574.0    303
# 640           522.0    299
# 641          1000.0    150
# 642           526.0    149
# 643           528.0     18

# %% [markdown]
# <b> Adding a feature indicating whether the day of rental was a business day or not</b>

# %%
# Map the hourly_aggregated to a new column indicating business day [1] or weekend/holiday [0]

# Public holidays in Mexico City:

public_holidays = [ # month and day
    '01-01', # new year's day
    '02-05', # consistution day
    '03-21', # Benito Juárez's Birthday
    '05-01', # Labour day
    '09-16', # Independence day
    '11-20', # revolution day
    '12-25' # Christmas
]

# convert public_holidays to datetime format
public_holidays_dt = [datetime.strptime(holiday, '%m-%d') for holiday in public_holidays]

# use apply function to check whether datetime in 'hourly_aggregated' is a public holiday or weekend
clean_eco_bici_df['is_business_day'] = clean_eco_bici_df['hourly_aggregated'].apply(
    lambda x: 1 if (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] and (x.weekday() < 5) else 0
)

clean_eco_bici_df
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 0                  M      24.0  2252039             7.0  2023-07-31
# 1                  M      33.0  8626897           206.0  2023-07-31
# 2                  M      34.0  4940557           215.0  2023-07-31
# 3                  F      30.0  2036523           291.0  2023-07-31
# 4                  F      23.0  8079220           546.0  2023-07-31
# ...              ...       ...      ...             ...         ...
# 13735643           M      33.0  6683080            22.0  2024-01-31
# 13735644           M      28.0  2005171           150.0  2024-01-31
# 13735645           M      26.0  6842108           545.0  2024-01-31
# 13735646           M      53.0  5478714             7.0  2024-01-31
# 13735647           F      30.0  3046505           129.0  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 0           23:52:00             7.0  2023-08-01    00:00:00
# 1           23:48:00           206.0  2023-08-01    00:00:00
# 2           23:55:00           215.0  2023-08-01    00:00:00
# 3           23:32:00           291.0  2023-08-01    00:01:00
# 4           23:51:00           546.0  2023-08-01    00:01:00
# ...              ...             ...         ...         ...
# 13735643    23:47:00            22.0  2024-01-31    23:59:00
# 13735644    23:56:00           150.0  2024-01-31    23:59:00
# 13735645    23:48:00           545.0  2024-01-31    23:59:00
# 13735646    23:45:00             7.0  2024-01-31    23:59:00
# 13735647    23:48:00           129.0  2024-01-31    23:59:00
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 0        2023-07-31 23:52:00 2023-07-31 23:00:00 2023-08-01 00:00:00
# 1        2023-07-31 23:48:00 2023-07-31 23:00:00 2023-08-01 00:00:00
# 2        2023-07-31 23:55:00 2023-07-31 23:00:00 2023-08-01 00:00:00
# 3        2023-07-31 23:32:00 2023-07-31 23:00:00 2023-08-01 00:01:00
# 4        2023-07-31 23:51:00 2023-07-31 23:00:00 2023-08-01 00:01:00
# ...                      ...                 ...                 ...
# 13735643 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735644 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735645 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735646 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735647 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:59:00
#
#                 duration  is_business_day
# 0        0 days 00:08:00                1
# 1        0 days 00:12:00                1
# 2        0 days 00:05:00                1
# 3        0 days 00:29:00                1
# 4        0 days 00:10:00                1
# ...                  ...              ...
# 13735643 0 days 00:12:00                1
# 13735644 0 days 00:03:00                1
# 13735645 0 days 00:11:00                1
# 13735646 0 days 00:14:00                1
# 13735647 0 days 00:11:00                1
#
# [13735453 rows x 14 columns]

# %%
clean_eco_bici_df= clean_eco_bici_df.sort_values(by='pickup_datetime')
clean_eco_bici_df.reset_index(drop=True, inplace=True)

# %%
clean_eco_bici_df= clean_eco_bici_df.dropna(subset=['pickup_station','return_station'])

# %%
# Define columns to convert to integers
columns_to_convert = ['user_age', 'pickup_station', 'return_station']

# Convert specified columns to integers
clean_eco_bici_df[columns_to_convert] = clean_eco_bici_df[columns_to_convert].astype(int)

# %%
# export to csv for Tableau
clean_eco_bici_df.to_csv('clean_eco_bici_df.csv')

# %%
clean_eco_bici_df.tail(50)
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 13735403           M        19  7410467             419  2024-01-31
# 13735404           M        43  6668115             145  2024-01-31
# 13735405           F        19  3223575             270  2024-01-31
# 13735406           M        32  2142115             258  2024-01-31
# 13735407           M        38  3184918             416  2024-01-31
# 13735408           M        32  6700058               9  2024-01-31
# 13735409           M        53  5478714               7  2024-01-31
# 13735410           M        26  8438061             619  2024-01-31
# 13735411           M        31  2288678              18  2024-01-31
# 13735412           M        26  3966611              47  2024-01-31
# 13735413           M        39  6549240              40  2024-01-31
# 13735414           M        30  4740635             281  2024-01-31
# 13735415           F        24  8277634              22  2024-01-31
# 13735416           M        31  5373261             592  2024-01-31
# 13735417           M        32  4834982             123  2024-01-31
# 13735418           M        23  5014865             260  2024-01-31
# 13735419           M        33  6683080              22  2024-01-31
# 13735420           M        25  2204139              20  2024-01-31
# 13735421           M        25  7564792              20  2024-01-31
# 13735422           F        39  8396699             545  2024-01-31
# 13735423           M        49  7016173             485  2024-01-31
# 13735424           M        23  6463905             301  2024-01-31
# 13735425           F        30  3046505             129  2024-01-31
# 13735426           M        35  5812672             157  2024-01-31
# 13735427           M        32  8178667              52  2024-01-31
# 13735428           M        26  6842108             545  2024-01-31
# 13735429           F        31  3375813             415  2024-01-31
# 13735430           M        20  8478208             625  2024-01-31
# 13735431           F        24  7291677               7  2024-01-31
# 13735432           M        38  3804572             414  2024-01-31
# 13735433           F        32  7652548             254  2024-01-31
# 13735434           M        26  4891628             625  2024-01-31
# 13735435           M        23  7920309             549  2024-01-31
# 13735436           M        36  4475331             415  2024-01-31
# 13735437           M        31  8759128             135  2024-01-31
# 13735438           M        30  2301265             145  2024-01-31
# 13735439           M        41  3053642              86  2024-01-31
# 13735440           M        39  8274540             141  2024-01-31
# 13735441           M        25  8722605               7  2024-01-31
# 13735442           M        25  3824075             111  2024-01-31
# 13735443           M        30  7125685             150  2024-01-31
# 13735444           M        27  4820759             551  2024-01-31
# 13735445           F        43  4956959             307  2024-01-31
# 13735446           F        33  4334041             145  2024-01-31
# 13735447           M        32  4696209             301  2024-01-31
# 13735448           M        26  4085452             111  2024-01-31
# 13735449           M        21  8516015             548  2024-01-31
# 13735450           M        35  2760585             115  2024-01-31
# 13735451           F        31  2132561             115  2024-01-31
# 13735452           M        28  2005171             150  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 13735403    23:44:00             419  2024-01-31    23:54:00
# 13735404    23:44:00             145  2024-01-31    23:49:00
# 13735405    23:44:00             270  2024-01-31    23:53:00
# 13735406    23:44:00             258  2024-01-31    23:54:00
# 13735407    23:45:00             416  2024-01-31    23:47:00
# 13735408    23:45:00               9  2024-01-31    23:47:00
# 13735409    23:45:00               7  2024-01-31    23:59:00
# 13735410    23:45:00             619  2024-01-31    23:47:00
# 13735411    23:45:00              18  2024-01-31    23:59:00
# 13735412    23:45:00              47  2024-01-31    23:52:00
# 13735413    23:45:00              40  2024-01-31    23:50:00
# 13735414    23:45:00             281  2024-01-31    23:52:00
# 13735415    23:46:00              22  2024-01-31    23:53:00
# 13735416    23:46:00             592  2024-01-31    23:52:00
# 13735417    23:46:00             123  2024-01-31    23:49:00
# 13735418    23:46:00             260  2024-01-31    23:52:00
# 13735419    23:47:00              22  2024-01-31    23:59:00
# 13735420    23:47:00              20  2024-01-31    23:54:00
# 13735421    23:47:00              20  2024-01-31    23:54:00
# 13735422    23:47:00             545  2024-01-31    23:51:00
# 13735423    23:47:00             485  2024-01-31    23:51:00
# 13735424    23:48:00             301  2024-01-31    23:52:00
# 13735425    23:48:00             129  2024-01-31    23:59:00
# 13735426    23:48:00             157  2024-01-31    23:50:00
# 13735427    23:48:00              52  2024-01-31    23:53:00
# 13735428    23:48:00             545  2024-01-31    23:59:00
# 13735429    23:48:00             415  2024-01-31    23:59:00
# 13735430    23:49:00             625  2024-01-31    23:57:00
# 13735431    23:49:00               7  2024-01-31    23:59:00
# 13735432    23:49:00             414  2024-01-31    23:52:00
# 13735433    23:49:00             254  2024-01-31    23:59:00
# 13735434    23:49:00             625  2024-01-31    23:57:00
# 13735435    23:49:00             549  2024-01-31    23:57:00
# 13735436    23:49:00             415  2024-01-31    23:55:00
# 13735437    23:49:00             135  2024-01-31    23:57:00
# 13735438    23:50:00             145  2024-01-31    23:56:00
# 13735439    23:50:00              86  2024-01-31    23:59:00
# 13735440    23:50:00             141  2024-01-31    23:55:00
# 13735441    23:50:00               7  2024-01-31    23:59:00
# 13735442    23:50:00             111  2024-01-31    23:57:00
# 13735443    23:51:00             150  2024-01-31    23:56:00
# 13735444    23:51:00             551  2024-01-31    23:55:00
# 13735445    23:51:00             307  2024-01-31    23:57:00
# 13735446    23:51:00             145  2024-01-31    23:56:00
# 13735447    23:52:00             301  2024-01-31    23:55:00
# 13735448    23:53:00             111  2024-01-31    23:57:00
# 13735449    23:55:00             548  2024-01-31    23:59:00
# 13735450    23:56:00             115  2024-01-31    23:58:00
# 13735451    23:56:00             115  2024-01-31    23:58:00
# 13735452    23:56:00             150  2024-01-31    23:59:00
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 13735403 2024-01-31 23:44:00 2024-01-31 23:00:00 2024-01-31 23:54:00
# 13735404 2024-01-31 23:44:00 2024-01-31 23:00:00 2024-01-31 23:49:00
# 13735405 2024-01-31 23:44:00 2024-01-31 23:00:00 2024-01-31 23:53:00
# 13735406 2024-01-31 23:44:00 2024-01-31 23:00:00 2024-01-31 23:54:00
# 13735407 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:47:00
# 13735408 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:47:00
# 13735409 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735410 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:47:00
# 13735411 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735412 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735413 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:50:00
# 13735414 2024-01-31 23:45:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735415 2024-01-31 23:46:00 2024-01-31 23:00:00 2024-01-31 23:53:00
# 13735416 2024-01-31 23:46:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735417 2024-01-31 23:46:00 2024-01-31 23:00:00 2024-01-31 23:49:00
# 13735418 2024-01-31 23:46:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735419 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735420 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:54:00
# 13735421 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:54:00
# 13735422 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:51:00
# 13735423 2024-01-31 23:47:00 2024-01-31 23:00:00 2024-01-31 23:51:00
# 13735424 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735425 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735426 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:50:00
# 13735427 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:53:00
# 13735428 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735429 2024-01-31 23:48:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735430 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735431 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735432 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:52:00
# 13735433 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735434 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735435 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735436 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:55:00
# 13735437 2024-01-31 23:49:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735438 2024-01-31 23:50:00 2024-01-31 23:00:00 2024-01-31 23:56:00
# 13735439 2024-01-31 23:50:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735440 2024-01-31 23:50:00 2024-01-31 23:00:00 2024-01-31 23:55:00
# 13735441 2024-01-31 23:50:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735442 2024-01-31 23:50:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735443 2024-01-31 23:51:00 2024-01-31 23:00:00 2024-01-31 23:56:00
# 13735444 2024-01-31 23:51:00 2024-01-31 23:00:00 2024-01-31 23:55:00
# 13735445 2024-01-31 23:51:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735446 2024-01-31 23:51:00 2024-01-31 23:00:00 2024-01-31 23:56:00
# 13735447 2024-01-31 23:52:00 2024-01-31 23:00:00 2024-01-31 23:55:00
# 13735448 2024-01-31 23:53:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735449 2024-01-31 23:55:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735450 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:58:00
# 13735451 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:58:00
# 13735452 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:59:00
#
#                 duration  is_business_day
# 13735403 0 days 00:10:00                1
# 13735404 0 days 00:05:00                1
# 13735405 0 days 00:09:00                1
# 13735406 0 days 00:10:00                1
# 13735407 0 days 00:02:00                1
# 13735408 0 days 00:02:00                1
# 13735409 0 days 00:14:00                1
# 13735410 0 days 00:02:00                1
# 13735411 0 days 00:14:00                1
# 13735412 0 days 00:07:00                1
# 13735413 0 days 00:05:00                1
# 13735414 0 days 00:07:00                1
# 13735415 0 days 00:07:00                1
# 13735416 0 days 00:06:00                1
# 13735417 0 days 00:03:00                1
# 13735418 0 days 00:06:00                1
# 13735419 0 days 00:12:00                1
# 13735420 0 days 00:07:00                1
# 13735421 0 days 00:07:00                1
# 13735422 0 days 00:04:00                1
# 13735423 0 days 00:04:00                1
# 13735424 0 days 00:04:00                1
# 13735425 0 days 00:11:00                1
# 13735426 0 days 00:02:00                1
# 13735427 0 days 00:05:00                1
# 13735428 0 days 00:11:00                1
# 13735429 0 days 00:11:00                1
# 13735430 0 days 00:08:00                1
# 13735431 0 days 00:10:00                1
# 13735432 0 days 00:03:00                1
# 13735433 0 days 00:10:00                1
# 13735434 0 days 00:08:00                1
# 13735435 0 days 00:08:00                1
# 13735436 0 days 00:06:00                1
# 13735437 0 days 00:08:00                1
# 13735438 0 days 00:06:00                1
# 13735439 0 days 00:09:00                1
# 13735440 0 days 00:05:00                1
# 13735441 0 days 00:09:00                1
# 13735442 0 days 00:07:00                1
# 13735443 0 days 00:05:00                1
# 13735444 0 days 00:04:00                1
# 13735445 0 days 00:06:00                1
# 13735446 0 days 00:05:00                1
# 13735447 0 days 00:03:00                1
# 13735448 0 days 00:04:00                1
# 13735449 0 days 00:04:00                1
# 13735450 0 days 00:02:00                1
# 13735451 0 days 00:02:00                1
# 13735452 0 days 00:03:00                1

# %% [markdown]
# <b>Split dataset into individual dataframes per bike station</b>

# %%
# instantiate a list of the individual pickup stations 
pickup_stations = clean_eco_bici_df.pickup_station.unique()
pickup_stations
# Out:
# array([     81,      56,      22,     287,     302,      19,     116,
#            131,     254,     111,      16,     157,     228,     330,
#            220,     249,       2,      79,      46,     320,      74,
#             65,      43,      25,      57,     214,       3,     212,
#            343,     132,     105,      99,      30,     260,     137,
#            150,     175,     285,     454,      35,     261,      89,
#             33,      31,     255,      76,      63,     281,     384,
#            124,     115,      10,     472,     461,     152,     345,
#             41,     181,     123,     439,     393,     133,     270,
#            114,     354,     327,     263,     128,      64,     119,
#            102,     284,      72,     466,     318,     322,     428,
#            147,     378,     476,     180,     555,      70,     427,
#            134,      93,     467,     415,      40,     372,     196,
#            161,      66,     312,     122,      83,       6,       7,
#            293,      12,     341,     165,     110,     397,     118,
#            280,     337,     204,       5,     381,     360,     112,
#            335,      59,     405,     195,     166,      44,     434,
#            174,     141,     278,     140,     243,      32,     407,
#            399,     213,     189,      29,     216,      42,     374,
#             67,     226,     241,     479,      37,     199,     358,
#            113,      53,     256,     421,     167,     447,     475,
#             36,     432,     282,     450,      58,     387,     308,
#            143,     126,     464,     259,      95,     200,      71,
#            306,     414,     367,      97,     156,     429,     307,
#            173,     109,     325,     127,     370,     424,      91,
#            229,     361,     222,      49,     218,      88,      82,
#            303,     100,     412,     144,     339,     298,     349,
#             60,      92,     120,     365,     348,     190,     148,
#            288,     283,     300,     207,     234,     375,     409,
#            125,     139,     262,     353,     332,     188,     417,
#            469,     419,     246,     179,     437,     315,     185,
#            377,     413,      55,     362,     394,     456,     177,
#             48,     247,     231,     333,     423,     460,     468,
#            443,     459,     457,     324,     438,     104,     294,
#             80,      94,     135,     136,      75,      15,      17,
#             14,      20,      27,     121,     252,     251,     117,
#            217,     224,     250,     215,     202,     258,     240,
#             47,      11,      18,      38,      13,     449,     265,
#             23,      34,      28,     103,     470,     183,      85,
#            227,     232,     211,       1,     480,     474,     176,
#            478,     257,     248,     219,     465,     455,     221,
#             86,     201,     223,    1000,     208,     210,     233,
#             87,       8,     206,     242,     451,      21,     244,
#            142,     225,     553,     145,      51,     186,     253,
#            452,      61,      62,      50,     448,     668,     554,
#            129,     552,     130,      68,     151,     550,     155,
#            551,     162,     656,     170,     549,      24,       9,
#            191,      52,      45,     657,     670,     194,     286,
#             26,     160,     660,     667,     658,     659,     163,
#             84,     184,      77,      78,      73,      54,      96,
#            239,     305,     169,     168,     153,     171,     154,
#            309,     430,     182,     291,     314,     279,     187,
#            331,     310,     297,     323,     296,     295,     319,
#            351,     329,     164,     340,     336,     669,     352,
#            209,     355,     304,     346,     299,     276,     380,
#            334,     385,     316,     317,      90,     290,     363,
#            366,     369,     347,     292,     328,     373,     342,
#            205,     422,     338,     389,     395,     371,     416,
#            386,     401,     420,     436,     396,     359,     402,
#            433,     442,     356,     404,     398,     326,     230,
#            138,     203,     178,     172,      39,     483,     198,
#            321,     313,     485,     277,     444,     471,     301,
#            462,     441,     477,     392,     546,     453,       4,
#            357,     473,     149,     146,      69,     245,     537,
#            481,     425,     492,     496,     495,     504,     498,
#            502,     536,     497,     507,     506,     503,     499,
#            541,     482,     458,     486,      98,     543,     672,
#            703,     540,     673,     700,     709,     706,     704,
#            491,     702,     545,     708,     626,     696,     615,
#            597,     694,     630,     617,     691,     689,     692,
#            701,     618,     612,     661,     652,     688,     629,
#            651,     649,     602,     624,     611,     637,     639,
#            633,     592,     619,     623,     620,     562,     559,
#            634,     589,     560,     579,     568,     564,     577,
#            609,     567,     604,     494,     573,     501,     571,
#            580,     569,     643,     603,     578,     645,     563,
#            697,     575,     590,     556,     584,     463,     650,
#            679,     678,     664,     666,     663,     662,     686,
#            525,     527,     521,     519,     518,     517,     516,
#            531,     514,     655,     684,     665,     635,     613,
#            631,     594,     628,     557,     687,     510,     512,
#            548,     608,     539,     622,     642, 4422222,     595,
#            585,     561,     636,     596,     621,     598,     698,
#            607,     685,     699,     671,     542,     610,     493,
#            500,     583,     599,     644,     572,     591,     601,
#            695,     640,     484,     593,     544,     490,     106,
#            707,     693,     538,     487,     654,     648,     570,
#            674,     605,     653,     705,     600,     638,     505,
#            690,     627,     641,     646,     558,     576,     632,
#            197,     489,     614,     565,     566,     625,     581,
#            616,     586,     587,     574,     535,     582,     683,
#            488,     606,     547,     526,     523,     522,     528])

# %%
# saving each individual dataframe into a dictionary, where station number is key and df is value
# access each df later by calling the station number as value in the dict, e.g. stations_dict['station_number']

stations_dict = {}

for station in pickup_stations: 
    stations_dict[station] = clean_eco_bici_df[(clean_eco_bici_df['pickup_station']==station)]
    print(f"Dataframe for station {station} was created.")
print(f"Number of new dataframes: {len(stations_dict)}")
# Out:
# Dataframe for station 81 was created.
# Dataframe for station 56 was created.
# Dataframe for station 22 was created.
# Dataframe for station 287 was created.
# Dataframe for station 302 was created.
# Dataframe for station 19 was created.
# Dataframe for station 116 was created.
# Dataframe for station 131 was created.
# Dataframe for station 254 was created.
# Dataframe for station 111 was created.
# Dataframe for station 16 was created.
# Dataframe for station 157 was created.
# Dataframe for station 228 was created.
# Dataframe for station 330 was created.
# Dataframe for station 220 was created.
# Dataframe for station 249 was created.
# Dataframe for station 2 was created.
# Dataframe for station 79 was created.
# Dataframe for station 46 was created.
# Dataframe for station 320 was created.
# Dataframe for station 74 was created.
# Dataframe for station 65 was created.
# Dataframe for station 43 was created.
# Dataframe for station 25 was created.
# Dataframe for station 57 was created.
# Dataframe for station 214 was created.
# Dataframe for station 3 was created.
# Dataframe for station 212 was created.
# Dataframe for station 343 was created.
# Dataframe for station 132 was created.
# Dataframe for station 105 was created.
# Dataframe for station 99 was created.
# Dataframe for station 30 was created.
# Dataframe for station 260 was created.
# Dataframe for station 137 was created.
# Dataframe for station 150 was created.
# Dataframe for station 175 was created.
# Dataframe for station 285 was created.
# Dataframe for station 454 was created.
# Dataframe for station 35 was created.
# Dataframe for station 261 was created.
# Dataframe for station 89 was created.
# Dataframe for station 33 was created.
# Dataframe for station 31 was created.
# Dataframe for station 255 was created.
# Dataframe for station 76 was created.
# Dataframe for station 63 was created.
# Dataframe for station 281 was created.
# Dataframe for station 384 was created.
# Dataframe for station 124 was created.
# Dataframe for station 115 was created.
# Dataframe for station 10 was created.
# Dataframe for station 472 was created.
# Dataframe for station 461 was created.
# Dataframe for station 152 was created.
# Dataframe for station 345 was created.
# Dataframe for station 41 was created.
# Dataframe for station 181 was created.
# Dataframe for station 123 was created.
# Dataframe for station 439 was created.
# Dataframe for station 393 was created.
# Dataframe for station 133 was created.
# Dataframe for station 270 was created.
# Dataframe for station 114 was created.
# Dataframe for station 354 was created.
# Dataframe for station 327 was created.
# Dataframe for station 263 was created.
# Dataframe for station 128 was created.
# Dataframe for station 64 was created.
# Dataframe for station 119 was created.
# Dataframe for station 102 was created.
# Dataframe for station 284 was created.
# Dataframe for station 72 was created.
# Dataframe for station 466 was created.
# Dataframe for station 318 was created.
# Dataframe for station 322 was created.
# Dataframe for station 428 was created.
# Dataframe for station 147 was created.
# Dataframe for station 378 was created.
# Dataframe for station 476 was created.
# Dataframe for station 180 was created.
# Dataframe for station 555 was created.
# Dataframe for station 70 was created.
# Dataframe for station 427 was created.
# Dataframe for station 134 was created.
# Dataframe for station 93 was created.
# Dataframe for station 467 was created.
# Dataframe for station 415 was created.
# Dataframe for station 40 was created.
# Dataframe for station 372 was created.
# Dataframe for station 196 was created.
# Dataframe for station 161 was created.
# Dataframe for station 66 was created.
# Dataframe for station 312 was created.
# Dataframe for station 122 was created.
# Dataframe for station 83 was created.
# Dataframe for station 6 was created.
# Dataframe for station 7 was created.
# Dataframe for station 293 was created.
# Dataframe for station 12 was created.
# Dataframe for station 341 was created.
# Dataframe for station 165 was created.
# Dataframe for station 110 was created.
# Dataframe for station 397 was created.
# Dataframe for station 118 was created.
# Dataframe for station 280 was created.
# Dataframe for station 337 was created.
# Dataframe for station 204 was created.
# Dataframe for station 5 was created.
# Dataframe for station 381 was created.
# Dataframe for station 360 was created.
# Dataframe for station 112 was created.
# Dataframe for station 335 was created.
# Dataframe for station 59 was created.
# Dataframe for station 405 was created.
# Dataframe for station 195 was created.
# Dataframe for station 166 was created.
# Dataframe for station 44 was created.
# Dataframe for station 434 was created.
# Dataframe for station 174 was created.
# Dataframe for station 141 was created.
# Dataframe for station 278 was created.
# Dataframe for station 140 was created.
# Dataframe for station 243 was created.
# Dataframe for station 32 was created.
# Dataframe for station 407 was created.
# Dataframe for station 399 was created.
# Dataframe for station 213 was created.
# Dataframe for station 189 was created.
# Dataframe for station 29 was created.
# Dataframe for station 216 was created.
# Dataframe for station 42 was created.
# Dataframe for station 374 was created.
# Dataframe for station 67 was created.
# Dataframe for station 226 was created.
# Dataframe for station 241 was created.
# Dataframe for station 479 was created.
# Dataframe for station 37 was created.
# Dataframe for station 199 was created.
# Dataframe for station 358 was created.
# Dataframe for station 113 was created.
# Dataframe for station 53 was created.
# Dataframe for station 256 was created.
# Dataframe for station 421 was created.
# Dataframe for station 167 was created.
# Dataframe for station 447 was created.
# Dataframe for station 475 was created.
# Dataframe for station 36 was created.
# Dataframe for station 432 was created.
# Dataframe for station 282 was created.
# Dataframe for station 450 was created.
# Dataframe for station 58 was created.
# Dataframe for station 387 was created.
# Dataframe for station 308 was created.
# Dataframe for station 143 was created.
# Dataframe for station 126 was created.
# Dataframe for station 464 was created.
# Dataframe for station 259 was created.
# Dataframe for station 95 was created.
# Dataframe for station 200 was created.
# Dataframe for station 71 was created.
# Dataframe for station 306 was created.
# Dataframe for station 414 was created.
# Dataframe for station 367 was created.
# Dataframe for station 97 was created.
# Dataframe for station 156 was created.
# Dataframe for station 429 was created.
# Dataframe for station 307 was created.
# Dataframe for station 173 was created.
# Dataframe for station 109 was created.
# Dataframe for station 325 was created.
# Dataframe for station 127 was created.
# Dataframe for station 370 was created.
# Dataframe for station 424 was created.
# Dataframe for station 91 was created.
# Dataframe for station 229 was created.
# Dataframe for station 361 was created.
# Dataframe for station 222 was created.
# Dataframe for station 49 was created.
# Dataframe for station 218 was created.
# Dataframe for station 88 was created.
# Dataframe for station 82 was created.
# Dataframe for station 303 was created.
# Dataframe for station 100 was created.
# Dataframe for station 412 was created.
# Dataframe for station 144 was created.
# Dataframe for station 339 was created.
# Dataframe for station 298 was created.
# Dataframe for station 349 was created.
# Dataframe for station 60 was created.
# Dataframe for station 92 was created.
# Dataframe for station 120 was created.
# Dataframe for station 365 was created.
# Dataframe for station 348 was created.
# Dataframe for station 190 was created.
# Dataframe for station 148 was created.
# Dataframe for station 288 was created.
# Dataframe for station 283 was created.
# Dataframe for station 300 was created.
# Dataframe for station 207 was created.
# Dataframe for station 234 was created.
# Dataframe for station 375 was created.
# Dataframe for station 409 was created.
# Dataframe for station 125 was created.
# Dataframe for station 139 was created.
# Dataframe for station 262 was created.
# Dataframe for station 353 was created.
# Dataframe for station 332 was created.
# Dataframe for station 188 was created.
# Dataframe for station 417 was created.
# Dataframe for station 469 was created.
# Dataframe for station 419 was created.
# Dataframe for station 246 was created.
# Dataframe for station 179 was created.
# Dataframe for station 437 was created.
# Dataframe for station 315 was created.
# Dataframe for station 185 was created.
# Dataframe for station 377 was created.
# Dataframe for station 413 was created.
# Dataframe for station 55 was created.
# Dataframe for station 362 was created.
# Dataframe for station 394 was created.
# Dataframe for station 456 was created.
# Dataframe for station 177 was created.
# Dataframe for station 48 was created.
# Dataframe for station 247 was created.
# Dataframe for station 231 was created.
# Dataframe for station 333 was created.
# Dataframe for station 423 was created.
# Dataframe for station 460 was created.
# Dataframe for station 468 was created.
# Dataframe for station 443 was created.
# Dataframe for station 459 was created.
# Dataframe for station 457 was created.
# Dataframe for station 324 was created.
# Dataframe for station 438 was created.
# Dataframe for station 104 was created.
# Dataframe for station 294 was created.
# Dataframe for station 80 was created.
# Dataframe for station 94 was created.
# Dataframe for station 135 was created.
# Dataframe for station 136 was created.
# Dataframe for station 75 was created.
# Dataframe for station 15 was created.
# Dataframe for station 17 was created.
# Dataframe for station 14 was created.
# Dataframe for station 20 was created.
# Dataframe for station 27 was created.
# Dataframe for station 121 was created.
# Dataframe for station 252 was created.
# Dataframe for station 251 was created.
# Dataframe for station 117 was created.
# Dataframe for station 217 was created.
# Dataframe for station 224 was created.
# Dataframe for station 250 was created.
# Dataframe for station 215 was created.
# Dataframe for station 202 was created.
# Dataframe for station 258 was created.
# Dataframe for station 240 was created.
# Dataframe for station 47 was created.
# Dataframe for station 11 was created.
# Dataframe for station 18 was created.
# Dataframe for station 38 was created.
# Dataframe for station 13 was created.
# Dataframe for station 449 was created.
# Dataframe for station 265 was created.
# Dataframe for station 23 was created.
# Dataframe for station 34 was created.
# Dataframe for station 28 was created.
# Dataframe for station 103 was created.
# Dataframe for station 470 was created.
# Dataframe for station 183 was created.
# Dataframe for station 85 was created.
# Dataframe for station 227 was created.
# Dataframe for station 232 was created.
# Dataframe for station 211 was created.
# Dataframe for station 1 was created.
# Dataframe for station 480 was created.
# Dataframe for station 474 was created.
# Dataframe for station 176 was created.
# Dataframe for station 478 was created.
# Dataframe for station 257 was created.
# Dataframe for station 248 was created.
# Dataframe for station 219 was created.
# Dataframe for station 465 was created.
# Dataframe for station 455 was created.
# Dataframe for station 221 was created.
# Dataframe for station 86 was created.
# Dataframe for station 201 was created.
# Dataframe for station 223 was created.
# Dataframe for station 1000 was created.
# Dataframe for station 208 was created.
# Dataframe for station 210 was created.
# Dataframe for station 233 was created.
# Dataframe for station 87 was created.
# Dataframe for station 8 was created.
# Dataframe for station 206 was created.
# Dataframe for station 242 was created.
# Dataframe for station 451 was created.
# Dataframe for station 21 was created.
# Dataframe for station 244 was created.
# Dataframe for station 142 was created.
# Dataframe for station 225 was created.
# Dataframe for station 553 was created.
# Dataframe for station 145 was created.
# Dataframe for station 51 was created.
# Dataframe for station 186 was created.
# Dataframe for station 253 was created.
# Dataframe for station 452 was created.
# Dataframe for station 61 was created.
# Dataframe for station 62 was created.
# Dataframe for station 50 was created.
# Dataframe for station 448 was created.
# Dataframe for station 668 was created.
# Dataframe for station 554 was created.
# Dataframe for station 129 was created.
# Dataframe for station 552 was created.
# Dataframe for station 130 was created.
# Dataframe for station 68 was created.
# Dataframe for station 151 was created.
# Dataframe for station 550 was created.
# Dataframe for station 155 was created.
# Dataframe for station 551 was created.
# Dataframe for station 162 was created.
# Dataframe for station 656 was created.
# Dataframe for station 170 was created.
# Dataframe for station 549 was created.
# Dataframe for station 24 was created.
# Dataframe for station 9 was created.
# Dataframe for station 191 was created.
# Dataframe for station 52 was created.
# Dataframe for station 45 was created.
# Dataframe for station 657 was created.
# Dataframe for station 670 was created.
# Dataframe for station 194 was created.
# Dataframe for station 286 was created.
# Dataframe for station 26 was created.
# Dataframe for station 160 was created.
# Dataframe for station 660 was created.
# Dataframe for station 667 was created.
# Dataframe for station 658 was created.
# Dataframe for station 659 was created.
# Dataframe for station 163 was created.
# Dataframe for station 84 was created.
# Dataframe for station 184 was created.
# Dataframe for station 77 was created.
# Dataframe for station 78 was created.
# Dataframe for station 73 was created.
# Dataframe for station 54 was created.
# Dataframe for station 96 was created.
# Dataframe for station 239 was created.
# Dataframe for station 305 was created.
# Dataframe for station 169 was created.
# Dataframe for station 168 was created.
# Dataframe for station 153 was created.
# Dataframe for station 171 was created.
# Dataframe for station 154 was created.
# Dataframe for station 309 was created.
# Dataframe for station 430 was created.
# Dataframe for station 182 was created.
# Dataframe for station 291 was created.
# Dataframe for station 314 was created.
# Dataframe for station 279 was created.
# Dataframe for station 187 was created.
# Dataframe for station 331 was created.
# Dataframe for station 310 was created.
# Dataframe for station 297 was created.
# Dataframe for station 323 was created.
# Dataframe for station 296 was created.
# Dataframe for station 295 was created.
# Dataframe for station 319 was created.
# Dataframe for station 351 was created.
# Dataframe for station 329 was created.
# Dataframe for station 164 was created.
# Dataframe for station 340 was created.
# Dataframe for station 336 was created.
# Dataframe for station 669 was created.
# Dataframe for station 352 was created.
# Dataframe for station 209 was created.
# Dataframe for station 355 was created.
# Dataframe for station 304 was created.
# Dataframe for station 346 was created.
# Dataframe for station 299 was created.
# Dataframe for station 276 was created.
# Dataframe for station 380 was created.
# Dataframe for station 334 was created.
# Dataframe for station 385 was created.
# Dataframe for station 316 was created.
# Dataframe for station 317 was created.
# Dataframe for station 90 was created.
# Dataframe for station 290 was created.
# Dataframe for station 363 was created.
# Dataframe for station 366 was created.
# Dataframe for station 369 was created.
# Dataframe for station 347 was created.
# Dataframe for station 292 was created.
# Dataframe for station 328 was created.
# Dataframe for station 373 was created.
# Dataframe for station 342 was created.
# Dataframe for station 205 was created.
# Dataframe for station 422 was created.
# Dataframe for station 338 was created.
# Dataframe for station 389 was created.
# Dataframe for station 395 was created.
# Dataframe for station 371 was created.
# Dataframe for station 416 was created.
# Dataframe for station 386 was created.
# Dataframe for station 401 was created.
# Dataframe for station 420 was created.
# Dataframe for station 436 was created.
# Dataframe for station 396 was created.
# Dataframe for station 359 was created.
# Dataframe for station 402 was created.
# Dataframe for station 433 was created.
# Dataframe for station 442 was created.
# Dataframe for station 356 was created.
# Dataframe for station 404 was created.
# Dataframe for station 398 was created.
# Dataframe for station 326 was created.
# Dataframe for station 230 was created.
# Dataframe for station 138 was created.
# Dataframe for station 203 was created.
# Dataframe for station 178 was created.
# Dataframe for station 172 was created.
# Dataframe for station 39 was created.
# Dataframe for station 483 was created.
# Dataframe for station 198 was created.
# Dataframe for station 321 was created.
# Dataframe for station 313 was created.
# Dataframe for station 485 was created.
# Dataframe for station 277 was created.
# Dataframe for station 444 was created.
# Dataframe for station 471 was created.
# Dataframe for station 301 was created.
# Dataframe for station 462 was created.
# Dataframe for station 441 was created.
# Dataframe for station 477 was created.
# Dataframe for station 392 was created.
# Dataframe for station 546 was created.
# Dataframe for station 453 was created.
# Dataframe for station 4 was created.
# Dataframe for station 357 was created.
# Dataframe for station 473 was created.
# Dataframe for station 149 was created.
# Dataframe for station 146 was created.
# Dataframe for station 69 was created.
# Dataframe for station 245 was created.
# Dataframe for station 537 was created.
# Dataframe for station 481 was created.
# Dataframe for station 425 was created.
# Dataframe for station 492 was created.
# Dataframe for station 496 was created.
# Dataframe for station 495 was created.
# Dataframe for station 504 was created.
# Dataframe for station 498 was created.
# Dataframe for station 502 was created.
# Dataframe for station 536 was created.
# Dataframe for station 497 was created.
# Dataframe for station 507 was created.
# Dataframe for station 506 was created.
# Dataframe for station 503 was created.
# Dataframe for station 499 was created.
# Dataframe for station 541 was created.
# Dataframe for station 482 was created.
# Dataframe for station 458 was created.
# Dataframe for station 486 was created.
# Dataframe for station 98 was created.
# Dataframe for station 543 was created.
# Dataframe for station 672 was created.
# Dataframe for station 703 was created.
# Dataframe for station 540 was created.
# Dataframe for station 673 was created.
# Dataframe for station 700 was created.
# Dataframe for station 709 was created.
# Dataframe for station 706 was created.
# Dataframe for station 704 was created.
# Dataframe for station 491 was created.
# Dataframe for station 702 was created.
# Dataframe for station 545 was created.
# Dataframe for station 708 was created.
# Dataframe for station 626 was created.
# Dataframe for station 696 was created.
# Dataframe for station 615 was created.
# Dataframe for station 597 was created.
# Dataframe for station 694 was created.
# Dataframe for station 630 was created.
# Dataframe for station 617 was created.
# Dataframe for station 691 was created.
# Dataframe for station 689 was created.
# Dataframe for station 692 was created.
# Dataframe for station 701 was created.
# Dataframe for station 618 was created.
# Dataframe for station 612 was created.
# Dataframe for station 661 was created.
# Dataframe for station 652 was created.
# Dataframe for station 688 was created.
# Dataframe for station 629 was created.
# Dataframe for station 651 was created.
# Dataframe for station 649 was created.
# Dataframe for station 602 was created.
# Dataframe for station 624 was created.
# Dataframe for station 611 was created.
# Dataframe for station 637 was created.
# Dataframe for station 639 was created.
# Dataframe for station 633 was created.
# Dataframe for station 592 was created.
# Dataframe for station 619 was created.
# Dataframe for station 623 was created.
# Dataframe for station 620 was created.
# Dataframe for station 562 was created.
# Dataframe for station 559 was created.
# Dataframe for station 634 was created.
# Dataframe for station 589 was created.
# Dataframe for station 560 was created.
# Dataframe for station 579 was created.
# Dataframe for station 568 was created.
# Dataframe for station 564 was created.
# Dataframe for station 577 was created.
# Dataframe for station 609 was created.
# Dataframe for station 567 was created.
# Dataframe for station 604 was created.
# Dataframe for station 494 was created.
# Dataframe for station 573 was created.
# Dataframe for station 501 was created.
# Dataframe for station 571 was created.
# Dataframe for station 580 was created.
# Dataframe for station 569 was created.
# Dataframe for station 643 was created.
# Dataframe for station 603 was created.
# Dataframe for station 578 was created.
# Dataframe for station 645 was created.
# Dataframe for station 563 was created.
# Dataframe for station 697 was created.
# Dataframe for station 575 was created.
# Dataframe for station 590 was created.
# Dataframe for station 556 was created.
# Dataframe for station 584 was created.
# Dataframe for station 463 was created.
# Dataframe for station 650 was created.
# Dataframe for station 679 was created.
# Dataframe for station 678 was created.
# Dataframe for station 664 was created.
# Dataframe for station 666 was created.
# Dataframe for station 663 was created.
# Dataframe for station 662 was created.
# Dataframe for station 686 was created.
# Dataframe for station 525 was created.
# Dataframe for station 527 was created.
# Dataframe for station 521 was created.
# Dataframe for station 519 was created.
# Dataframe for station 518 was created.
# Dataframe for station 517 was created.
# Dataframe for station 516 was created.
# Dataframe for station 531 was created.
# Dataframe for station 514 was created.
# Dataframe for station 655 was created.
# Dataframe for station 684 was created.
# Dataframe for station 665 was created.
# Dataframe for station 635 was created.
# Dataframe for station 613 was created.
# Dataframe for station 631 was created.
# Dataframe for station 594 was created.
# Dataframe for station 628 was created.
# Dataframe for station 557 was created.
# Dataframe for station 687 was created.
# Dataframe for station 510 was created.
# Dataframe for station 512 was created.
# Dataframe for station 548 was created.
# Dataframe for station 608 was created.
# Dataframe for station 539 was created.
# Dataframe for station 622 was created.
# Dataframe for station 642 was created.
# Dataframe for station 4422222 was created.
# Dataframe for station 595 was created.
# Dataframe for station 585 was created.
# Dataframe for station 561 was created.
# Dataframe for station 636 was created.
# Dataframe for station 596 was created.
# Dataframe for station 621 was created.
# Dataframe for station 598 was created.
# Dataframe for station 698 was created.
# Dataframe for station 607 was created.
# Dataframe for station 685 was created.
# Dataframe for station 699 was created.
# Dataframe for station 671 was created.
# Dataframe for station 542 was created.
# Dataframe for station 610 was created.
# Dataframe for station 493 was created.
# Dataframe for station 500 was created.
# Dataframe for station 583 was created.
# Dataframe for station 599 was created.
# Dataframe for station 644 was created.
# Dataframe for station 572 was created.
# Dataframe for station 591 was created.
# Dataframe for station 601 was created.
# Dataframe for station 695 was created.
# Dataframe for station 640 was created.
# Dataframe for station 484 was created.
# Dataframe for station 593 was created.
# Dataframe for station 544 was created.
# Dataframe for station 490 was created.
# Dataframe for station 106 was created.
# Dataframe for station 707 was created.
# Dataframe for station 693 was created.
# Dataframe for station 538 was created.
# Dataframe for station 487 was created.
# Dataframe for station 654 was created.
# Dataframe for station 648 was created.
# Dataframe for station 570 was created.
# Dataframe for station 674 was created.
# Dataframe for station 605 was created.
# Dataframe for station 653 was created.
# Dataframe for station 705 was created.
# Dataframe for station 600 was created.
# Dataframe for station 638 was created.
# Dataframe for station 505 was created.
# Dataframe for station 690 was created.
# Dataframe for station 627 was created.
# Dataframe for station 641 was created.
# Dataframe for station 646 was created.
# Dataframe for station 558 was created.
# Dataframe for station 576 was created.
# Dataframe for station 632 was created.
# Dataframe for station 197 was created.
# Dataframe for station 489 was created.
# Dataframe for station 614 was created.
# Dataframe for station 565 was created.
# Dataframe for station 566 was created.
# Dataframe for station 625 was created.
# Dataframe for station 581 was created.
# Dataframe for station 616 was created.
# Dataframe for station 586 was created.
# Dataframe for station 587 was created.
# Dataframe for station 574 was created.
# Dataframe for station 535 was created.
# Dataframe for station 582 was created.
# Dataframe for station 683 was created.
# Dataframe for station 488 was created.
# Dataframe for station 606 was created.
# Dataframe for station 547 was created.
# Dataframe for station 526 was created.
# Dataframe for station 523 was created.
# Dataframe for station 522 was created.
# Dataframe for station 528 was created.
# Number of new dataframes: 644

# %%
# calling dataframe for pickup_station 6
stations_dict[6]
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 192        undefined        37  5125273               6  2023-01-01
# 270                M        42  7262884               6  2023-01-01
# 535                M        58  5202841               6  2023-01-01
# 621                M        36  4868600               6  2023-01-01
# 702                M        35  8541591               6  2023-01-01
# ...              ...       ...      ...             ...         ...
# 13734080           F        33  3026184               6  2024-01-31
# 13734102           M        41  5299292               6  2024-01-31
# 13734394           M        33  8081168               6  2024-01-31
# 13734547           M        32  4277828               6  2024-01-31
# 13734893           F        29  6510093               6  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 192         07:20:00               6  2023-01-01    07:26:00
# 270         08:27:00               6  2023-01-01    08:33:00
# 535         10:15:00               6  2023-01-01    10:51:00
# 621         10:38:00               6  2023-01-01    10:43:00
# 702         10:58:00               6  2023-01-01    11:06:00
# ...              ...             ...         ...         ...
# 13734080    22:30:00               6  2024-01-31    22:48:00
# 13734102    22:31:00               6  2024-01-31    23:15:00
# 13734394    22:43:00               6  2024-01-31    23:18:00
# 13734547    22:51:00               6  2024-01-31    23:00:00
# 13734893    23:09:00               6  2024-01-31    23:15:00
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 192      2023-01-01 07:20:00 2023-01-01 07:00:00 2023-01-01 07:26:00
# 270      2023-01-01 08:27:00 2023-01-01 08:00:00 2023-01-01 08:33:00
# 535      2023-01-01 10:15:00 2023-01-01 10:00:00 2023-01-01 10:51:00
# 621      2023-01-01 10:38:00 2023-01-01 10:00:00 2023-01-01 10:43:00
# 702      2023-01-01 10:58:00 2023-01-01 10:00:00 2023-01-01 11:06:00
# ...                      ...                 ...                 ...
# 13734080 2024-01-31 22:30:00 2024-01-31 22:00:00 2024-01-31 22:48:00
# 13734102 2024-01-31 22:31:00 2024-01-31 22:00:00 2024-01-31 23:15:00
# 13734394 2024-01-31 22:43:00 2024-01-31 22:00:00 2024-01-31 23:18:00
# 13734547 2024-01-31 22:51:00 2024-01-31 22:00:00 2024-01-31 23:00:00
# 13734893 2024-01-31 23:09:00 2024-01-31 23:00:00 2024-01-31 23:15:00
#
#                 duration  is_business_day
# 192      0 days 00:06:00                0
# 270      0 days 00:06:00                0
# 535      0 days 00:36:00                0
# 621      0 days 00:05:00                0
# 702      0 days 00:08:00                0
# ...                  ...              ...
# 13734080 0 days 00:18:00                1
# 13734102 0 days 00:44:00                1
# 13734394 0 days 00:35:00                1
# 13734547 0 days 00:09:00                1
# 13734893 0 days 00:06:00                1
#
# [49037 rows x 14 columns]

# %% [markdown]
# <b> Aggregating each station's df by hour</b>

# %%
# For each dataframe in stations_dict:
# Group by 'hourly_datetime' and aggregate the data using aggregating functions (mean, mode, etc.)
# set index to hour and reindex to get full index and insert empty rows for missing hours, fillna with 0
# saving each individual dataframe into a dictionary, where station number is key and df is value

full_index = pd.date_range(start='2023-01-01 00:00:00', end='2024-02-01 00:00:00', freq='H')
stations_hourly_dict = {}

for key,value in stations_dict.items():
    station_aggregated = value.groupby('hourly_aggregated',as_index=False).agg(
        {'bike_id': 'count',
         'duration': 'mean',
        }
    )
    # reformat df columns and duration values, reset index
    station_aggregated.rename(columns={'hourly_aggregated':'hour','bike_id':'rental_counts','duration':'avg_rental_duration'},inplace=True)
    station_aggregated.set_index('hour', drop=False, inplace=True)
    station_aggregated = station_aggregated.reindex(full_index)
    station_aggregated.hour = station_aggregated.index
    station_aggregated.fillna(0, inplace=True)
    
    # convert avg rental duration from timedelta to float, representing minutes
    station_aggregated['avg_rental_duration'] = station_aggregated['avg_rental_duration'].apply(
    lambda x: round(float(x.total_seconds() / 60) if isinstance(x, pd.Timedelta) else x, 2))
    
    # add is_business_day
    station_aggregated['is_business_day'] = pd.to_datetime(station_aggregated['hour']).apply(
        lambda x: 1 if 
        (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] \
        and x.weekday() < 5 else 0
    )
    station_aggregated.drop('hour', axis=1,inplace=True)
    
    stations_hourly_dict[key] = station_aggregated

    print(f"Aggregated dataframe for station {key} was created.")
    
print(f"Number of new dataframes: {len(stations_hourly_dict)}")
# Out:
# Aggregated dataframe for station 81 was created.
# Aggregated dataframe for station 56 was created.
# Aggregated dataframe for station 22 was created.
# Aggregated dataframe for station 287 was created.
# Aggregated dataframe for station 302 was created.
# Aggregated dataframe for station 19 was created.
# Aggregated dataframe for station 116 was created.
# Aggregated dataframe for station 131 was created.
# Aggregated dataframe for station 254 was created.
# Aggregated dataframe for station 111 was created.
# Aggregated dataframe for station 16 was created.
# Aggregated dataframe for station 157 was created.
# Aggregated dataframe for station 228 was created.
# Aggregated dataframe for station 330 was created.
# Aggregated dataframe for station 220 was created.
# Aggregated dataframe for station 249 was created.
# Aggregated dataframe for station 2 was created.
# Aggregated dataframe for station 79 was created.
# Aggregated dataframe for station 46 was created.
# Aggregated dataframe for station 320 was created.
# Aggregated dataframe for station 74 was created.
# Aggregated dataframe for station 65 was created.
# Aggregated dataframe for station 43 was created.
# Aggregated dataframe for station 25 was created.
# Aggregated dataframe for station 57 was created.
# Aggregated dataframe for station 214 was created.
# Aggregated dataframe for station 3 was created.
# Aggregated dataframe for station 212 was created.
# Aggregated dataframe for station 343 was created.
# Aggregated dataframe for station 132 was created.
# Aggregated dataframe for station 105 was created.
# Aggregated dataframe for station 99 was created.
# Aggregated dataframe for station 30 was created.
# Aggregated dataframe for station 260 was created.
# Aggregated dataframe for station 137 was created.
# Aggregated dataframe for station 150 was created.
# Aggregated dataframe for station 175 was created.
# Aggregated dataframe for station 285 was created.
# Aggregated dataframe for station 454 was created.
# Aggregated dataframe for station 35 was created.
# Aggregated dataframe for station 261 was created.
# Aggregated dataframe for station 89 was created.
# Aggregated dataframe for station 33 was created.
# Aggregated dataframe for station 31 was created.
# Aggregated dataframe for station 255 was created.
# Aggregated dataframe for station 76 was created.
# Aggregated dataframe for station 63 was created.
# Aggregated dataframe for station 281 was created.
# Aggregated dataframe for station 384 was created.
# Aggregated dataframe for station 124 was created.
# Aggregated dataframe for station 115 was created.
# Aggregated dataframe for station 10 was created.
# Aggregated dataframe for station 472 was created.
# Aggregated dataframe for station 461 was created.
# Aggregated dataframe for station 152 was created.
# Aggregated dataframe for station 345 was created.
# Aggregated dataframe for station 41 was created.
# Aggregated dataframe for station 181 was created.
# Aggregated dataframe for station 123 was created.
# Aggregated dataframe for station 439 was created.
# Aggregated dataframe for station 393 was created.
# Aggregated dataframe for station 133 was created.
# Aggregated dataframe for station 270 was created.
# Aggregated dataframe for station 114 was created.
# Aggregated dataframe for station 354 was created.
# Aggregated dataframe for station 327 was created.
# Aggregated dataframe for station 263 was created.
# Aggregated dataframe for station 128 was created.
# Aggregated dataframe for station 64 was created.
# Aggregated dataframe for station 119 was created.
# Aggregated dataframe for station 102 was created.
# Aggregated dataframe for station 284 was created.
# Aggregated dataframe for station 72 was created.
# Aggregated dataframe for station 466 was created.
# Aggregated dataframe for station 318 was created.
# Aggregated dataframe for station 322 was created.
# Aggregated dataframe for station 428 was created.
# Aggregated dataframe for station 147 was created.
# Aggregated dataframe for station 378 was created.
# Aggregated dataframe for station 476 was created.
# Aggregated dataframe for station 180 was created.
# Aggregated dataframe for station 555 was created.
# Aggregated dataframe for station 70 was created.
# Aggregated dataframe for station 427 was created.
# Aggregated dataframe for station 134 was created.
# Aggregated dataframe for station 93 was created.
# Aggregated dataframe for station 467 was created.
# Aggregated dataframe for station 415 was created.
# Aggregated dataframe for station 40 was created.
# Aggregated dataframe for station 372 was created.
# Aggregated dataframe for station 196 was created.
# Aggregated dataframe for station 161 was created.
# Aggregated dataframe for station 66 was created.
# Aggregated dataframe for station 312 was created.
# Aggregated dataframe for station 122 was created.
# Aggregated dataframe for station 83 was created.
# Aggregated dataframe for station 6 was created.
# Aggregated dataframe for station 7 was created.
# Aggregated dataframe for station 293 was created.
# Aggregated dataframe for station 12 was created.
# Aggregated dataframe for station 341 was created.
# Aggregated dataframe for station 165 was created.
# Aggregated dataframe for station 110 was created.
# Aggregated dataframe for station 397 was created.
# Aggregated dataframe for station 118 was created.
# Aggregated dataframe for station 280 was created.
# Aggregated dataframe for station 337 was created.
# Aggregated dataframe for station 204 was created.
# Aggregated dataframe for station 5 was created.
# Aggregated dataframe for station 381 was created.
# Aggregated dataframe for station 360 was created.
# Aggregated dataframe for station 112 was created.
# Aggregated dataframe for station 335 was created.
# Aggregated dataframe for station 59 was created.
# Aggregated dataframe for station 405 was created.
# Aggregated dataframe for station 195 was created.
# Aggregated dataframe for station 166 was created.
# Aggregated dataframe for station 44 was created.
# Aggregated dataframe for station 434 was created.
# Aggregated dataframe for station 174 was created.
# Aggregated dataframe for station 141 was created.
# Aggregated dataframe for station 278 was created.
# Aggregated dataframe for station 140 was created.
# Aggregated dataframe for station 243 was created.
# Aggregated dataframe for station 32 was created.
# Aggregated dataframe for station 407 was created.
# Aggregated dataframe for station 399 was created.
# Aggregated dataframe for station 213 was created.
# Aggregated dataframe for station 189 was created.
# Aggregated dataframe for station 29 was created.
# Aggregated dataframe for station 216 was created.
# Aggregated dataframe for station 42 was created.
# Aggregated dataframe for station 374 was created.
# Aggregated dataframe for station 67 was created.
# Aggregated dataframe for station 226 was created.
# Aggregated dataframe for station 241 was created.
# Aggregated dataframe for station 479 was created.
# Aggregated dataframe for station 37 was created.
# Aggregated dataframe for station 199 was created.
# Aggregated dataframe for station 358 was created.
# Aggregated dataframe for station 113 was created.
# Aggregated dataframe for station 53 was created.
# Aggregated dataframe for station 256 was created.
# Aggregated dataframe for station 421 was created.
# Aggregated dataframe for station 167 was created.
# Aggregated dataframe for station 447 was created.
# Aggregated dataframe for station 475 was created.
# Aggregated dataframe for station 36 was created.
# Aggregated dataframe for station 432 was created.
# Aggregated dataframe for station 282 was created.
# Aggregated dataframe for station 450 was created.
# Aggregated dataframe for station 58 was created.
# Aggregated dataframe for station 387 was created.
# Aggregated dataframe for station 308 was created.
# Aggregated dataframe for station 143 was created.
# Aggregated dataframe for station 126 was created.
# Aggregated dataframe for station 464 was created.
# Aggregated dataframe for station 259 was created.
# Aggregated dataframe for station 95 was created.
# Aggregated dataframe for station 200 was created.
# Aggregated dataframe for station 71 was created.
# Aggregated dataframe for station 306 was created.
# Aggregated dataframe for station 414 was created.
# Aggregated dataframe for station 367 was created.
# Aggregated dataframe for station 97 was created.
# Aggregated dataframe for station 156 was created.
# Aggregated dataframe for station 429 was created.
# Aggregated dataframe for station 307 was created.
# Aggregated dataframe for station 173 was created.
# Aggregated dataframe for station 109 was created.
# Aggregated dataframe for station 325 was created.
# Aggregated dataframe for station 127 was created.
# Aggregated dataframe for station 370 was created.
# Aggregated dataframe for station 424 was created.
# Aggregated dataframe for station 91 was created.
# Aggregated dataframe for station 229 was created.
# Aggregated dataframe for station 361 was created.
# Aggregated dataframe for station 222 was created.
# Aggregated dataframe for station 49 was created.
# Aggregated dataframe for station 218 was created.
# Aggregated dataframe for station 88 was created.
# Aggregated dataframe for station 82 was created.
# Aggregated dataframe for station 303 was created.
# Aggregated dataframe for station 100 was created.
# Aggregated dataframe for station 412 was created.
# Aggregated dataframe for station 144 was created.
# Aggregated dataframe for station 339 was created.
# Aggregated dataframe for station 298 was created.
# Aggregated dataframe for station 349 was created.
# Aggregated dataframe for station 60 was created.
# Aggregated dataframe for station 92 was created.
# Aggregated dataframe for station 120 was created.
# Aggregated dataframe for station 365 was created.
# Aggregated dataframe for station 348 was created.
# Aggregated dataframe for station 190 was created.
# Aggregated dataframe for station 148 was created.
# Aggregated dataframe for station 288 was created.
# Aggregated dataframe for station 283 was created.
# Aggregated dataframe for station 300 was created.
# Aggregated dataframe for station 207 was created.
# Aggregated dataframe for station 234 was created.
# Aggregated dataframe for station 375 was created.
# Aggregated dataframe for station 409 was created.
# Aggregated dataframe for station 125 was created.
# Aggregated dataframe for station 139 was created.
# Aggregated dataframe for station 262 was created.
# Aggregated dataframe for station 353 was created.
# Aggregated dataframe for station 332 was created.
# Aggregated dataframe for station 188 was created.
# Aggregated dataframe for station 417 was created.
# Aggregated dataframe for station 469 was created.
# Aggregated dataframe for station 419 was created.
# Aggregated dataframe for station 246 was created.
# Aggregated dataframe for station 179 was created.
# Aggregated dataframe for station 437 was created.
# Aggregated dataframe for station 315 was created.
# Aggregated dataframe for station 185 was created.
# Aggregated dataframe for station 377 was created.
# Aggregated dataframe for station 413 was created.
# Aggregated dataframe for station 55 was created.
# Aggregated dataframe for station 362 was created.
# Aggregated dataframe for station 394 was created.
# Aggregated dataframe for station 456 was created.
# Aggregated dataframe for station 177 was created.
# Aggregated dataframe for station 48 was created.
# Aggregated dataframe for station 247 was created.
# Aggregated dataframe for station 231 was created.
# Aggregated dataframe for station 333 was created.
# Aggregated dataframe for station 423 was created.
# Aggregated dataframe for station 460 was created.
# Aggregated dataframe for station 468 was created.
# Aggregated dataframe for station 443 was created.
# Aggregated dataframe for station 459 was created.
# Aggregated dataframe for station 457 was created.
# Aggregated dataframe for station 324 was created.
# Aggregated dataframe for station 438 was created.
# Aggregated dataframe for station 104 was created.
# Aggregated dataframe for station 294 was created.
# Aggregated dataframe for station 80 was created.
# Aggregated dataframe for station 94 was created.
# Aggregated dataframe for station 135 was created.
# Aggregated dataframe for station 136 was created.
# Aggregated dataframe for station 75 was created.
# Aggregated dataframe for station 15 was created.
# Aggregated dataframe for station 17 was created.
# Aggregated dataframe for station 14 was created.
# Aggregated dataframe for station 20 was created.
# Aggregated dataframe for station 27 was created.
# Aggregated dataframe for station 121 was created.
# Aggregated dataframe for station 252 was created.
# Aggregated dataframe for station 251 was created.
# Aggregated dataframe for station 117 was created.
# Aggregated dataframe for station 217 was created.
# Aggregated dataframe for station 224 was created.
# Aggregated dataframe for station 250 was created.
# Aggregated dataframe for station 215 was created.
# Aggregated dataframe for station 202 was created.
# Aggregated dataframe for station 258 was created.
# Aggregated dataframe for station 240 was created.
# Aggregated dataframe for station 47 was created.
# Aggregated dataframe for station 11 was created.
# Aggregated dataframe for station 18 was created.
# Aggregated dataframe for station 38 was created.
# Aggregated dataframe for station 13 was created.
# Aggregated dataframe for station 449 was created.
# Aggregated dataframe for station 265 was created.
# Aggregated dataframe for station 23 was created.
# Aggregated dataframe for station 34 was created.
# Aggregated dataframe for station 28 was created.
# Aggregated dataframe for station 103 was created.
# Aggregated dataframe for station 470 was created.
# Aggregated dataframe for station 183 was created.
# Aggregated dataframe for station 85 was created.
# Aggregated dataframe for station 227 was created.
# Aggregated dataframe for station 232 was created.
# Aggregated dataframe for station 211 was created.
# Aggregated dataframe for station 1 was created.
# Aggregated dataframe for station 480 was created.
# Aggregated dataframe for station 474 was created.
# Aggregated dataframe for station 176 was created.
# Aggregated dataframe for station 478 was created.
# Aggregated dataframe for station 257 was created.
# Aggregated dataframe for station 248 was created.
# Aggregated dataframe for station 219 was created.
# Aggregated dataframe for station 465 was created.
# Aggregated dataframe for station 455 was created.
# Aggregated dataframe for station 221 was created.
# Aggregated dataframe for station 86 was created.
# Aggregated dataframe for station 201 was created.
# Aggregated dataframe for station 223 was created.
# Aggregated dataframe for station 1000 was created.
# Aggregated dataframe for station 208 was created.
# Aggregated dataframe for station 210 was created.
# Aggregated dataframe for station 233 was created.
# Aggregated dataframe for station 87 was created.
# Aggregated dataframe for station 8 was created.
# Aggregated dataframe for station 206 was created.
# Aggregated dataframe for station 242 was created.
# Aggregated dataframe for station 451 was created.
# Aggregated dataframe for station 21 was created.
# Aggregated dataframe for station 244 was created.
# Aggregated dataframe for station 142 was created.
# Aggregated dataframe for station 225 was created.
# Aggregated dataframe for station 553 was created.
# Aggregated dataframe for station 145 was created.
# Aggregated dataframe for station 51 was created.
# Aggregated dataframe for station 186 was created.
# Aggregated dataframe for station 253 was created.
# Aggregated dataframe for station 452 was created.
# Aggregated dataframe for station 61 was created.
# Aggregated dataframe for station 62 was created.
# Aggregated dataframe for station 50 was created.
# Aggregated dataframe for station 448 was created.
# Aggregated dataframe for station 668 was created.
# Aggregated dataframe for station 554 was created.
# Aggregated dataframe for station 129 was created.
# Aggregated dataframe for station 552 was created.
# Aggregated dataframe for station 130 was created.
# Aggregated dataframe for station 68 was created.
# Aggregated dataframe for station 151 was created.
# Aggregated dataframe for station 550 was created.
# Aggregated dataframe for station 155 was created.
# Aggregated dataframe for station 551 was created.
# Aggregated dataframe for station 162 was created.
# Aggregated dataframe for station 656 was created.
# Aggregated dataframe for station 170 was created.
# Aggregated dataframe for station 549 was created.
# Aggregated dataframe for station 24 was created.
# Aggregated dataframe for station 9 was created.
# Aggregated dataframe for station 191 was created.
# Aggregated dataframe for station 52 was created.
# Aggregated dataframe for station 45 was created.
# Aggregated dataframe for station 657 was created.
# Aggregated dataframe for station 670 was created.
# Aggregated dataframe for station 194 was created.
# Aggregated dataframe for station 286 was created.
# Aggregated dataframe for station 26 was created.
# Aggregated dataframe for station 160 was created.
# Aggregated dataframe for station 660 was created.
# Aggregated dataframe for station 667 was created.
# Aggregated dataframe for station 658 was created.
# Aggregated dataframe for station 659 was created.
# Aggregated dataframe for station 163 was created.
# Aggregated dataframe for station 84 was created.
# Aggregated dataframe for station 184 was created.
# Aggregated dataframe for station 77 was created.
# Aggregated dataframe for station 78 was created.
# Aggregated dataframe for station 73 was created.
# Aggregated dataframe for station 54 was created.
# Aggregated dataframe for station 96 was created.
# Aggregated dataframe for station 239 was created.
# Aggregated dataframe for station 305 was created.
# Aggregated dataframe for station 169 was created.
# Aggregated dataframe for station 168 was created.
# Aggregated dataframe for station 153 was created.
# Aggregated dataframe for station 171 was created.
# Aggregated dataframe for station 154 was created.
# Aggregated dataframe for station 309 was created.
# Aggregated dataframe for station 430 was created.
# Aggregated dataframe for station 182 was created.
# Aggregated dataframe for station 291 was created.
# Aggregated dataframe for station 314 was created.
# Aggregated dataframe for station 279 was created.
# Aggregated dataframe for station 187 was created.
# Aggregated dataframe for station 331 was created.
# Aggregated dataframe for station 310 was created.
# Aggregated dataframe for station 297 was created.
# Aggregated dataframe for station 323 was created.
# Aggregated dataframe for station 296 was created.
# Aggregated dataframe for station 295 was created.
# Aggregated dataframe for station 319 was created.
# Aggregated dataframe for station 351 was created.
# Aggregated dataframe for station 329 was created.
# Aggregated dataframe for station 164 was created.
# Aggregated dataframe for station 340 was created.
# Aggregated dataframe for station 336 was created.
# Aggregated dataframe for station 669 was created.
# Aggregated dataframe for station 352 was created.
# Aggregated dataframe for station 209 was created.
# Aggregated dataframe for station 355 was created.
# Aggregated dataframe for station 304 was created.
# Aggregated dataframe for station 346 was created.
# Aggregated dataframe for station 299 was created.
# Aggregated dataframe for station 276 was created.
# Aggregated dataframe for station 380 was created.
# Aggregated dataframe for station 334 was created.
# Aggregated dataframe for station 385 was created.
# Aggregated dataframe for station 316 was created.
# Aggregated dataframe for station 317 was created.
# Aggregated dataframe for station 90 was created.
# Aggregated dataframe for station 290 was created.
# Aggregated dataframe for station 363 was created.
# Aggregated dataframe for station 366 was created.
# Aggregated dataframe for station 369 was created.
# Aggregated dataframe for station 347 was created.
# Aggregated dataframe for station 292 was created.
# Aggregated dataframe for station 328 was created.
# Aggregated dataframe for station 373 was created.
# Aggregated dataframe for station 342 was created.
# Aggregated dataframe for station 205 was created.
# Aggregated dataframe for station 422 was created.
# Aggregated dataframe for station 338 was created.
# Aggregated dataframe for station 389 was created.
# Aggregated dataframe for station 395 was created.
# Aggregated dataframe for station 371 was created.
# Aggregated dataframe for station 416 was created.
# Aggregated dataframe for station 386 was created.
# Aggregated dataframe for station 401 was created.
# Aggregated dataframe for station 420 was created.
# Aggregated dataframe for station 436 was created.
# Aggregated dataframe for station 396 was created.
# Aggregated dataframe for station 359 was created.
# Aggregated dataframe for station 402 was created.
# Aggregated dataframe for station 433 was created.
# Aggregated dataframe for station 442 was created.
# Aggregated dataframe for station 356 was created.
# Aggregated dataframe for station 404 was created.
# Aggregated dataframe for station 398 was created.
# Aggregated dataframe for station 326 was created.
# Aggregated dataframe for station 230 was created.
# Aggregated dataframe for station 138 was created.
# Aggregated dataframe for station 203 was created.
# Aggregated dataframe for station 178 was created.
# Aggregated dataframe for station 172 was created.
# Aggregated dataframe for station 39 was created.
# Aggregated dataframe for station 483 was created.
# Aggregated dataframe for station 198 was created.
# Aggregated dataframe for station 321 was created.
# Aggregated dataframe for station 313 was created.
# Aggregated dataframe for station 485 was created.
# Aggregated dataframe for station 277 was created.
# Aggregated dataframe for station 444 was created.
# Aggregated dataframe for station 471 was created.
# Aggregated dataframe for station 301 was created.
# Aggregated dataframe for station 462 was created.
# Aggregated dataframe for station 441 was created.
# Aggregated dataframe for station 477 was created.
# Aggregated dataframe for station 392 was created.
# Aggregated dataframe for station 546 was created.
# Aggregated dataframe for station 453 was created.
# Aggregated dataframe for station 4 was created.
# Aggregated dataframe for station 357 was created.
# Aggregated dataframe for station 473 was created.
# Aggregated dataframe for station 149 was created.
# Aggregated dataframe for station 146 was created.
# Aggregated dataframe for station 69 was created.
# Aggregated dataframe for station 245 was created.
# Aggregated dataframe for station 537 was created.
# Aggregated dataframe for station 481 was created.
# Aggregated dataframe for station 425 was created.
# Aggregated dataframe for station 492 was created.
# Aggregated dataframe for station 496 was created.
# Aggregated dataframe for station 495 was created.
# Aggregated dataframe for station 504 was created.
# Aggregated dataframe for station 498 was created.
# Aggregated dataframe for station 502 was created.
# Aggregated dataframe for station 536 was created.
# Aggregated dataframe for station 497 was created.
# Aggregated dataframe for station 507 was created.
# Aggregated dataframe for station 506 was created.
# Aggregated dataframe for station 503 was created.
# Aggregated dataframe for station 499 was created.
# Aggregated dataframe for station 541 was created.
# Aggregated dataframe for station 482 was created.
# Aggregated dataframe for station 458 was created.
# Aggregated dataframe for station 486 was created.
# Aggregated dataframe for station 98 was created.
# Aggregated dataframe for station 543 was created.
# Aggregated dataframe for station 672 was created.
# Aggregated dataframe for station 703 was created.
# Aggregated dataframe for station 540 was created.
# Aggregated dataframe for station 673 was created.
# Aggregated dataframe for station 700 was created.
# Aggregated dataframe for station 709 was created.
# Aggregated dataframe for station 706 was created.
# Aggregated dataframe for station 704 was created.
# Aggregated dataframe for station 491 was created.
# Aggregated dataframe for station 702 was created.
# Aggregated dataframe for station 545 was created.
# Aggregated dataframe for station 708 was created.
# Aggregated dataframe for station 626 was created.
# Aggregated dataframe for station 696 was created.
# Aggregated dataframe for station 615 was created.
# Aggregated dataframe for station 597 was created.
# Aggregated dataframe for station 694 was created.
# Aggregated dataframe for station 630 was created.
# Aggregated dataframe for station 617 was created.
# Aggregated dataframe for station 691 was created.
# Aggregated dataframe for station 689 was created.
# Aggregated dataframe for station 692 was created.
# Aggregated dataframe for station 701 was created.
# Aggregated dataframe for station 618 was created.
# Aggregated dataframe for station 612 was created.
# Aggregated dataframe for station 661 was created.
# Aggregated dataframe for station 652 was created.
# Aggregated dataframe for station 688 was created.
# Aggregated dataframe for station 629 was created.
# Aggregated dataframe for station 651 was created.
# Aggregated dataframe for station 649 was created.
# Aggregated dataframe for station 602 was created.
# Aggregated dataframe for station 624 was created.
# Aggregated dataframe for station 611 was created.
# Aggregated dataframe for station 637 was created.
# Aggregated dataframe for station 639 was created.
# Aggregated dataframe for station 633 was created.
# Aggregated dataframe for station 592 was created.
# Aggregated dataframe for station 619 was created.
# Aggregated dataframe for station 623 was created.
# Aggregated dataframe for station 620 was created.
# Aggregated dataframe for station 562 was created.
# Aggregated dataframe for station 559 was created.
# Aggregated dataframe for station 634 was created.
# Aggregated dataframe for station 589 was created.
# Aggregated dataframe for station 560 was created.
# Aggregated dataframe for station 579 was created.
# Aggregated dataframe for station 568 was created.
# Aggregated dataframe for station 564 was created.
# Aggregated dataframe for station 577 was created.
# Aggregated dataframe for station 609 was created.
# Aggregated dataframe for station 567 was created.
# Aggregated dataframe for station 604 was created.
# Aggregated dataframe for station 494 was created.
# Aggregated dataframe for station 573 was created.
# Aggregated dataframe for station 501 was created.
# Aggregated dataframe for station 571 was created.
# Aggregated dataframe for station 580 was created.
# Aggregated dataframe for station 569 was created.
# Aggregated dataframe for station 643 was created.
# Aggregated dataframe for station 603 was created.
# Aggregated dataframe for station 578 was created.
# Aggregated dataframe for station 645 was created.
# Aggregated dataframe for station 563 was created.
# Aggregated dataframe for station 697 was created.
# Aggregated dataframe for station 575 was created.
# Aggregated dataframe for station 590 was created.
# Aggregated dataframe for station 556 was created.
# Aggregated dataframe for station 584 was created.
# Aggregated dataframe for station 463 was created.
# Aggregated dataframe for station 650 was created.
# Aggregated dataframe for station 679 was created.
# Aggregated dataframe for station 678 was created.
# Aggregated dataframe for station 664 was created.
# Aggregated dataframe for station 666 was created.
# Aggregated dataframe for station 663 was created.
# Aggregated dataframe for station 662 was created.
# Aggregated dataframe for station 686 was created.
# Aggregated dataframe for station 525 was created.
# Aggregated dataframe for station 527 was created.
# Aggregated dataframe for station 521 was created.
# Aggregated dataframe for station 519 was created.
# Aggregated dataframe for station 518 was created.
# Aggregated dataframe for station 517 was created.
# Aggregated dataframe for station 516 was created.
# Aggregated dataframe for station 531 was created.
# Aggregated dataframe for station 514 was created.
# Aggregated dataframe for station 655 was created.
# Aggregated dataframe for station 684 was created.
# Aggregated dataframe for station 665 was created.
# Aggregated dataframe for station 635 was created.
# Aggregated dataframe for station 613 was created.
# Aggregated dataframe for station 631 was created.
# Aggregated dataframe for station 594 was created.
# Aggregated dataframe for station 628 was created.
# Aggregated dataframe for station 557 was created.
# Aggregated dataframe for station 687 was created.
# Aggregated dataframe for station 510 was created.
# Aggregated dataframe for station 512 was created.
# Aggregated dataframe for station 548 was created.
# Aggregated dataframe for station 608 was created.
# Aggregated dataframe for station 539 was created.
# Aggregated dataframe for station 622 was created.
# Aggregated dataframe for station 642 was created.
# Aggregated dataframe for station 4422222 was created.
# Aggregated dataframe for station 595 was created.
# Aggregated dataframe for station 585 was created.
# Aggregated dataframe for station 561 was created.
# Aggregated dataframe for station 636 was created.
# Aggregated dataframe for station 596 was created.
# Aggregated dataframe for station 621 was created.
# Aggregated dataframe for station 598 was created.
# Aggregated dataframe for station 698 was created.
# Aggregated dataframe for station 607 was created.
# Aggregated dataframe for station 685 was created.
# Aggregated dataframe for station 699 was created.
# Aggregated dataframe for station 671 was created.
# Aggregated dataframe for station 542 was created.
# Aggregated dataframe for station 610 was created.
# Aggregated dataframe for station 493 was created.
# Aggregated dataframe for station 500 was created.
# Aggregated dataframe for station 583 was created.
# Aggregated dataframe for station 599 was created.
# Aggregated dataframe for station 644 was created.
# Aggregated dataframe for station 572 was created.
# Aggregated dataframe for station 591 was created.
# Aggregated dataframe for station 601 was created.
# Aggregated dataframe for station 695 was created.
# Aggregated dataframe for station 640 was created.
# Aggregated dataframe for station 484 was created.
# Aggregated dataframe for station 593 was created.
# Aggregated dataframe for station 544 was created.
# Aggregated dataframe for station 490 was created.
# Aggregated dataframe for station 106 was created.
# Aggregated dataframe for station 707 was created.
# Aggregated dataframe for station 693 was created.
# Aggregated dataframe for station 538 was created.
# Aggregated dataframe for station 487 was created.
# Aggregated dataframe for station 654 was created.
# Aggregated dataframe for station 648 was created.
# Aggregated dataframe for station 570 was created.
# Aggregated dataframe for station 674 was created.
# Aggregated dataframe for station 605 was created.
# Aggregated dataframe for station 653 was created.
# Aggregated dataframe for station 705 was created.
# Aggregated dataframe for station 600 was created.
# Aggregated dataframe for station 638 was created.
# Aggregated dataframe for station 505 was created.
# Aggregated dataframe for station 690 was created.
# Aggregated dataframe for station 627 was created.
# Aggregated dataframe for station 641 was created.
# Aggregated dataframe for station 646 was created.
# Aggregated dataframe for station 558 was created.
# Aggregated dataframe for station 576 was created.
# Aggregated dataframe for station 632 was created.
# Aggregated dataframe for station 197 was created.
# Aggregated dataframe for station 489 was created.
# Aggregated dataframe for station 614 was created.
# Aggregated dataframe for station 565 was created.
# Aggregated dataframe for station 566 was created.
# Aggregated dataframe for station 625 was created.
# Aggregated dataframe for station 581 was created.
# Aggregated dataframe for station 616 was created.
# Aggregated dataframe for station 586 was created.
# Aggregated dataframe for station 587 was created.
# Aggregated dataframe for station 574 was created.
# Aggregated dataframe for station 535 was created.
# Aggregated dataframe for station 582 was created.
# Aggregated dataframe for station 683 was created.
# Aggregated dataframe for station 488 was created.
# Aggregated dataframe for station 606 was created.
# Aggregated dataframe for station 547 was created.
# Aggregated dataframe for station 526 was created.
# Aggregated dataframe for station 523 was created.
# Aggregated dataframe for station 522 was created.
# Aggregated dataframe for station 528 was created.
# Number of new dataframes: 644

# %%
# calling aggregated dataframe for pickup_station 6
# check if is_business_day imputed correctly
stations_hourly_dict[6].tail(50)

## should we filter out pickups with high duration? i.e. > 1 day??
# Out:
#                      rental_counts  avg_rental_duration  is_business_day
# 2024-01-29 23:00:00            0.0                 0.00                1
# 2024-01-30 00:00:00            4.0                18.50                1
# 2024-01-30 01:00:00            0.0                 0.00                1
# 2024-01-30 02:00:00            0.0                 0.00                1
# 2024-01-30 03:00:00            0.0                 0.00                1
# 2024-01-30 04:00:00            0.0                 0.00                1
# 2024-01-30 05:00:00            2.0                 8.00                1
# 2024-01-30 06:00:00            8.0                12.25                1
# 2024-01-30 07:00:00           11.0                12.45                1
# 2024-01-30 08:00:00           13.0                12.23                1
# 2024-01-30 09:00:00            6.0                17.67                1
# 2024-01-30 10:00:00           15.0                16.40                1
# 2024-01-30 11:00:00            8.0                11.12                1
# 2024-01-30 12:00:00            4.0                18.75                1
# 2024-01-30 13:00:00            8.0                17.00                1
# 2024-01-30 14:00:00            7.0                14.71                1
# 2024-01-30 15:00:00           17.0                13.18                1
# 2024-01-30 16:00:00           16.0                12.94                1
# 2024-01-30 17:00:00           16.0                11.31                1
# 2024-01-30 18:00:00           18.0                16.22                1
# 2024-01-30 19:00:00            8.0                17.50                1
# 2024-01-30 20:00:00            5.0                13.00                1
# 2024-01-30 21:00:00            8.0                17.25                1
# 2024-01-30 22:00:00            4.0                11.50                1
# 2024-01-30 23:00:00            2.0                12.50                1
# 2024-01-31 00:00:00            3.0                19.00                1
# 2024-01-31 01:00:00            0.0                 0.00                1
# 2024-01-31 02:00:00            0.0                 0.00                1
# 2024-01-31 03:00:00            0.0                 0.00                1
# 2024-01-31 04:00:00            0.0                 0.00                1
# 2024-01-31 05:00:00            2.0                 7.50                1
# 2024-01-31 06:00:00            8.0                11.50                1
# 2024-01-31 07:00:00           10.0                11.10                1
# 2024-01-31 08:00:00           11.0                14.00                1
# 2024-01-31 09:00:00           12.0                13.08                1
# 2024-01-31 10:00:00            6.0                20.83                1
# 2024-01-31 11:00:00            5.0                13.40                1
# 2024-01-31 12:00:00            7.0                11.57                1
# 2024-01-31 13:00:00           13.0                18.85                1
# 2024-01-31 14:00:00           11.0                14.45                1
# 2024-01-31 15:00:00           18.0                13.17                1
# 2024-01-31 16:00:00           12.0                13.25                1
# 2024-01-31 17:00:00           19.0                14.11                1
# 2024-01-31 18:00:00           19.0                17.79                1
# 2024-01-31 19:00:00           12.0                19.33                1
# 2024-01-31 20:00:00            7.0                17.29                1
# 2024-01-31 21:00:00            7.0                12.57                1
# 2024-01-31 22:00:00            9.0                15.56                1
# 2024-01-31 23:00:00            1.0                 6.00                1
# 2024-02-01 00:00:00            0.0                 0.00                1

# %% [markdown]
# ### incorporating/merging weather data

# %%
# mexico_city_weather = pd.read_csv("DATA/open-meteo-hourly-mexico-city_2020-12-02_2024-01-31.csv", skiprows=3)
# mexico_city_weather.drop(['snowfall (cm)','weather_code (wmo code)'], axis=1, inplace=True) # no snow in mexico city

# %%
# weather_columns = {
#     'time': 'hour', 
#     'temperature_2m_(°c)': 'temperature_C', 
#     'relative_humidity_2m_(%)': 'rel_humidity_perc',
#     'apparent_temperature_(°c)': 'feels_like_temp_C', 
#     'rain_(mm)': 'rain_mm',
#     'cloud_cover_(%)': 'cloud_cover_perc', 
#     'wind_speed_10m_(km/h)': 'wind_speed_kmh',
#     'is_day_()':'is_day'
# }
# mexico_city_weather.columns = [name.strip().replace(" ", "_").lower() for name in mexico_city_weather.columns]
# mexico_city_weather.rename(columns=weather_columns, inplace=True)

# %%
# reformat the hour column to match our aggregated ecobici df and set as index
# mexico_city_weather['hour'] = pd.to_datetime(mexico_city_weather['hour'], format='%Y-%m-%dT%H:%M')
# mexico_city_weather.set_index('hour', inplace=True)

# %%
# data_frame_overview(mexico_city_weather)
# Out:
# Column names:
#  Index(['temperature_C', 'rel_humidity_perc', 'feels_like_temp_C', 'rain_mm',
#        'cloud_cover_perc', 'wind_speed_kmh', 'is_day'],
#       dtype='object')
#
# Dimensions: (27744, 7)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 27744 entries, 2020-12-02 00:00:00 to 2024-01-31 23:00:00
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   temperature_C      27744 non-null  float64
#  1   rel_humidity_perc  27744 non-null  int64
#  2   feels_like_temp_C  27744 non-null  float64
#  3   rain_mm            27744 non-null  float64
#  4   cloud_cover_perc   27744 non-null  int64
#  5   wind_speed_kmh     27744 non-null  float64
#  6   is_day             27744 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 1.7 MB
# None
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# hour
# 2020-12-02 00:00:00           18.8                 43               17.0
# 2020-12-02 01:00:00           17.1                 59               16.3
# 2020-12-02 02:00:00           15.8                 60               13.9
# 2020-12-02 03:00:00           14.3                 67               12.4
# 2020-12-02 04:00:00           12.7                 76               11.5
# 2020-12-02 05:00:00           11.6                 80               10.5
# 2020-12-02 06:00:00           10.6                 83                9.4
# 2020-12-02 07:00:00            9.9                 83                8.5
# 2020-12-02 08:00:00            9.6                 79                8.1
# 2020-12-02 09:00:00            8.7                 81                7.0
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# hour
# 2020-12-02 00:00:00      0.0                38             5.5       0
# 2020-12-02 01:00:00      0.0                22             3.5       0
# 2020-12-02 02:00:00      0.0                16             9.5       0
# 2020-12-02 03:00:00      0.0                12             9.7       0
# 2020-12-02 04:00:00      0.0                 9             5.7       0
# 2020-12-02 05:00:00      0.0                18             5.1       0
# 2020-12-02 06:00:00      0.0                23             4.4       0
# 2020-12-02 07:00:00      0.0                25             4.3       0
# 2020-12-02 08:00:00      0.0                25             3.6       0
# 2020-12-02 09:00:00      0.0                28             4.3       0

# %%
clean_eco_bici_df
# Out:
#          user_gender  user_age  bike_id  pickup_station pickup_date  \
# 0                  M        35  8908451              81  2022-09-03
# 1          undefined        29  5380423              56  2022-09-30
# 2          undefined        32  5218094              56  2022-09-30
# 3          undefined        25  7278658              56  2022-09-30
# 4                  M        48  4031258              22  2022-11-10
# ...              ...       ...      ...             ...         ...
# 13735448           M        26  4085452             111  2024-01-31
# 13735449           M        21  8516015             548  2024-01-31
# 13735450           M        35  2760585             115  2024-01-31
# 13735451           F        31  2132561             115  2024-01-31
# 13735452           M        28  2005171             150  2024-01-31
#
#          pickup_time  return_station return_date return_time  \
# 0           18:45:00              81  2023-02-02    19:09:00
# 1           12:24:00              56  2023-11-24    15:13:00
# 2           13:17:00              56  2023-02-09    13:14:00
# 3           13:20:00              56  2023-02-09    13:11:00
# 4           21:26:00              22  2023-02-02    19:11:00
# ...              ...             ...         ...         ...
# 13735448    23:53:00             111  2024-01-31    23:57:00
# 13735449    23:55:00             548  2024-01-31    23:59:00
# 13735450    23:56:00             115  2024-01-31    23:58:00
# 13735451    23:56:00             115  2024-01-31    23:58:00
# 13735452    23:56:00             150  2024-01-31    23:59:00
#
#              pickup_datetime   hourly_aggregated     return_datetime  \
# 0        2022-09-03 18:45:00 2022-09-03 18:00:00 2023-02-02 19:09:00
# 1        2022-09-30 12:24:00 2022-09-30 12:00:00 2023-11-24 15:13:00
# 2        2022-09-30 13:17:00 2022-09-30 13:00:00 2023-02-09 13:14:00
# 3        2022-09-30 13:20:00 2022-09-30 13:00:00 2023-02-09 13:11:00
# 4        2022-11-10 21:26:00 2022-11-10 21:00:00 2023-02-02 19:11:00
# ...                      ...                 ...                 ...
# 13735448 2024-01-31 23:53:00 2024-01-31 23:00:00 2024-01-31 23:57:00
# 13735449 2024-01-31 23:55:00 2024-01-31 23:00:00 2024-01-31 23:59:00
# 13735450 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:58:00
# 13735451 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:58:00
# 13735452 2024-01-31 23:56:00 2024-01-31 23:00:00 2024-01-31 23:59:00
#
#                   duration  is_business_day
# 0        152 days 00:24:00                0
# 1        420 days 02:49:00                1
# 2        131 days 23:57:00                1
# 3        131 days 23:51:00                1
# 4         83 days 21:45:00                1
# ...                    ...              ...
# 13735448   0 days 00:04:00                1
# 13735449   0 days 00:04:00                1
# 13735450   0 days 00:02:00                1
# 13735451   0 days 00:02:00                1
# 13735452   0 days 00:03:00                1
#
# [13047307 rows x 14 columns]

# %%
# aggregate clean_eco_bici_df for general exploratory data analysis
eco_bici_hourly_count = clean_eco_bici_df.groupby('hourly_aggregated',as_index=False).agg(
        {'bike_id': 'count',
         'duration': 'mean'
        }
    )

# reformat df columns and duration values
eco_bici_hourly_count.rename(columns={'hourly_aggregated':'hour','bike_id':'rental_counts','duration':'avg_rental_duration'},inplace=True)
eco_bici_hourly_count.avg_rental_duration = eco_bici_hourly_count.avg_rental_duration.apply(
    lambda x: round(float(x.total_seconds() / 60) if isinstance(x, pd.Timedelta) else x, 2))

# reindex
eco_bici_hourly_count.set_index('hour', drop=False, inplace=True)
eco_bici_hourly_count = eco_bici_hourly_count.reindex(full_index)
eco_bici_hourly_count.fillna(0, inplace=True)

# add is_business_day column
eco_bici_hourly_count['is_business_day'] = pd.to_datetime(eco_bici_hourly_count['hour']).apply(
    lambda x: 1 if (x.month, x.day) not in [(holiday.month, holiday.day) for holiday in public_holidays_dt] and (x.weekday() < 5) else 0
)
eco_bici_hourly_count.drop('hour', axis=1, inplace=True)

data_frame_overview(eco_bici_hourly_count)
# Out:
# Column names:
#  Index(['rental_counts', 'avg_rental_duration', 'is_business_day'], dtype='object')
#
# Dimensions: (9505, 3)
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9505 entries, 2023-01-01 00:00:00 to 2024-02-01 00:00:00
# Freq: H
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rental_counts        9505 non-null   float64
#  1   avg_rental_duration  9505 non-null   float64
#  2   is_business_day      9505 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 297.0 KB
# None
#                      rental_counts  avg_rental_duration  is_business_day
# 2023-01-01 00:00:00           59.0                17.68                0
# 2023-01-01 01:00:00            0.0                 0.00                0
# 2023-01-01 02:00:00            0.0                 0.00                0
# 2023-01-01 03:00:00            0.0                 0.00                0
# 2023-01-01 04:00:00            0.0                 0.00                0
# 2023-01-01 05:00:00           26.0                14.46                0
# 2023-01-01 06:00:00           43.0                22.37                0
# 2023-01-01 07:00:00           63.0                14.83                0
# 2023-01-01 08:00:00           78.0                25.79                0
# 2023-01-01 09:00:00          160.0                22.69                0

# %%
# concatenate weather df with eco_bici_hourly_count dataframe for general exploratory data analysis

# hourly_weather_rentals = eco_bici_hourly_count.merge(mexico_city_weather, left_index=True, right_index=True, how='inner')
# hourly_weather_rentals.to_csv('hourly_weather_rentals.csv')

# %%
# for each station df in stations_hourly_dict, with key = station number
# merge weather df with aggregated station dataframes
# save the merged dfs into a stations_weather_rentals dictionary

# full_index = pd.date_range(start='2019-07-01 00:00:00', end='2021-03-01 00:00:00', freq='H')
# stations_weather_rentals = {}

# for key, value in stations_hourly_dict.items():
#     merged_df = value.merge(mexico_city_weather, left_index=True, right_index=True, how='inner')
#     stations_weather_rentals[key] = merged_df    
#     print(f"Merged rental count and weather dataframe for station {key} was created.")
    
# print(f"Number of new dataframes: {len(stations_weather_rentals)}")
# Out:
# Merged rental count and weather dataframe for station 81 was created.
# Merged rental count and weather dataframe for station 56 was created.
# Merged rental count and weather dataframe for station 22 was created.
# Merged rental count and weather dataframe for station 287 was created.
# Merged rental count and weather dataframe for station 302 was created.
# Merged rental count and weather dataframe for station 19 was created.
# Merged rental count and weather dataframe for station 116 was created.
# Merged rental count and weather dataframe for station 131 was created.
# Merged rental count and weather dataframe for station 254 was created.
# Merged rental count and weather dataframe for station 111 was created.
# Merged rental count and weather dataframe for station 16 was created.
# Merged rental count and weather dataframe for station 157 was created.
# Merged rental count and weather dataframe for station 228 was created.
# Merged rental count and weather dataframe for station 330 was created.
# Merged rental count and weather dataframe for station 220 was created.
# Merged rental count and weather dataframe for station 249 was created.
# Merged rental count and weather dataframe for station 2 was created.
# Merged rental count and weather dataframe for station 79 was created.
# Merged rental count and weather dataframe for station 46 was created.
# Merged rental count and weather dataframe for station 320 was created.
# Merged rental count and weather dataframe for station 74 was created.
# Merged rental count and weather dataframe for station 65 was created.
# Merged rental count and weather dataframe for station 43 was created.
# Merged rental count and weather dataframe for station 25 was created.
# Merged rental count and weather dataframe for station 57 was created.
# Merged rental count and weather dataframe for station 214 was created.
# Merged rental count and weather dataframe for station 3 was created.
# Merged rental count and weather dataframe for station 212 was created.
# Merged rental count and weather dataframe for station 343 was created.
# Merged rental count and weather dataframe for station 132 was created.
# Merged rental count and weather dataframe for station 105 was created.
# Merged rental count and weather dataframe for station 99 was created.
# Merged rental count and weather dataframe for station 30 was created.
# Merged rental count and weather dataframe for station 260 was created.
# Merged rental count and weather dataframe for station 137 was created.
# Merged rental count and weather dataframe for station 150 was created.
# Merged rental count and weather dataframe for station 175 was created.
# Merged rental count and weather dataframe for station 285 was created.
# Merged rental count and weather dataframe for station 454 was created.
# Merged rental count and weather dataframe for station 35 was created.
# Merged rental count and weather dataframe for station 261 was created.
# Merged rental count and weather dataframe for station 89 was created.
# Merged rental count and weather dataframe for station 33 was created.
# Merged rental count and weather dataframe for station 31 was created.
# Merged rental count and weather dataframe for station 255 was created.
# Merged rental count and weather dataframe for station 76 was created.
# Merged rental count and weather dataframe for station 63 was created.
# Merged rental count and weather dataframe for station 281 was created.
# Merged rental count and weather dataframe for station 384 was created.
# Merged rental count and weather dataframe for station 124 was created.
# Merged rental count and weather dataframe for station 115 was created.
# Merged rental count and weather dataframe for station 10 was created.
# Merged rental count and weather dataframe for station 472 was created.
# Merged rental count and weather dataframe for station 461 was created.
# Merged rental count and weather dataframe for station 152 was created.
# Merged rental count and weather dataframe for station 345 was created.
# Merged rental count and weather dataframe for station 41 was created.
# Merged rental count and weather dataframe for station 181 was created.
# Merged rental count and weather dataframe for station 123 was created.
# Merged rental count and weather dataframe for station 439 was created.
# Merged rental count and weather dataframe for station 393 was created.
# Merged rental count and weather dataframe for station 133 was created.
# Merged rental count and weather dataframe for station 270 was created.
# Merged rental count and weather dataframe for station 114 was created.
# Merged rental count and weather dataframe for station 354 was created.
# Merged rental count and weather dataframe for station 327 was created.
# Merged rental count and weather dataframe for station 263 was created.
# Merged rental count and weather dataframe for station 128 was created.
# Merged rental count and weather dataframe for station 64 was created.
# Merged rental count and weather dataframe for station 119 was created.
# Merged rental count and weather dataframe for station 102 was created.
# Merged rental count and weather dataframe for station 284 was created.
# Merged rental count and weather dataframe for station 72 was created.
# Merged rental count and weather dataframe for station 466 was created.
# Merged rental count and weather dataframe for station 318 was created.
# Merged rental count and weather dataframe for station 322 was created.
# Merged rental count and weather dataframe for station 428 was created.
# Merged rental count and weather dataframe for station 147 was created.
# Merged rental count and weather dataframe for station 378 was created.
# Merged rental count and weather dataframe for station 476 was created.
# Merged rental count and weather dataframe for station 180 was created.
# Merged rental count and weather dataframe for station 555 was created.
# Merged rental count and weather dataframe for station 70 was created.
# Merged rental count and weather dataframe for station 427 was created.
# Merged rental count and weather dataframe for station 134 was created.
# Merged rental count and weather dataframe for station 93 was created.
# Merged rental count and weather dataframe for station 467 was created.
# Merged rental count and weather dataframe for station 415 was created.
# Merged rental count and weather dataframe for station 40 was created.
# Merged rental count and weather dataframe for station 372 was created.
# Merged rental count and weather dataframe for station 196 was created.
# Merged rental count and weather dataframe for station 161 was created.
# Merged rental count and weather dataframe for station 66 was created.
# Merged rental count and weather dataframe for station 312 was created.
# Merged rental count and weather dataframe for station 122 was created.
# Merged rental count and weather dataframe for station 83 was created.
# Merged rental count and weather dataframe for station 6 was created.
# Merged rental count and weather dataframe for station 7 was created.
# Merged rental count and weather dataframe for station 293 was created.
# Merged rental count and weather dataframe for station 12 was created.
# Merged rental count and weather dataframe for station 341 was created.
# Merged rental count and weather dataframe for station 165 was created.
# Merged rental count and weather dataframe for station 110 was created.
# Merged rental count and weather dataframe for station 397 was created.
# Merged rental count and weather dataframe for station 118 was created.
# Merged rental count and weather dataframe for station 280 was created.
# Merged rental count and weather dataframe for station 337 was created.
# Merged rental count and weather dataframe for station 204 was created.
# Merged rental count and weather dataframe for station 5 was created.
# Merged rental count and weather dataframe for station 381 was created.
# Merged rental count and weather dataframe for station 360 was created.
# Merged rental count and weather dataframe for station 112 was created.
# Merged rental count and weather dataframe for station 335 was created.
# Merged rental count and weather dataframe for station 59 was created.
# Merged rental count and weather dataframe for station 405 was created.
# Merged rental count and weather dataframe for station 195 was created.
# Merged rental count and weather dataframe for station 166 was created.
# Merged rental count and weather dataframe for station 44 was created.
# Merged rental count and weather dataframe for station 434 was created.
# Merged rental count and weather dataframe for station 174 was created.
# Merged rental count and weather dataframe for station 141 was created.
# Merged rental count and weather dataframe for station 278 was created.
# Merged rental count and weather dataframe for station 140 was created.
# Merged rental count and weather dataframe for station 243 was created.
# Merged rental count and weather dataframe for station 32 was created.
# Merged rental count and weather dataframe for station 407 was created.
# Merged rental count and weather dataframe for station 399 was created.
# Merged rental count and weather dataframe for station 213 was created.
# Merged rental count and weather dataframe for station 189 was created.
# Merged rental count and weather dataframe for station 29 was created.
# Merged rental count and weather dataframe for station 216 was created.
# Merged rental count and weather dataframe for station 42 was created.
# Merged rental count and weather dataframe for station 374 was created.
# Merged rental count and weather dataframe for station 67 was created.
# Merged rental count and weather dataframe for station 226 was created.
# Merged rental count and weather dataframe for station 241 was created.
# Merged rental count and weather dataframe for station 479 was created.
# Merged rental count and weather dataframe for station 37 was created.
# Merged rental count and weather dataframe for station 199 was created.
# Merged rental count and weather dataframe for station 358 was created.
# Merged rental count and weather dataframe for station 113 was created.
# Merged rental count and weather dataframe for station 53 was created.
# Merged rental count and weather dataframe for station 256 was created.
# Merged rental count and weather dataframe for station 421 was created.
# Merged rental count and weather dataframe for station 167 was created.
# Merged rental count and weather dataframe for station 447 was created.
# Merged rental count and weather dataframe for station 475 was created.
# Merged rental count and weather dataframe for station 36 was created.
# Merged rental count and weather dataframe for station 432 was created.
# Merged rental count and weather dataframe for station 282 was created.
# Merged rental count and weather dataframe for station 450 was created.
# Merged rental count and weather dataframe for station 58 was created.
# Merged rental count and weather dataframe for station 387 was created.
# Merged rental count and weather dataframe for station 308 was created.
# Merged rental count and weather dataframe for station 143 was created.
# Merged rental count and weather dataframe for station 126 was created.
# Merged rental count and weather dataframe for station 464 was created.
# Merged rental count and weather dataframe for station 259 was created.
# Merged rental count and weather dataframe for station 95 was created.
# Merged rental count and weather dataframe for station 200 was created.
# Merged rental count and weather dataframe for station 71 was created.
# Merged rental count and weather dataframe for station 306 was created.
# Merged rental count and weather dataframe for station 414 was created.
# Merged rental count and weather dataframe for station 367 was created.
# Merged rental count and weather dataframe for station 97 was created.
# Merged rental count and weather dataframe for station 156 was created.
# Merged rental count and weather dataframe for station 429 was created.
# Merged rental count and weather dataframe for station 307 was created.
# Merged rental count and weather dataframe for station 173 was created.
# Merged rental count and weather dataframe for station 109 was created.
# Merged rental count and weather dataframe for station 325 was created.
# Merged rental count and weather dataframe for station 127 was created.
# Merged rental count and weather dataframe for station 370 was created.
# Merged rental count and weather dataframe for station 424 was created.
# Merged rental count and weather dataframe for station 91 was created.
# Merged rental count and weather dataframe for station 229 was created.
# Merged rental count and weather dataframe for station 361 was created.
# Merged rental count and weather dataframe for station 222 was created.
# Merged rental count and weather dataframe for station 49 was created.
# Merged rental count and weather dataframe for station 218 was created.
# Merged rental count and weather dataframe for station 88 was created.
# Merged rental count and weather dataframe for station 82 was created.
# Merged rental count and weather dataframe for station 303 was created.
# Merged rental count and weather dataframe for station 100 was created.
# Merged rental count and weather dataframe for station 412 was created.
# Merged rental count and weather dataframe for station 144 was created.
# Merged rental count and weather dataframe for station 339 was created.
# Merged rental count and weather dataframe for station 298 was created.
# Merged rental count and weather dataframe for station 349 was created.
# Merged rental count and weather dataframe for station 60 was created.
# Merged rental count and weather dataframe for station 92 was created.
# Merged rental count and weather dataframe for station 120 was created.
# Merged rental count and weather dataframe for station 365 was created.
# Merged rental count and weather dataframe for station 348 was created.
# Merged rental count and weather dataframe for station 190 was created.
# Merged rental count and weather dataframe for station 148 was created.
# Merged rental count and weather dataframe for station 288 was created.
# Merged rental count and weather dataframe for station 283 was created.
# Merged rental count and weather dataframe for station 300 was created.
# Merged rental count and weather dataframe for station 207 was created.
# Merged rental count and weather dataframe for station 234 was created.
# Merged rental count and weather dataframe for station 375 was created.
# Merged rental count and weather dataframe for station 409 was created.
# Merged rental count and weather dataframe for station 125 was created.
# Merged rental count and weather dataframe for station 139 was created.
# Merged rental count and weather dataframe for station 262 was created.
# Merged rental count and weather dataframe for station 353 was created.
# Merged rental count and weather dataframe for station 332 was created.
# Merged rental count and weather dataframe for station 188 was created.
# Merged rental count and weather dataframe for station 417 was created.
# Merged rental count and weather dataframe for station 469 was created.
# Merged rental count and weather dataframe for station 419 was created.
# Merged rental count and weather dataframe for station 246 was created.
# Merged rental count and weather dataframe for station 179 was created.
# Merged rental count and weather dataframe for station 437 was created.
# Merged rental count and weather dataframe for station 315 was created.
# Merged rental count and weather dataframe for station 185 was created.
# Merged rental count and weather dataframe for station 377 was created.
# Merged rental count and weather dataframe for station 413 was created.
# Merged rental count and weather dataframe for station 55 was created.
# Merged rental count and weather dataframe for station 362 was created.
# Merged rental count and weather dataframe for station 394 was created.
# Merged rental count and weather dataframe for station 456 was created.
# Merged rental count and weather dataframe for station 177 was created.
# Merged rental count and weather dataframe for station 48 was created.
# Merged rental count and weather dataframe for station 247 was created.
# Merged rental count and weather dataframe for station 231 was created.
# Merged rental count and weather dataframe for station 333 was created.
# Merged rental count and weather dataframe for station 423 was created.
# Merged rental count and weather dataframe for station 460 was created.
# Merged rental count and weather dataframe for station 468 was created.
# Merged rental count and weather dataframe for station 443 was created.
# Merged rental count and weather dataframe for station 459 was created.
# Merged rental count and weather dataframe for station 457 was created.
# Merged rental count and weather dataframe for station 324 was created.
# Merged rental count and weather dataframe for station 438 was created.
# Merged rental count and weather dataframe for station 104 was created.
# Merged rental count and weather dataframe for station 294 was created.
# Merged rental count and weather dataframe for station 80 was created.
# Merged rental count and weather dataframe for station 94 was created.
# Merged rental count and weather dataframe for station 135 was created.
# Merged rental count and weather dataframe for station 136 was created.
# Merged rental count and weather dataframe for station 75 was created.
# Merged rental count and weather dataframe for station 15 was created.
# Merged rental count and weather dataframe for station 17 was created.
# Merged rental count and weather dataframe for station 14 was created.
# Merged rental count and weather dataframe for station 20 was created.
# Merged rental count and weather dataframe for station 27 was created.
# Merged rental count and weather dataframe for station 121 was created.
# Merged rental count and weather dataframe for station 252 was created.
# Merged rental count and weather dataframe for station 251 was created.
# Merged rental count and weather dataframe for station 117 was created.
# Merged rental count and weather dataframe for station 217 was created.
# Merged rental count and weather dataframe for station 224 was created.
# Merged rental count and weather dataframe for station 250 was created.
# Merged rental count and weather dataframe for station 215 was created.
# Merged rental count and weather dataframe for station 202 was created.
# Merged rental count and weather dataframe for station 258 was created.
# Merged rental count and weather dataframe for station 240 was created.
# Merged rental count and weather dataframe for station 47 was created.
# Merged rental count and weather dataframe for station 11 was created.
# Merged rental count and weather dataframe for station 18 was created.
# Merged rental count and weather dataframe for station 38 was created.
# Merged rental count and weather dataframe for station 13 was created.
# Merged rental count and weather dataframe for station 449 was created.
# Merged rental count and weather dataframe for station 265 was created.
# Merged rental count and weather dataframe for station 23 was created.
# Merged rental count and weather dataframe for station 34 was created.
# Merged rental count and weather dataframe for station 28 was created.
# Merged rental count and weather dataframe for station 103 was created.
# Merged rental count and weather dataframe for station 470 was created.
# Merged rental count and weather dataframe for station 183 was created.
# Merged rental count and weather dataframe for station 85 was created.
# Merged rental count and weather dataframe for station 227 was created.
# Merged rental count and weather dataframe for station 232 was created.
# Merged rental count and weather dataframe for station 211 was created.
# Merged rental count and weather dataframe for station 1 was created.
# Merged rental count and weather dataframe for station 480 was created.
# Merged rental count and weather dataframe for station 474 was created.
# Merged rental count and weather dataframe for station 176 was created.
# Merged rental count and weather dataframe for station 478 was created.
# Merged rental count and weather dataframe for station 257 was created.
# Merged rental count and weather dataframe for station 248 was created.
# Merged rental count and weather dataframe for station 219 was created.
# Merged rental count and weather dataframe for station 465 was created.
# Merged rental count and weather dataframe for station 455 was created.
# Merged rental count and weather dataframe for station 221 was created.
# Merged rental count and weather dataframe for station 86 was created.
# Merged rental count and weather dataframe for station 201 was created.
# Merged rental count and weather dataframe for station 223 was created.
# Merged rental count and weather dataframe for station 1000 was created.
# Merged rental count and weather dataframe for station 208 was created.
# Merged rental count and weather dataframe for station 210 was created.
# Merged rental count and weather dataframe for station 233 was created.
# Merged rental count and weather dataframe for station 87 was created.
# Merged rental count and weather dataframe for station 8 was created.
# Merged rental count and weather dataframe for station 206 was created.
# Merged rental count and weather dataframe for station 242 was created.
# Merged rental count and weather dataframe for station 451 was created.
# Merged rental count and weather dataframe for station 21 was created.
# Merged rental count and weather dataframe for station 244 was created.
# Merged rental count and weather dataframe for station 142 was created.
# Merged rental count and weather dataframe for station 225 was created.
# Merged rental count and weather dataframe for station 553 was created.
# Merged rental count and weather dataframe for station 145 was created.
# Merged rental count and weather dataframe for station 51 was created.
# Merged rental count and weather dataframe for station 186 was created.
# Merged rental count and weather dataframe for station 253 was created.
# Merged rental count and weather dataframe for station 452 was created.
# Merged rental count and weather dataframe for station 61 was created.
# Merged rental count and weather dataframe for station 62 was created.
# Merged rental count and weather dataframe for station 50 was created.
# Merged rental count and weather dataframe for station 448 was created.
# Merged rental count and weather dataframe for station 668 was created.
# Merged rental count and weather dataframe for station 554 was created.
# Merged rental count and weather dataframe for station 129 was created.
# Merged rental count and weather dataframe for station 552 was created.
# Merged rental count and weather dataframe for station 130 was created.
# Merged rental count and weather dataframe for station 68 was created.
# Merged rental count and weather dataframe for station 151 was created.
# Merged rental count and weather dataframe for station 550 was created.
# Merged rental count and weather dataframe for station 155 was created.
# Merged rental count and weather dataframe for station 551 was created.
# Merged rental count and weather dataframe for station 162 was created.
# Merged rental count and weather dataframe for station 656 was created.
# Merged rental count and weather dataframe for station 170 was created.
# Merged rental count and weather dataframe for station 549 was created.
# Merged rental count and weather dataframe for station 24 was created.
# Merged rental count and weather dataframe for station 9 was created.
# Merged rental count and weather dataframe for station 191 was created.
# Merged rental count and weather dataframe for station 52 was created.
# Merged rental count and weather dataframe for station 45 was created.
# Merged rental count and weather dataframe for station 657 was created.
# Merged rental count and weather dataframe for station 670 was created.
# Merged rental count and weather dataframe for station 194 was created.
# Merged rental count and weather dataframe for station 286 was created.
# Merged rental count and weather dataframe for station 26 was created.
# Merged rental count and weather dataframe for station 160 was created.
# Merged rental count and weather dataframe for station 660 was created.
# Merged rental count and weather dataframe for station 667 was created.
# Merged rental count and weather dataframe for station 658 was created.
# Merged rental count and weather dataframe for station 659 was created.
# Merged rental count and weather dataframe for station 163 was created.
# Merged rental count and weather dataframe for station 84 was created.
# Merged rental count and weather dataframe for station 184 was created.
# Merged rental count and weather dataframe for station 77 was created.
# Merged rental count and weather dataframe for station 78 was created.
# Merged rental count and weather dataframe for station 73 was created.
# Merged rental count and weather dataframe for station 54 was created.
# Merged rental count and weather dataframe for station 96 was created.
# Merged rental count and weather dataframe for station 239 was created.
# Merged rental count and weather dataframe for station 305 was created.
# Merged rental count and weather dataframe for station 169 was created.
# Merged rental count and weather dataframe for station 168 was created.
# Merged rental count and weather dataframe for station 153 was created.
# Merged rental count and weather dataframe for station 171 was created.
# Merged rental count and weather dataframe for station 154 was created.
# Merged rental count and weather dataframe for station 309 was created.
# Merged rental count and weather dataframe for station 430 was created.
# Merged rental count and weather dataframe for station 182 was created.
# Merged rental count and weather dataframe for station 291 was created.
# Merged rental count and weather dataframe for station 314 was created.
# Merged rental count and weather dataframe for station 279 was created.
# Merged rental count and weather dataframe for station 187 was created.
# Merged rental count and weather dataframe for station 331 was created.
# Merged rental count and weather dataframe for station 310 was created.
# Merged rental count and weather dataframe for station 297 was created.
# Merged rental count and weather dataframe for station 323 was created.
# Merged rental count and weather dataframe for station 296 was created.
# Merged rental count and weather dataframe for station 295 was created.
# Merged rental count and weather dataframe for station 319 was created.
# Merged rental count and weather dataframe for station 351 was created.
# Merged rental count and weather dataframe for station 329 was created.
# Merged rental count and weather dataframe for station 164 was created.
# Merged rental count and weather dataframe for station 340 was created.
# Merged rental count and weather dataframe for station 336 was created.
# Merged rental count and weather dataframe for station 669 was created.
# Merged rental count and weather dataframe for station 352 was created.
# Merged rental count and weather dataframe for station 209 was created.
# Merged rental count and weather dataframe for station 355 was created.
# Merged rental count and weather dataframe for station 304 was created.
# Merged rental count and weather dataframe for station 346 was created.
# Merged rental count and weather dataframe for station 299 was created.
# Merged rental count and weather dataframe for station 276 was created.
# Merged rental count and weather dataframe for station 380 was created.
# Merged rental count and weather dataframe for station 334 was created.
# Merged rental count and weather dataframe for station 385 was created.
# Merged rental count and weather dataframe for station 316 was created.
# Merged rental count and weather dataframe for station 317 was created.
# Merged rental count and weather dataframe for station 90 was created.
# Merged rental count and weather dataframe for station 290 was created.
# Merged rental count and weather dataframe for station 363 was created.
# Merged rental count and weather dataframe for station 366 was created.
# Merged rental count and weather dataframe for station 369 was created.
# Merged rental count and weather dataframe for station 347 was created.
# Merged rental count and weather dataframe for station 292 was created.
# Merged rental count and weather dataframe for station 328 was created.
# Merged rental count and weather dataframe for station 373 was created.
# Merged rental count and weather dataframe for station 342 was created.
# Merged rental count and weather dataframe for station 205 was created.
# Merged rental count and weather dataframe for station 422 was created.
# Merged rental count and weather dataframe for station 338 was created.
# Merged rental count and weather dataframe for station 389 was created.
# Merged rental count and weather dataframe for station 395 was created.
# Merged rental count and weather dataframe for station 371 was created.
# Merged rental count and weather dataframe for station 416 was created.
# Merged rental count and weather dataframe for station 386 was created.
# Merged rental count and weather dataframe for station 401 was created.
# Merged rental count and weather dataframe for station 420 was created.
# Merged rental count and weather dataframe for station 436 was created.
# Merged rental count and weather dataframe for station 396 was created.
# Merged rental count and weather dataframe for station 359 was created.
# Merged rental count and weather dataframe for station 402 was created.
# Merged rental count and weather dataframe for station 433 was created.
# Merged rental count and weather dataframe for station 442 was created.
# Merged rental count and weather dataframe for station 356 was created.
# Merged rental count and weather dataframe for station 404 was created.
# Merged rental count and weather dataframe for station 398 was created.
# Merged rental count and weather dataframe for station 326 was created.
# Merged rental count and weather dataframe for station 230 was created.
# Merged rental count and weather dataframe for station 138 was created.
# Merged rental count and weather dataframe for station 203 was created.
# Merged rental count and weather dataframe for station 178 was created.
# Merged rental count and weather dataframe for station 172 was created.
# Merged rental count and weather dataframe for station 39 was created.
# Merged rental count and weather dataframe for station 483 was created.
# Merged rental count and weather dataframe for station 198 was created.
# Merged rental count and weather dataframe for station 321 was created.
# Merged rental count and weather dataframe for station 313 was created.
# Merged rental count and weather dataframe for station 485 was created.
# Merged rental count and weather dataframe for station 277 was created.
# Merged rental count and weather dataframe for station 444 was created.
# Merged rental count and weather dataframe for station 471 was created.
# Merged rental count and weather dataframe for station 301 was created.
# Merged rental count and weather dataframe for station 462 was created.
# Merged rental count and weather dataframe for station 441 was created.
# Merged rental count and weather dataframe for station 477 was created.
# Merged rental count and weather dataframe for station 392 was created.
# Merged rental count and weather dataframe for station 546 was created.
# Merged rental count and weather dataframe for station 453 was created.
# Merged rental count and weather dataframe for station 4 was created.
# Merged rental count and weather dataframe for station 357 was created.
# Merged rental count and weather dataframe for station 473 was created.
# Merged rental count and weather dataframe for station 149 was created.
# Merged rental count and weather dataframe for station 146 was created.
# Merged rental count and weather dataframe for station 69 was created.
# Merged rental count and weather dataframe for station 245 was created.
# Merged rental count and weather dataframe for station 537 was created.
# Merged rental count and weather dataframe for station 481 was created.
# Merged rental count and weather dataframe for station 425 was created.
# Merged rental count and weather dataframe for station 492 was created.
# Merged rental count and weather dataframe for station 496 was created.
# Merged rental count and weather dataframe for station 495 was created.
# Merged rental count and weather dataframe for station 504 was created.
# Merged rental count and weather dataframe for station 498 was created.
# Merged rental count and weather dataframe for station 502 was created.
# Merged rental count and weather dataframe for station 536 was created.
# Merged rental count and weather dataframe for station 497 was created.
# Merged rental count and weather dataframe for station 507 was created.
# Merged rental count and weather dataframe for station 506 was created.
# Merged rental count and weather dataframe for station 503 was created.
# Merged rental count and weather dataframe for station 499 was created.
# Merged rental count and weather dataframe for station 541 was created.
# Merged rental count and weather dataframe for station 482 was created.
# Merged rental count and weather dataframe for station 458 was created.
# Merged rental count and weather dataframe for station 486 was created.
# Merged rental count and weather dataframe for station 98 was created.
# Merged rental count and weather dataframe for station 543 was created.
# Merged rental count and weather dataframe for station 672 was created.
# Merged rental count and weather dataframe for station 703 was created.
# Merged rental count and weather dataframe for station 540 was created.
# Merged rental count and weather dataframe for station 673 was created.
# Merged rental count and weather dataframe for station 700 was created.
# Merged rental count and weather dataframe for station 709 was created.
# Merged rental count and weather dataframe for station 706 was created.
# Merged rental count and weather dataframe for station 704 was created.
# Merged rental count and weather dataframe for station 491 was created.
# Merged rental count and weather dataframe for station 702 was created.
# Merged rental count and weather dataframe for station 545 was created.
# Merged rental count and weather dataframe for station 708 was created.
# Merged rental count and weather dataframe for station 626 was created.
# Merged rental count and weather dataframe for station 696 was created.
# Merged rental count and weather dataframe for station 615 was created.
# Merged rental count and weather dataframe for station 597 was created.
# Merged rental count and weather dataframe for station 694 was created.
# Merged rental count and weather dataframe for station 630 was created.
# Merged rental count and weather dataframe for station 617 was created.
# Merged rental count and weather dataframe for station 691 was created.
# Merged rental count and weather dataframe for station 689 was created.
# Merged rental count and weather dataframe for station 692 was created.
# Merged rental count and weather dataframe for station 701 was created.
# Merged rental count and weather dataframe for station 618 was created.
# Merged rental count and weather dataframe for station 612 was created.
# Merged rental count and weather dataframe for station 661 was created.
# Merged rental count and weather dataframe for station 652 was created.
# Merged rental count and weather dataframe for station 688 was created.
# Merged rental count and weather dataframe for station 629 was created.
# Merged rental count and weather dataframe for station 651 was created.
# Merged rental count and weather dataframe for station 649 was created.
# Merged rental count and weather dataframe for station 602 was created.
# Merged rental count and weather dataframe for station 624 was created.
# Merged rental count and weather dataframe for station 611 was created.
# Merged rental count and weather dataframe for station 637 was created.
# Merged rental count and weather dataframe for station 639 was created.
# Merged rental count and weather dataframe for station 633 was created.
# Merged rental count and weather dataframe for station 592 was created.
# Merged rental count and weather dataframe for station 619 was created.
# Merged rental count and weather dataframe for station 623 was created.
# Merged rental count and weather dataframe for station 620 was created.
# Merged rental count and weather dataframe for station 562 was created.
# Merged rental count and weather dataframe for station 559 was created.
# Merged rental count and weather dataframe for station 634 was created.
# Merged rental count and weather dataframe for station 589 was created.
# Merged rental count and weather dataframe for station 560 was created.
# Merged rental count and weather dataframe for station 579 was created.
# Merged rental count and weather dataframe for station 568 was created.
# Merged rental count and weather dataframe for station 564 was created.
# Merged rental count and weather dataframe for station 577 was created.
# Merged rental count and weather dataframe for station 609 was created.
# Merged rental count and weather dataframe for station 567 was created.
# Merged rental count and weather dataframe for station 604 was created.
# Merged rental count and weather dataframe for station 494 was created.
# Merged rental count and weather dataframe for station 573 was created.
# Merged rental count and weather dataframe for station 501 was created.
# Merged rental count and weather dataframe for station 571 was created.
# Merged rental count and weather dataframe for station 580 was created.
# Merged rental count and weather dataframe for station 569 was created.
# Merged rental count and weather dataframe for station 643 was created.
# Merged rental count and weather dataframe for station 603 was created.
# Merged rental count and weather dataframe for station 578 was created.
# Merged rental count and weather dataframe for station 645 was created.
# Merged rental count and weather dataframe for station 563 was created.
# Merged rental count and weather dataframe for station 697 was created.
# Merged rental count and weather dataframe for station 575 was created.
# Merged rental count and weather dataframe for station 590 was created.
# Merged rental count and weather dataframe for station 556 was created.
# Merged rental count and weather dataframe for station 584 was created.
# Merged rental count and weather dataframe for station 463 was created.
# Merged rental count and weather dataframe for station 650 was created.
# Merged rental count and weather dataframe for station 679 was created.
# Merged rental count and weather dataframe for station 678 was created.
# Merged rental count and weather dataframe for station 664 was created.
# Merged rental count and weather dataframe for station 666 was created.
# Merged rental count and weather dataframe for station 663 was created.
# Merged rental count and weather dataframe for station 662 was created.
# Merged rental count and weather dataframe for station 686 was created.
# Merged rental count and weather dataframe for station 525 was created.
# Merged rental count and weather dataframe for station 527 was created.
# Merged rental count and weather dataframe for station 521 was created.
# Merged rental count and weather dataframe for station 519 was created.
# Merged rental count and weather dataframe for station 518 was created.
# Merged rental count and weather dataframe for station 517 was created.
# Merged rental count and weather dataframe for station 516 was created.
# Merged rental count and weather dataframe for station 531 was created.
# Merged rental count and weather dataframe for station 514 was created.
# Merged rental count and weather dataframe for station 655 was created.
# Merged rental count and weather dataframe for station 684 was created.
# Merged rental count and weather dataframe for station 665 was created.
# Merged rental count and weather dataframe for station 635 was created.
# Merged rental count and weather dataframe for station 613 was created.
# Merged rental count and weather dataframe for station 631 was created.
# Merged rental count and weather dataframe for station 594 was created.
# Merged rental count and weather dataframe for station 628 was created.
# Merged rental count and weather dataframe for station 557 was created.
# Merged rental count and weather dataframe for station 687 was created.
# Merged rental count and weather dataframe for station 510 was created.
# Merged rental count and weather dataframe for station 512 was created.
# Merged rental count and weather dataframe for station 548 was created.
# Merged rental count and weather dataframe for station 608 was created.
# Merged rental count and weather dataframe for station 539 was created.
# Merged rental count and weather dataframe for station 622 was created.
# Merged rental count and weather dataframe for station 642 was created.
# Merged rental count and weather dataframe for station 4422222 was created.
# Merged rental count and weather dataframe for station 595 was created.
# Merged rental count and weather dataframe for station 585 was created.
# Merged rental count and weather dataframe for station 561 was created.
# Merged rental count and weather dataframe for station 636 was created.
# Merged rental count and weather dataframe for station 596 was created.
# Merged rental count and weather dataframe for station 621 was created.
# Merged rental count and weather dataframe for station 598 was created.
# Merged rental count and weather dataframe for station 698 was created.
# Merged rental count and weather dataframe for station 607 was created.
# Merged rental count and weather dataframe for station 685 was created.
# Merged rental count and weather dataframe for station 699 was created.
# Merged rental count and weather dataframe for station 671 was created.
# Merged rental count and weather dataframe for station 542 was created.
# Merged rental count and weather dataframe for station 610 was created.
# Merged rental count and weather dataframe for station 493 was created.
# Merged rental count and weather dataframe for station 500 was created.
# Merged rental count and weather dataframe for station 583 was created.
# Merged rental count and weather dataframe for station 599 was created.
# Merged rental count and weather dataframe for station 644 was created.
# Merged rental count and weather dataframe for station 572 was created.
# Merged rental count and weather dataframe for station 591 was created.
# Merged rental count and weather dataframe for station 601 was created.
# Merged rental count and weather dataframe for station 695 was created.
# Merged rental count and weather dataframe for station 640 was created.
# Merged rental count and weather dataframe for station 484 was created.
# Merged rental count and weather dataframe for station 593 was created.
# Merged rental count and weather dataframe for station 544 was created.
# Merged rental count and weather dataframe for station 490 was created.
# Merged rental count and weather dataframe for station 106 was created.
# Merged rental count and weather dataframe for station 707 was created.
# Merged rental count and weather dataframe for station 693 was created.
# Merged rental count and weather dataframe for station 538 was created.
# Merged rental count and weather dataframe for station 487 was created.
# Merged rental count and weather dataframe for station 654 was created.
# Merged rental count and weather dataframe for station 648 was created.
# Merged rental count and weather dataframe for station 570 was created.
# Merged rental count and weather dataframe for station 674 was created.
# Merged rental count and weather dataframe for station 605 was created.
# Merged rental count and weather dataframe for station 653 was created.
# Merged rental count and weather dataframe for station 705 was created.
# Merged rental count and weather dataframe for station 600 was created.
# Merged rental count and weather dataframe for station 638 was created.
# Merged rental count and weather dataframe for station 505 was created.
# Merged rental count and weather dataframe for station 690 was created.
# Merged rental count and weather dataframe for station 627 was created.
# Merged rental count and weather dataframe for station 641 was created.
# Merged rental count and weather dataframe for station 646 was created.
# Merged rental count and weather dataframe for station 558 was created.
# Merged rental count and weather dataframe for station 576 was created.
# Merged rental count and weather dataframe for station 632 was created.
# Merged rental count and weather dataframe for station 197 was created.
# Merged rental count and weather dataframe for station 489 was created.
# Merged rental count and weather dataframe for station 614 was created.
# Merged rental count and weather dataframe for station 565 was created.
# Merged rental count and weather dataframe for station 566 was created.
# Merged rental count and weather dataframe for station 625 was created.
# Merged rental count and weather dataframe for station 581 was created.
# Merged rental count and weather dataframe for station 616 was created.
# Merged rental count and weather dataframe for station 586 was created.
# Merged rental count and weather dataframe for station 587 was created.
# Merged rental count and weather dataframe for station 574 was created.
# Merged rental count and weather dataframe for station 535 was created.
# Merged rental count and weather dataframe for station 582 was created.
# Merged rental count and weather dataframe for station 683 was created.
# Merged rental count and weather dataframe for station 488 was created.
# Merged rental count and weather dataframe for station 606 was created.
# Merged rental count and weather dataframe for station 547 was created.
# Merged rental count and weather dataframe for station 526 was created.
# Merged rental count and weather dataframe for station 523 was created.
# Merged rental count and weather dataframe for station 522 was created.
# Merged rental count and weather dataframe for station 528 was created.
# Number of new dataframes: 644

# %%
# calling aggregated dataframe merged with weather for pickup_station 6
# stations_weather_rentals[6].tail(50)
# Out:
#                      rental_counts  avg_rental_duration  is_business_day  \
# 2024-01-29 22:00:00            3.0                 9.00                1
# 2024-01-29 23:00:00            0.0                 0.00                1
# 2024-01-30 00:00:00            4.0                18.50                1
# 2024-01-30 01:00:00            0.0                 0.00                1
# 2024-01-30 02:00:00            0.0                 0.00                1
# 2024-01-30 03:00:00            0.0                 0.00                1
# 2024-01-30 04:00:00            0.0                 0.00                1
# 2024-01-30 05:00:00            2.0                 8.00                1
# 2024-01-30 06:00:00            8.0                12.25                1
# 2024-01-30 07:00:00           11.0                12.45                1
# 2024-01-30 08:00:00           13.0                12.23                1
# 2024-01-30 09:00:00            6.0                17.67                1
# 2024-01-30 10:00:00           15.0                16.40                1
# 2024-01-30 11:00:00            8.0                11.12                1
# 2024-01-30 12:00:00            4.0                18.75                1
# 2024-01-30 13:00:00            8.0                17.00                1
# 2024-01-30 14:00:00            7.0                14.71                1
# 2024-01-30 15:00:00           17.0                13.18                1
# 2024-01-30 16:00:00           16.0                12.94                1
# 2024-01-30 17:00:00           16.0                11.31                1
# 2024-01-30 18:00:00           18.0                16.22                1
# 2024-01-30 19:00:00            8.0                17.50                1
# 2024-01-30 20:00:00            5.0                13.00                1
# 2024-01-30 21:00:00            8.0                17.25                1
# 2024-01-30 22:00:00            4.0                11.50                1
# 2024-01-30 23:00:00            2.0                12.50                1
# 2024-01-31 00:00:00            3.0                19.00                1
# 2024-01-31 01:00:00            0.0                 0.00                1
# 2024-01-31 02:00:00            0.0                 0.00                1
# 2024-01-31 03:00:00            0.0                 0.00                1
# 2024-01-31 04:00:00            0.0                 0.00                1
# 2024-01-31 05:00:00            2.0                 7.50                1
# 2024-01-31 06:00:00            8.0                11.50                1
# 2024-01-31 07:00:00           10.0                11.10                1
# 2024-01-31 08:00:00           11.0                14.00                1
# 2024-01-31 09:00:00           12.0                13.08                1
# 2024-01-31 10:00:00            6.0                20.83                1
# 2024-01-31 11:00:00            5.0                13.40                1
# 2024-01-31 12:00:00            7.0                11.57                1
# 2024-01-31 13:00:00           13.0                18.85                1
# 2024-01-31 14:00:00           11.0                14.45                1
# 2024-01-31 15:00:00           18.0                13.17                1
# 2024-01-31 16:00:00           12.0                13.25                1
# 2024-01-31 17:00:00           19.0                14.11                1
# 2024-01-31 18:00:00           19.0                17.79                1
# 2024-01-31 19:00:00           12.0                19.33                1
# 2024-01-31 20:00:00            7.0                17.29                1
# 2024-01-31 21:00:00            7.0                12.57                1
# 2024-01-31 22:00:00            9.0                15.56                1
# 2024-01-31 23:00:00            1.0                 6.00                1
#
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 2024-01-29 22:00:00           21.6                 14               17.3
# 2024-01-29 23:00:00           21.3                 15               16.6
# 2024-01-30 00:00:00           19.8                 22               15.1
# 2024-01-30 01:00:00           17.7                 34               13.4
# 2024-01-30 02:00:00           16.2                 41               12.6
# 2024-01-30 03:00:00           14.7                 47               11.3
# 2024-01-30 04:00:00           13.7                 48               10.4
# 2024-01-30 05:00:00           13.0                 50                9.7
# 2024-01-30 06:00:00           12.2                 53                9.3
# 2024-01-30 07:00:00           11.4                 57                8.8
# 2024-01-30 08:00:00           10.5                 61                8.1
# 2024-01-30 09:00:00           10.3                 61                7.7
# 2024-01-30 10:00:00            9.3                 65                6.7
# 2024-01-30 11:00:00            8.8                 67                6.3
# 2024-01-30 12:00:00            7.8                 72                5.2
# 2024-01-30 13:00:00            7.8                 71                5.2
# 2024-01-30 14:00:00            8.9                 67                6.6
# 2024-01-30 15:00:00           11.2                 55                9.2
# 2024-01-30 16:00:00           13.2                 47               11.4
# 2024-01-30 17:00:00           15.4                 40               13.1
# 2024-01-30 18:00:00           18.0                 30               15.7
# 2024-01-30 19:00:00           19.8                 24               16.6
# 2024-01-30 20:00:00           21.4                 19               17.3
# 2024-01-30 21:00:00           21.4                 17               16.2
# 2024-01-30 22:00:00           19.5                 20               13.4
# 2024-01-30 23:00:00           18.4                 23               12.9
# 2024-01-31 00:00:00           17.7                 23               12.6
# 2024-01-31 01:00:00           17.3                 18               12.5
# 2024-01-31 02:00:00           16.6                 21               12.4
# 2024-01-31 03:00:00           16.0                 22               11.9
# 2024-01-31 04:00:00           15.0                 25               11.2
# 2024-01-31 05:00:00           14.3                 30               11.0
# 2024-01-31 06:00:00           13.5                 38               10.7
# 2024-01-31 07:00:00           13.2                 42               10.8
# 2024-01-31 08:00:00           12.7                 44               10.5
# 2024-01-31 09:00:00           11.9                 39                9.0
# 2024-01-31 10:00:00           11.5                 41                8.7
# 2024-01-31 11:00:00           11.3                 44                8.7
# 2024-01-31 12:00:00           11.1                 55                9.2
# 2024-01-31 13:00:00           10.9                 59                8.9
# 2024-01-31 14:00:00           11.4                 53                9.4
# 2024-01-31 15:00:00           12.9                 47               10.7
# 2024-01-31 16:00:00           15.2                 36               12.8
# 2024-01-31 17:00:00           16.4                 32               13.7
# 2024-01-31 18:00:00           17.9                 28               14.9
# 2024-01-31 19:00:00           18.8                 26               15.5
# 2024-01-31 20:00:00           20.8                 20               17.2
# 2024-01-31 21:00:00           21.7                 20               18.4
# 2024-01-31 22:00:00           21.7                 20               18.3
# 2024-01-31 23:00:00           21.4                 21               18.1
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 2024-01-29 22:00:00      0.0                87             8.9       1
# 2024-01-29 23:00:00      0.0                87            11.9       1
# 2024-01-30 00:00:00      0.0                85            14.7       1
# 2024-01-30 01:00:00      0.0                88            16.9       0
# 2024-01-30 02:00:00      0.0                87            13.1       0
# 2024-01-30 03:00:00      0.0                89            12.4       0
# 2024-01-30 04:00:00      0.0                90            11.6       0
# 2024-01-30 05:00:00      0.0                90            11.4       0
# 2024-01-30 06:00:00      0.0                80             8.7       0
# 2024-01-30 07:00:00      0.0                35             6.8       0
# 2024-01-30 08:00:00      0.0                85             5.9       0
# 2024-01-30 09:00:00      0.0                35             6.3       0
# 2024-01-30 10:00:00      0.0                37             7.3       0
# 2024-01-30 11:00:00      0.0                37             6.6       0
# 2024-01-30 12:00:00      0.0                43             6.6       0
# 2024-01-30 13:00:00      0.0                84             7.1       0
# 2024-01-30 14:00:00      0.0                90             4.8       1
# 2024-01-30 15:00:00      0.0                90             1.9       1
# 2024-01-30 16:00:00      0.0                86             0.5       1
# 2024-01-30 17:00:00      0.0                70             3.4       1
# 2024-01-30 18:00:00      0.0                80             4.7       1
# 2024-01-30 19:00:00      0.0                85             7.7       1
# 2024-01-30 20:00:00      0.0                89            12.5       1
# 2024-01-30 21:00:00      0.0                89            16.9       1
# 2024-01-30 22:00:00      0.0                88            23.0       1
# 2024-01-30 23:00:00      0.0                86            20.4       1
# 2024-01-31 00:00:00      0.0                64            16.9       1
# 2024-01-31 01:00:00      0.0                90            12.0       0
# 2024-01-31 02:00:00      0.0                90             8.9       0
# 2024-01-31 03:00:00      0.0                58             8.2       0
# 2024-01-31 04:00:00      0.0                86             7.2       0
# 2024-01-31 05:00:00      0.0                85             5.3       0
# 2024-01-31 06:00:00      0.0                90             4.0       0
# 2024-01-31 07:00:00      0.1                90             2.6       0
# 2024-01-31 08:00:00      0.0                89             1.8       0
# 2024-01-31 09:00:00      0.0                90             3.9       0
# 2024-01-31 10:00:00      0.0                89             3.3       0
# 2024-01-31 11:00:00      0.0                90             3.0       0
# 2024-01-31 12:00:00      0.0                88             1.1       0
# 2024-01-31 13:00:00      0.0                84             3.3       0
# 2024-01-31 14:00:00      0.0                81             1.4       1
# 2024-01-31 15:00:00      0.0                71             2.5       1
# 2024-01-31 16:00:00      0.0                68             1.8       1
# 2024-01-31 17:00:00      0.0                85             3.5       1
# 2024-01-31 18:00:00      0.0                84             5.5       1
# 2024-01-31 19:00:00      0.0                75             6.6       1
# 2024-01-31 20:00:00      0.0                85             7.5       1
# 2024-01-31 21:00:00      0.0                79             6.9       1
# 2024-01-31 22:00:00      0.0                85             6.8       1
# 2024-01-31 23:00:00      0.0                62             6.5       1

# %%
# check Dtype
# stations_weather_rentals[6].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9504 entries, 2023-01-01 00:00:00 to 2024-01-31 23:00:00
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rental_counts        9504 non-null   float64
#  1   avg_rental_duration  9504 non-null   float64
#  2   is_business_day      9504 non-null   int64
#  3   temperature_C        9504 non-null   float64
#  4   rel_humidity_perc    9504 non-null   int64
#  5   feels_like_temp_C    9504 non-null   float64
#  6   rain_mm              9504 non-null   float64
#  7   cloud_cover_perc     9504 non-null   int64
#  8   wind_speed_kmh       9504 non-null   float64
#  9   is_day               9504 non-null   int64
# dtypes: float64(6), int64(4)
# memory usage: 816.8 KB

# %% [markdown]
# <b>Data frames to be used for SARIMA modelling</b>

# %%
# stored in a dictionary as values: 
    # stations_hourly_dict[6]
# station numbers stored in an array: 
    # pickup_stations

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import matplotlib.dates as mdates
import statsmodels.api as sm
from statsmodels.tsa.api import SARIMAX
InteractiveShell.ast_node_interactivity = "all"

# %%
# general check on all columns. Seems plausible.
# pd.DataFrame(hourly_weather_rentals).describe()
# Out:
#        rental_counts  avg_rental_duration  is_business_day  temperature_C  \
# count    9504.000000          9504.000000      9504.000000    9504.000000
# mean     1372.818182            13.227562         0.587016      17.058544
# std      1196.952721            15.390720         0.492396       5.645082
# min         0.000000             0.000000         0.000000       1.600000
# 25%       250.000000            12.700000         0.000000      13.000000
# 50%      1245.000000            14.530000         1.000000      16.400000
# 75%      2146.000000            16.130000         1.000000      21.400000
# max      6538.000000          1245.660000         1.000000      33.900000
#
#        rel_humidity_perc  feels_like_temp_C      rain_mm  cloud_cover_perc  \
# count        9504.000000        9504.000000  9504.000000       9504.000000
# mean           58.279987          15.700168     0.087742         32.619108
# std            24.873807           5.806799     0.512445         31.790070
# min             3.000000          -1.000000     0.000000          0.000000
# 25%            38.000000          11.800000     0.000000          3.000000
# 50%            60.000000          15.300000     0.000000         26.000000
# 75%            80.000000          19.800000     0.000000         51.000000
# max           100.000000          32.200000    10.500000        100.000000
#
#        wind_speed_kmh       is_day
# count     9504.000000  9504.000000
# mean         7.635953     0.500526
# std          5.522959     0.500026
# min          0.000000     0.000000
# 25%          3.700000     0.000000
# 50%          6.100000     1.000000
# 75%         10.100000     1.000000
# max         38.500000     1.000000

# %%
# filter out rental durations greater than 1000 minutes? 
filter_ = hourly_weather_rentals['avg_rental_duration'] < 1000
hourly_weather_rentals_filtered = hourly_weather_rentals[filter_]
hourly_weather_rentals_filtered.sort_values(by='avg_rental_duration', ascending=False)
# original dimensions of hourly_weather_rentals: (12485, 11)
# filtered = (12466, 11)
# filtered out 19 rows
# Do we want to filter it out in our modelling and analysis??
# Out:
#                      rental_counts  avg_rental_duration  is_business_day  \
# 2023-07-15 22:00:00          693.0               412.63                0
# 2023-04-29 14:00:00         1636.0               211.68                0
# 2023-04-28 14:00:00         1849.0               187.74                1
# 2023-06-19 06:00:00          844.0               170.02                1
# 2023-05-18 18:00:00         2625.0               125.48                1
# ...                            ...                  ...              ...
# 2023-12-05 04:00:00            0.0                 0.00                0
# 2023-12-05 03:00:00            0.0                 0.00                0
# 2023-12-05 02:00:00            0.0                 0.00                0
# 2023-12-05 01:00:00            0.0                 0.00                0
# 2023-12-16 01:00:00            0.0                 0.00                0
#
#                      temperature_C  rel_humidity_perc  feels_like_temp_C  \
# 2023-07-15 22:00:00           26.2                 30               25.1
# 2023-04-29 14:00:00           16.3                 32               13.4
# 2023-04-28 14:00:00           15.9                 36               13.5
# 2023-06-19 06:00:00           20.7                 37               18.3
# 2023-05-18 18:00:00           23.5                 29               23.8
# ...                            ...                ...                ...
# 2023-12-05 04:00:00           13.7                 80               12.4
# 2023-12-05 03:00:00           13.8                 82               12.8
# 2023-12-05 02:00:00           14.6                 78               13.3
# 2023-12-05 01:00:00           14.8                 76               12.2
# 2023-12-16 01:00:00           14.2                 76               13.7
#
#                      rain_mm  cloud_cover_perc  wind_speed_kmh  is_day
# 2023-07-15 22:00:00      0.0                46             6.0       1
# 2023-04-29 14:00:00      0.0                 0             4.7       1
# 2023-04-28 14:00:00      0.0                 0             2.8       1
# 2023-06-19 06:00:00      0.0                 0             8.7       0
# 2023-05-18 18:00:00      0.0                19             5.3       1
# ...                      ...               ...             ...     ...
# 2023-12-05 04:00:00      0.0                98             9.8       0
# 2023-12-05 03:00:00      0.0               100             9.2       0
# 2023-12-05 02:00:00      0.0                59            10.4       0
# 2023-12-05 01:00:00      0.1                62            19.1       0
# 2023-12-16 01:00:00      0.0               100             4.1       0
#
# [9503 rows x 10 columns]

# %%
# visualize the data: rental counts and rental duration over entire timeframe

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(hourly_weather_rentals_filtered.index, hourly_weather_rentals_filtered['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axis that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(hourly_weather_rentals_filtered.index, hourly_weather_rentals_filtered['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %%
# visualize the data: rental counts and rental duration over one business day in 2021
# Feb 11 2021 = Thursday

# Filter the data for the specified date range
random_day = hourly_weather_rentals[(
    hourly_weather_rentals.index >= '2021-02-09 00:00:00') & (hourly_weather_rentals.index <= '2021-02-09 23:00:00'
                                                               )]

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(random_day.index, random_day['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(random_day.index, random_day['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %%
# visualize the data: rental counts and rental duration over one business day for one station in 2021
# Feb 09 2021 = Tuesday
# station 27 third highest pickup counts

# Filter the data for the specified date range
random_day = stations_weather_rentals[27][(
    stations_weather_rentals[27].index >= '2021-02-09 05:00:00') & (stations_weather_rentals[27].index <= '2021-02-10 00:00:00'
                                                               )]

fig, ax1 = plt.subplots(figsize=(10,5))

color = 'tab:blue'
ax1.set_xlabel('Hour')
ax1.set_ylabel('Rental Counts', color=color)
ax1.plot(random_day.index, random_day['rental_counts'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Average Rental Duration (in minutes)', color=color)
ax2.plot(random_day.index, random_day['avg_rental_duration'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# Text(0.5, 0, 'Hour')
# Text(0, 0.5, 'Rental Counts')
# Text(0, 0.5, 'Average Rental Duration (in minutes)')

# %% [markdown]
# <b>Observation:</b> Station 182 seems to follow a more "normal" work day seasonality than Station 27. Station 182 may be closer to offices/businesses.

# %% [markdown]
# ## SARIMAX
# <b>Hyperparametres</b><br>

# %% [markdown]
# First three from ARIMA:<br>
# - <b>p</b>: Order of the AR term – relationship between an observation and a number of lagged observations (auto-regression); captures the effect of past values on current values
# - <b>d</b>: Degree of differencing – differencing of raw observations to make the time series stationary (i.e., removing trends or seasonality); represents the number of differences needed to make the series stationary.
# - <b>q</b>: Order of the MA term – relationship between the residual error and the lagged observations; captures the dependency between an observation and a residual error from a moving average model.

# %% [markdown]
# Last four for SARIMAX, similar to ARIMA hyperparamatres but with seasonal component:<br>
# - <b>P</b>: Order of the seasonal AR term.
# - <b>D</b>: Degree of seasonal differencing.
# - <b>Q</b>: Order of the seasonal MA term.
# - <b>m</b>: Seasonal length of the time series (e.g., 12 for monthly data, 4 for quarterly data)

# %% [markdown]
# ### Seasonal decomposition
# Checking out the presence of a seasonal component for one station<br>
# <br>
# <i>Parameters:</i>
# - <b>x</b>: The time series data to be decomposed.
# - <b>model</b>: This specifies the type of seasonal decomposition model to be used. It can be either 'additive' or 'multiplicative'.
#     - With the 'additive' model, the components are combined linearly, while with the 'multiplicative' model, the components are combined multiplicatively.
# - <b>filt</b>: This is an array filtering the trend component. By default, an evenly sized window will be used.
# - <b>period</b>: An integer representing the periodicity of the series, i.e. number of observations per cycle. For example, 24 for daily data with hourly observations or 12 for monthly data with yearly observations. This parameter influences the seasonal component of the decomposition.
# - <b>two_sided</b>: If True, moving averages are calculated symmetrically. If False, moving averages will be calculated using past values only.

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
rental_counts_st6 = pd.Series(stations_hourly_dict[6]['rental_counts'].values, \
                              index=stations_hourly_dict[6].index)

# %%
rental_counts_st6.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 9505 entries, 2023-01-01 00:00:00 to 2024-02-01 00:00:00
# Freq: H
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 9505 non-null   float64
# dtypes: float64(1)
# memory usage: 148.5 KB

# %%
rental_counts_st6.fillna(0,inplace=True)

# %%
# decompose from observation #13000 onwards so that we can actually see the trends and seasonalities
decomposition = sm.tsa.seasonal_decompose(rental_counts_st6[5000:], 
                                          model='additive',  # no reason (yet) to believe magnitude of variation changes significantly with time
                                          period=24) # since we have hourly data

# Extract the decomposed components
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the decomposed components
decomposition.plot()
plt.show()

# Trending upwards
# seasonality looks to be daily given the density of the plot
# resid is stable looking

# %%
# closer examination at the seasonality, definitely looks daily
seasonal = decomposition.seasonal
plt.figure(figsize=(20, 6))
seasonal.plot()
plt.show()

# %% [markdown]
# ### ACF and PACF
# ACF (Autocorrelation Function) and PACF (Partial Autocorrelation Function) plots are used to diagnose patterns of autocorrelation in time series data, which can help in identifying the proper hyperparameters for models such as ARIMA and SARIMA, i.e. the order of AR, MA, and ARMA models.<br>
# 1. <b>Autocorrelation Function (ACF) Plot:</b>
#     - The ACF plot shows the autocorrelation of the time series with its own lagged values. Each bar on the plot represents the correlation between the series and its lagged values at various lags.
#     - Interpretation: In an ACF plot, significant autocorrelations that extend beyond the critical boundaries indicate the presence of autoregressive (AR) components in the data. For example, if the ACF values decay exponentially, it may indicate the series is stationary and lends itself to an ARIMA model.
# <br><br>
# 2. <b>Partial Autocorrelation Function (PACF) Plot:</b>
#     - The PACF plot displays the partial correlation of the time series with its own lagged values, while controlling for the values of the intervening lags.
#     - Interpretation: In a PACF plot, significant partial autocorrelations that extend beyond the critical boundaries imply the presence of a moving average (MA) component in the data.

# %%
# check the ACF and PACF plots and confirm the presence of seasonality and the seasonal period
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot ACF
fig, ax = plt.subplots(figsize=(8, 3))
plot_acf(rental_counts_st6, ax=ax, lags=48)
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF)')
plt.show()

# Plot PACF
fig, ax = plt.subplots(figsize=(8, 3))
plot_pacf(rental_counts_st6, ax=ax, lags=48)
plt.xlabel('Lag')
plt.ylabel('Partial Autocorrelation')
plt.title('Partial Autocorrelation Function (PACF)')
plt.show()

# %% [markdown]
# ### Splitting the data
# starting with station 6

# %%
# split our timeseries dataset into train/test sets

def SARIMA_train_test_split(df, test_percentage): # df = dataframe, test_percentage = proportion of df we want to keep for testing
    n_test = int(round(len(df)*test_percentage, 0))
    train = df.iloc[:-n_test]
    test = df.iloc[-n_test:]
    return train, test

# %%
train, test = SARIMA_train_test_split(stations_hourly_dict[6].drop('avg_rental_duration',axis=1), 0.20)

# %%
test
# Out:
#                      rental_counts  is_business_day
# 2023-11-13 20:00:00            7.0                1
# 2023-11-13 21:00:00            9.0                1
# 2023-11-13 22:00:00            7.0                1
# 2023-11-13 23:00:00            1.0                1
# 2023-11-14 00:00:00            0.0                1
# ...                            ...              ...
# 2024-01-31 20:00:00            7.0                1
# 2024-01-31 21:00:00            7.0                1
# 2024-01-31 22:00:00            9.0                1
# 2024-01-31 23:00:00            1.0                1
# 2024-02-01 00:00:00            0.0                1
#
# [1901 rows x 2 columns]

# %% [markdown]
# ### Grid search for best hyperparameters

# %%
import itertools
import math
import warnings
warnings.filterwarnings('ignore')

# %%
# with default solver: L-BFGS-B

# # Define the range of values for p, d, q, P, D, Q, and m
# p_values = range(0, 3)  # Autoregressive order
# d_values = [0]          # Differencing order
# q_values = range(0, 3)  # Moving average order
# P_values = range(0, 2)  # Seasonal autoregressive order
# D_values = range(0, 1)  # Seasonal differencing order
# Q_values = range(0, 2)  # Seasonal moving average order
# m_values = [24]         # Seasonal period

# # Create all possible combinations of SARIMA parameters
# param_combinations = list(itertools.product(p_values, 
#                                             d_values, 
#                                             q_values, 
#                                             P_values, 
#                                             D_values, 
#                                             Q_values, 
#                                             m_values))

# # Initialize AIC with a large value (positive infinity = "inf")
# best_aic = float("inf")  
# best_params = None

# # Perform grid search
# for params in param_combinations:
#     order = params[:3]
#     seasonal_order = params[3:]
    
#     try:
#         model = sm.tsa.SARIMAX(endog=train['rental_counts'], 
#                                exog=train.drop('rental_counts',axis=1), 
#                                order=order, 
#                                seasonal_order=seasonal_order)
#         result = model.fit(disp=False)
#         aic = result.aic
        
#         # Ensure the convergence of the model
#         if not math.isinf(result.zvalues.mean()):
#             print(order, seasonal_order, aic)
        
#             if aic < best_aic:
#                 best_aic = aic
#                 best_params = params
                
#         else:
#             print(order, seasonal_order, 'not converged')

#     except:
#         continue

# # Print the best parameters and AIC
# print("Best Parameters:", best_params)
# print("Best AIC:", best_aic)
# Out:
# (0, 0, 0) (0, 0, 0, 24) 42834.37439337958
# (0, 0, 0) (0, 0, 1, 24) 41464.77510146398
# (0, 0, 0) (1, 0, 0, 24) 40610.50015737368
# (0, 0, 0) (1, 0, 1, 24) 38522.05993450863
# (0, 0, 1) (0, 0, 0, 24) 41644.7125061501
# (0, 0, 1) (0, 0, 1, 24) 40783.16641471046
# (0, 0, 1) (1, 0, 0, 24) 40266.39987611248
# (0, 0, 1) (1, 0, 1, 24) 38364.41730016533
# (0, 0, 2) (0, 0, 0, 24) 41243.58305607521
# (0, 0, 2) (0, 0, 1, 24) 40526.29770119384
# (0, 0, 2) (1, 0, 0, 24) 40114.69829019638
# (0, 0, 2) (1, 0, 1, 24) 38258.45162773178
# (1, 0, 0) (0, 0, 0, 24) 41118.457614293264
# (1, 0, 0) (0, 0, 1, 24) 40494.49093462834
# (1, 0, 0) (1, 0, 0, 24) 40140.20031139121
# (1, 0, 0) (1, 0, 1, 24) 38380.96991322709
# (1, 0, 1) (0, 0, 0, 24) 41000.233008824594
# (1, 0, 1) (0, 0, 1, 24) 40347.31632444963
# (1, 0, 1) (1, 0, 0, 24) 40030.49941219076
# (1, 0, 1) (1, 0, 1, 24) 38276.26497447549
# (1, 0, 2) (0, 0, 0, 24) 41008.33240706242
# (1, 0, 2) (0, 0, 1, 24) 40351.249057318026
# (1, 0, 2) (1, 0, 0, 24) 40026.54909466358
# (1, 0, 2) (1, 0, 1, 24) 38372.10983757078
# (2, 0, 0) (0, 0, 0, 24) 40998.2118055865
# (2, 0, 0) (0, 0, 1, 24) 40355.987814018314
# (2, 0, 0) (1, 0, 0, 24) 40018.3369223964
# (2, 0, 0) (1, 0, 1, 24) 38258.32447814812
# (2, 0, 1) (0, 0, 0, 24) 40997.01349466008
# (2, 0, 1) (0, 0, 1, 24) 40344.19344205156
# (2, 0, 1) (1, 0, 0, 24) 40009.570801131296
# (2, 0, 1) (1, 0, 1, 24) 38229.580458961296
# (2, 0, 2) (0, 0, 0, 24) 40953.40699649129
# (2, 0, 2) (0, 0, 1, 24) 40272.45508643988
# (2, 0, 2) (1, 0, 0, 24) 39998.91159344268
# (2, 0, 2) (1, 0, 1, 24) 38308.007313324066
# Best Parameters: (2, 0, 1, 1, 0, 1, 24)
# Best AIC: 38229.580458961296

# %%
# with method = 'nm'

# Define the range of values for p, d, q, P, D, Q, and m
p_values = range(0, 3)  # Autoregressive order
d_values = [0]          # Differencing order
q_values = range(0, 3)  # Moving average order
P_values = range(0, 2)  # Seasonal autoregressive order
D_values = range(0, 1)  # Seasonal differencing order
Q_values = range(0, 2)  # Seasonal moving average order
m_values = [24]         # Seasonal period

# Create all possible combinations of SARIMA parameters
param_combinations = list(itertools.product(p_values, 
                                            d_values, 
                                            q_values, 
                                            P_values, 
                                            D_values, 
                                            Q_values, 
                                            m_values))

# Initialize AIC with a large value (positive infinity = "inf")
best_aic = float("inf")  
best_params = None

# Perform grid search
for params in param_combinations:
    order = params[:3]
    seasonal_order = params[3:]
    
    try:
        model = sm.tsa.SARIMAX(endog=train['rental_counts'], 
                               exog=train.drop('rental_counts',axis=1), 
                               order=order, 
                               seasonal_order=seasonal_order)
        result = model.fit(disp=False, method='nm')
        aic = result.aic
        
        # Ensure the convergence of the model
        if not math.isinf(result.zvalues.mean()):
            print(order, seasonal_order, aic)
        
            if aic < best_aic:
                best_aic = aic
                best_params = params
                
        else:
            print(order, seasonal_order, 'not converged')

    except:
        continue

# Print the best parameters and AIC
print("Best Parameters:", best_params)
print("Best AIC:", best_aic)
# Out:
# (0, 0, 0) (0, 0, 0, 24) 46051.438253210086
# (0, 0, 0) (0, 0, 1, 24) 43620.41898090605
# (0, 0, 0) (1, 0, 0, 24) 41358.125874040416
# (0, 0, 0) (1, 0, 1, 24) 39560.85549303822
# (0, 0, 1) (0, 0, 0, 24) 43521.170891018985
# (0, 0, 1) (0, 0, 1, 24) 42275.70813082672
# (0, 0, 1) (1, 0, 0, 24) 41102.465316301736
# (0, 0, 1) (1, 0, 1, 24) 39238.62662898203
# (0, 0, 2) (0, 0, 0, 24) 42502.68389193939
# (0, 0, 2) (0, 0, 1, 24) 41661.304215840006
# (0, 0, 2) (1, 0, 0, 24) 40911.85854692885
# (0, 0, 2) (1, 0, 1, 24) 39212.60409669003
# (1, 0, 0) (0, 0, 0, 24) 41910.427825703264
# (1, 0, 0) (0, 0, 1, 24) 41347.1484772482
# (1, 0, 0) (1, 0, 0, 24) 40931.102268228235
# (1, 0, 0) (1, 0, 1, 24) 39164.04538839793
# (1, 0, 1) (0, 0, 0, 24) 41721.40188358733
# (1, 0, 1) (0, 0, 1, 24) 41040.15338167125
# (1, 0, 1) (1, 0, 0, 24) 40626.72569526899
# (1, 0, 1) (1, 0, 1, 24) 39073.85157266844
# (1, 0, 2) (0, 0, 0, 24) 41712.20840461255
# (1, 0, 2) (0, 0, 1, 24) 41034.47228457469
# (1, 0, 2) (1, 0, 0, 24) 40630.818877618
# (1, 0, 2) (1, 0, 1, 24) 39228.682441073666
# (2, 0, 0) (0, 0, 0, 24) 41711.761610241934
# (2, 0, 0) (0, 0, 1, 24) 41045.73152856064
# (2, 0, 0) (1, 0, 0, 24) 40670.94076607178
# (2, 0, 0) (1, 0, 1, 24) 38998.99694157737
# (2, 0, 1) (0, 0, 0, 24) 41713.48403989994
# (2, 0, 1) (0, 0, 1, 24) 41044.118942274145
# (2, 0, 1) (1, 0, 0, 24) 40666.11598865058
# (2, 0, 1) (1, 0, 1, 24) 39395.23658460118
# (2, 0, 2) (0, 0, 0, 24) 41707.85853185252
# (2, 0, 2) (0, 0, 1, 24) 41024.30179948486
# (2, 0, 2) (1, 0, 0, 24) 40620.305421779296
# (2, 0, 2) (1, 0, 1, 24) 39288.727749228514
# Best Parameters: (2, 0, 0, 1, 0, 1, 24)
# Best AIC: 38998.99694157737

# %% [markdown]
# ### Fitting SARIMAX + Predictions

# %%
# Assuming 'endog' contains the time series variable and 'exog' contains the exogenous variables
# Assuming 'y' is the rental_counts variable
# change the solver when fitting, L-BFGS-B is better for small datasets
    ## NOTE: Need to re-run the grid search to fit with method='nm'

# Fit the SARIMAX model
model = sm.tsa.SARIMAX(train['rental_counts'], \
                       exog=train.drop('rental_counts',axis=1), order=(2, 0, 0), seasonal_order=(1, 0, 1, 24))
results = model.fit(method='nm')

# %% [markdown]
# ### Assessing our SARIMAX model
#
# In our summary, the <b>“P>|z|”</b> provides the p-value associated with each coefficient. For the coefficient to be significant, they should be lower than our significance level of 0.05.<br>
# <br>
# Examining our model's <b>plot diagnostics</b>, we want to see:
# 1. The standardized residual shouldn’t have any obvious patterns, i.e. random noise, data with a zero mean and a uniform variance. The residuals should be uncorrelated with Gaussian noise centered on zero.
# 2. The histogram plus KDE estimate should look similar to a normal distribution
# 3. In the Normal Q-Q graph, we should observe the majority of the points lying on the straight line, indicating a normal distribution of the residuals.
#     - <i>(quantile-quantile graph: graphical comparison between the empirical quantiles of the data and the quantiles of the theoretical distribution)</i>
# 4. In the ACF or correlogram, 95% of correlations for lag greater than one should be within the confidence band, i.e. not significant.

# %%
results.summary()

# The “P>|z|” column provides the p-value associated with each coefficient, 
# for all cases they are lower than 0.05, our significance level, 
# which means that all of them are statistically significant.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                        rental_counts   No. Observations:                 7604
# Model:             SARIMAX(2, 0, 0)x(1, 0, [1], 24)   Log Likelihood              -19493.498
# Date:                              Wed, 06 Mar 2024   AIC                          38998.997
# Time:                                      15:31:45   BIC                          39040.616
# Sample:                                  01-01-2023   HQIC                         39013.279
#                                        - 11-13-2023
# Covariance Type:                                opg
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# is_business_day     3.2291      0.113     28.493      0.000       3.007       3.451
# ar.L1               0.2104      0.010     20.040      0.000       0.190       0.231
# ar.L2               0.1245      0.011     11.008      0.000       0.102       0.147
# ar.S.L24            0.9572      0.004    255.378      0.000       0.950       0.965
# ma.S.L24           -0.6961      0.011    -63.017      0.000      -0.718      -0.674
# sigma2             10.3903      0.145     71.488      0.000      10.105      10.675
# ===================================================================================
# Ljung-Box (L1) (Q):                   8.15   Jarque-Bera (JB):              1711.68
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.51   Skew:                             0.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
fig = results.plot_diagnostics(figsize=(8, 8))
fig.autofmt_xdate()
plt.show()

# 1. standardized residual looks heavier for the first half
# 2. histogram and KDE are somewhat normally distributed
# 3. In the Normal Q-Q graph, points don't completely lie on the straight line
# 4. 1st and last lags not within confidence band

# %%
# get predictions for test set
# set prediction period 
start_datetime = pd.Timestamp('2023-11-13 20:00:00')
end_datetime = pd.Timestamp('2024-02-01 00:00:00')

# Make predictions
predictions = results.predict(start=start_datetime, end=end_datetime, exog=test.drop('rental_counts',axis=1))

# %%
from sklearn.metrics import mean_squared_error as mse, mean_absolute_error as mae

# %%
# calculate residuals of our test data and predictions
test_residuals = pd.DataFrame({'rental_counts': test['rental_counts'], 'predictions': predictions}, index=predictions.index)
test_residuals['residuals'] = test_residuals['rental_counts']-test_residuals['predictions']
test_residuals
# Out:
#                      rental_counts  predictions  residuals
# 2023-11-13 20:00:00            7.0     8.389986  -1.389986
# 2023-11-13 21:00:00            9.0     5.808709   3.191291
# 2023-11-13 22:00:00            7.0     4.639481   2.360519
# 2023-11-13 23:00:00            1.0     4.705741  -3.705741
# 2023-11-14 00:00:00            0.0     2.055453  -2.055453
# ...                            ...          ...        ...
# 2024-01-31 20:00:00            7.0     3.360330   3.639670
# 2024-01-31 21:00:00            7.0     3.294031   3.705969
# 2024-01-31 22:00:00            9.0     3.266188   5.733812
# 2024-01-31 23:00:00            1.0     3.272085  -2.272085
# 2024-02-01 00:00:00            0.0     3.190324  -3.190324
#
# [1901 rows x 3 columns]

# %%
# calculating error metrics for test data

me_test = round(test_residuals.residuals.mean(),2)
print(f'mean error of test: {me_test}')

mse_test = round(mse(test['rental_counts'],predictions),2) # mean squared error
print(f'mean squared error of test: {mse_test}')

mae_test = round(mae(test['rental_counts'],predictions),2) # mean absolute error
print(f'mean absolut error of test: {mae_test}')

rmse_test = round(mse(test['rental_counts'],predictions,squared=False),2) # root mean squared error
print(f'root mean squared error of test: {rmse_test}')
# Out:
# mean error of test: 2.45
# mean squared error of test: 26.87
# mean absolut error of test: 3.73
# root mean squared error of test: 5.18

# %% [markdown]
# <b>mean error:</b> on average, the model tends to overestimate the target values by 0.92 units<br>
# <b>mean squared error:</b> A mean squared error of 20.66 indicates the average squared magnitude of the prediction errors. It provides a sense of the overall variability or dispersion of the errors.<br>
# <b>mean absolute error:</b> A mean absolute error of 3.46 signifies the average magnitude of the errors without considering their direction.<br>
# <b>root mean squared error:</b> An RMSE of 4.55 suggests the typical size of the errors (standard deviations) generated by the model.<br>

# %%
# Plot test predictions with training data

ax = train['rental_counts'][8000:].plot(figsize=(12,5))
predictions.plot()
test['rental_counts'].plot(ax=ax)
# plt.fill_between(predictions.index, 
#                  confidence_intervals['lower tmax'], 
#                  confidence_intervals['upper tmax'], 
#                  color='blue',
#                  alpha=0.15)
plt.legend(['Training rental counts', 
            'Predicted rental counts', 
            'Actual rental counts'], 
           loc='upper left')
plt.xlabel('Date & Hour')
plt.ylabel('Number of rentals')
plt.grid(alpha=0.5)
plt.show()

# %%
# Plot test forecast with training data (same as above but diff function, with confidence intervals)

forecast = results.get_forecast(steps=1901, exog=test.drop('rental_counts',axis=1)) # steps = number of rows in test set
forecast_values = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

ax = train['rental_counts'][8000:].plot(figsize=(12,5))
forecast_values.plot()
test['rental_counts'].plot(ax=ax)
plt.fill_between(predictions.index, 
                 confidence_intervals['lower rental_counts'], 
                 confidence_intervals['upper rental_counts'], 
                 color='blue',
                 alpha=0.15)
plt.legend(['Training rental counts', 
            'Predicted rental counts', 
            'Actual rental counts'], 
           loc='upper left')
plt.xlabel('Date & Hour')
plt.ylabel('Number of rentals')
plt.grid(alpha=0.5)
plt.show()

# %%
# Get forecast and confidence intervals for next two days
# NEED exogenous variables for the next 48 hours, i.e. weather data, is_business_day, etc.

forecast = results.get_forecast(steps=48, exog=test.drop('rental_counts',axis=1)) # 48 hours for next two days
forecast_values = forecast.predicted_mean
confidence_intervals = forecast.conf_int()

# Plot forecast with training data
ax = test['rental_counts'].plot(figsize=(10,5))
forecast_values.plot()
test['rental_counts'].plot(ax=ax)
plt.fill_between(forecast_values.index, 
                 confidence_intervals['lower tmax'], 
                 confidence_intervals['upper tmax'], 
                 color='blue',
                 alpha=0.15)
plt.legend(['Training rental counts', 
            'Predicted rental counts', 
            'Actual rental counts'], 
           loc='upper left')
plt.xlabel('Date & Hour')
plt.ylabel('Number of rentals')
plt.grid(alpha=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 2
#       1 # Get forecast and confidence intervals for next two days
# ----> 2 forecast = results.get_forecast(steps=48) # 48 hours for next two days
#       3 forecast_values = forecast.predicted_mean
#       4 confidence_intervals = forecast.conf_int()
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:3417, in MLEResults.get_forecast(self, steps, signal_only, **kwargs)
#    3415 else:
#    3416     end = steps
# -> 3417 return self.get_prediction(start=self.nobs, end=end,
#    3418                            signal_only=signal_only, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:3355, in MLEResults.get_prediction(self, start, end, dynamic, information_set, signal_only, index, exog, extend_model, extend_kwargs, **kwargs)
#    3352     extend_model = (self.model.exog is not None or
#    3353                     not self.filter_results.time_invariant)
#    3354 if out_of_sample and extend_model:
# -> 3355     kwargs = self.model._get_extension_time_varying_matrices(
#    3356         self.params, exog, out_of_sample, extend_kwargs,
#    3357         transformed=True, includes_fixed=True, **kwargs)
#    3359 # Make sure the model class has the current parameters
#    3360 self.model.update(self.params, transformed=True, includes_fixed=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/sarimax.py:1718, in SARIMAX._get_extension_time_varying_matrices(self, params, exog, out_of_sample, extend_kwargs, transformed, includes_fixed, **kwargs)
#    1708 """
#    1709 Get time-varying state space system matrices for extended model
#    1710
#    (...)
#    1714 special handling in the `simple_differencing=True` case.
#    1715 """
#    1717 # Get the appropriate exog for the extended sample
# -> 1718 exog = self._validate_out_of_sample_exog(exog, out_of_sample)
#    1720 # Get the tmp endog, exog
#    1721 if self.simple_differencing:
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:1769, in MLEModel._validate_out_of_sample_exog(self, exog, out_of_sample)
#    1767 if out_of_sample and k_exog > 0:
#    1768     if exog is None:
# -> 1769         raise ValueError('Out-of-sample operations in a model'
#    1770                          ' with a regression component require'
#    1771                          ' additional exogenous values via the'
#    1772                          ' `exog` argument.')
#    1773     exog = np.array(exog)
#    1774     required_exog_shape = (out_of_sample, self.k_exog)
#
# ValueError: Out-of-sample operations in a model with a regression component require additional exogenous values via the `exog` argument.
